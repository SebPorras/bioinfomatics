# %% [markdown]
# # Load in sorted fasta files and try to find columns that behave the same

# %%
import pandas as pd
from sequence import *

# %%
ec_nums = ['3_2_1_4', '3_2_1_14', '3_6_5_2', '2_7_11_22','2_4_99_18','2_7_11_24',
'2_7_3_3','4_2_1_1','3_2_1_21', '2_4_1_207', '2_7_11_1', '2_7_13_3', 
'2_7_10_2', '2_7_10_1', '1_14_99_39', '2_5_1_18', '3_2_1_8', '3_5_2_6', 
'1_15_1_1', '4_1_1_39']

# %%
def load_seqs(ec_num):
    
    df = pd.read_csv(f"../workflows/{ec_num}/csv/{ec_num}_uniprot.csv")

    unfiltered_seqs = readFastaFile(f"../workflows/{ec_num}/files/{ec_num}.fasta")
  
    filtered_seqs = readFastaFile(f"../workflows/{ec_num}/files/{ec_num}_filt.fasta")
    
    filtered_names = [seq.name for seq in filtered_seqs]

    unfiltered_names = [seq.name for seq in unfiltered_seqs if seq.name not in filtered_names]

    filtered_df = df.loc[(df["Entry"].isin(filtered_names))]
  
    unfiltered_df = df.loc[df["Entry"].isin(unfiltered_names)]
  
    pos_column_counts = {}

    for col in filtered_df.columns:
        #record how many unique values there are 
        unique = len(filtered_df[col].unique())
        pos_column_counts[col] = unique 

    neg_column_counts = {}

    for col in unfiltered_df.columns:
        #record how many unique values there are 
        unique = len(unfiltered_df[col].unique())
    
        neg_column_counts[col] = unique 

    return pos_column_counts, neg_column_counts

# %% [markdown]
# # Columns with 1 entry

# %%
entries = {}

for ec in ec_nums:
    pos_column_counts, neg_column_counts = load_seqs(ec)

    for (k1, v1), (k2, v2) in zip(neg_column_counts.items(), pos_column_counts.items()):
        if v2 == 1 and v1 > 1:
            if entries.get(k2) is None:
                entries[k2] = v2
            else:
                entries[k2] += 1

    
ordered = sorted(entries.items(), key = lambda x: x[1], reverse=True)
# Out:
# BRENDA_REFERENCES_102
# BRENDA_REFERENCES_102_PUBMED
# BRENDA_KM_p_nitrophenyl_beta_D_cellopentaoside_DATA
# BRENDA_KM_p_nitrophenyl_beta_D_cellopentaoside_UNITS
# BRENDA_KM_p_nitrophenyl_beta_D_cellopentaoside_REFS
# BRENDA_KM_p_nitrophenyl_beta_D_cellotetraoside_DATA
# BRENDA_KM_p_nitrophenyl_beta_D_cellotetraoside_UNITS
# BRENDA_KM_p_nitrophenyl_beta_D_cellotetraoside_REFS
# BRENDA_REFERENCES_33
# BRENDA_REFERENCES_72
# BRENDA_SU_DATA
# BRENDA_SU_REFS
# BRENDA_SU_COMMENT
# BRENDA_KM_2,4_dinitrophenyl_beta_D_cellobioside_DATA
# BRENDA_KM_2,4_dinitrophenyl_beta_D_cellobioside_UNITS
# BRENDA_KM_2,4_dinitrophenyl_beta_D_cellobioside_REFS
# BRENDA_KM_2,4_dinitrophenyl_beta_D_cellobioside_COMMENT
# BRENDA_TN_2,4_dinitrophenyl_beta_D_cellobioside_DATA
# BRENDA_TN_2,4_dinitrophenyl_beta_D_cellobioside_UNITS
# BRENDA_TN_2,4_dinitrophenyl_beta_D_cellobioside_REFS
# BRENDA_TN_2,4_dinitrophenyl_beta_D_cellobioside_COMMENT
# BRENDA_SS_DATA
# BRENDA_SS_REFS
# BRENDA_REFERENCES_53
# BRENDA_REFERENCES_94
# BRENDA_REFERENCES_94_PUBMED
# BRENDA_REFERENCES_389
# BRENDA_IC50_DATA
# BRENDA_IC50_UNITS
# BRENDA_IC50_REFS
# BRENDA_IC50_COMMENT
# BRENDA_IC50_sodium_hypochlorite_DATA
# BRENDA_IC50
# BRENDA_IC50_sodium_hypochlorite_UNITS
# BRENDA_IC50_sodium_hypochlorite_REFS
# BRENDA_REFERENCES_227
# BRENDA_REFERENCES_227_PUBMED
# BRENDA_KM_4_nitrophenyl_D_cellobioside_DATA
# BRENDA_KM_4_nitrophenyl_D_cellobioside_UNITS
# BRENDA_KM_4_nitrophenyl_D_cellobioside_REFS
# BRENDA_KM_4_nitrophenyl_D_cellobioside_COMMENT
# BRENDA_TN_4_nitrophenyl_D_cellobioside_DATA
# BRENDA_TN_4_nitrophenyl_D_cellobioside_UNITS
# BRENDA_TN_4_nitrophenyl_D_cellobioside_REFS
# BRENDA_TN_4_nitrophenyl_D_cellobioside_COMMENT
# BRENDA_TN_carboxymethyl_cellulose_DATA
# BRENDA_TN_carboxymethyl_cellulose_UNITS
# BRENDA_TN_carboxymethyl_cellulose_REFS
# BRENDA_TN_carboxymethyl_cellulose_COMMENT
# BRENDA_REFERENCES_106
# BRENDA_REFERENCES_106_PUBMED
# BRENDA_REFERENCES_140
# BRENDA_REFERENCES_140_PUBMED
# BRENDA_REFERENCES_255
# BRENDA_REFERENCES_255_PUBMED
# BRENDA_REFERENCES_268
# BRENDA_REFERENCES_268_PUBMED
# BRENDA_REFERENCES_277
# BRENDA_REFERENCES_277_PUBMED
# BRENDA_REFERENCES_306
# BRENDA_REFERENCES_306_PUBMED
# BRENDA_REFERENCES_329
# BRENDA_REFERENCES_329_PUBMED
# BRENDA_REFERENCES_359
# BRENDA_REFERENCES_396
# BRENDA_REFERENCES_396_PUBMED
# BRENDA_REFERENCES_424
# BRENDA_REFERENCES_424_PUBMED
# BRENDA_KM_p_nitrophenyl_cellobiose_DATA
# BRENDA_KM_p_nitrophenyl_cellobiose_UNITS
# BRENDA_KM_p_nitrophenyl_cellobiose_REFS
# BRENDA_KM_p_nitrophenyl_cellobiose_COMMENT
# BRENDA_TN_p_nitrophenyl_cellobiose_DATA
# BRENDA_TN_p_nitrophenyl_cellobiose_UNITS
# BRENDA_TN_p_nitrophenyl_cellobiose_REFS
# BRENDA_TN_p_nitrophenyl_cellobiose_COMMENT
# BRENDA_REFERENCES_315
# BRENDA_REFERENCES_315_PUBMED
# BRENDA_REFERENCES_174
# BRENDA_REFERENCES_174_PUBMED
# BRENDA_REFERENCES_340
# BRENDA_REFERENCES_340_PUBMED
# BRENDA_TN_Barley_beta_glucan_DATA
# BRENDA_TN_Barley_beta_glucan_UNITS
# BRENDA_TN_Barley_beta_glucan_REFS
# BRENDA_TN_Barley_beta_glucan_COMMENT
# BRENDA_EXP_DATA
# BRENDA_EXP_REFS
# BRENDA_EXP_COMMENT
# BRENDA_TN_Avicel_DATA
# BRENDA_TN_Avicel_UNITS
# BRENDA_TN_Avicel_REFS
# BRENDA_TN_Avicel_COMMENT
# BRENDA_KM_4_methylumbelliferyl_cellobioside_DATA
# BRENDA_KM_4_methylumbelliferyl_cellobioside_UNITS
# BRENDA_KM_4_methylumbelliferyl_cellobioside_REFS
# BRENDA_KM_4_methylumbelliferyl_cellobioside_COMMENT
# BRENDA_TN_4_methylumbelliferyl_cellobioside_DATA
# BRENDA_TN_4_methylumbelliferyl_cellobioside_UNITS
# BRENDA_TN_4_methylumbelliferyl_cellobioside_REFS
# BRENDA_TN_4_methylumbelliferyl_cellobioside_COMMENT
# BRENDA_REFERENCES_294
# BRENDA_REFERENCES_294_PUBMED
# BRENDA_TN_carboxymethylcellulose_DATA
# BRENDA_TN_carboxymethylcellulose_UNITS
# BRENDA_TN_carboxymethylcellulose_REFS
# BRENDA_TN_carboxymethylcellulose_COMMENT
# BRENDA_KM_Cellopentaose_DATA
# BRENDA_KM_Cellopentaose_UNITS
# BRENDA_KM_Cellopentaose_REFS
# BRENDA_KM_Cellopentaose_COMMENT
# BRENDA_KM_Barley_beta_glucan_DATA
# BRENDA_KM_Barley_beta_glucan_UNITS
# BRENDA_KM_Barley_beta_glucan_REFS
# BRENDA_KM_Barley_beta_glucan_COMMENT
# BRENDA_KM_cellotriose_DATA
# BRENDA_KM_cellotriose_UNITS
# BRENDA_KM_cellotriose_REFS
# BRENDA_KM_cellotriose_COMMENT
# BRENDA_KM_Cellotetraose_DATA
# BRENDA_KM_Cellotetraose_UNITS
# BRENDA_KM_Cellotetraose_REFS
# BRENDA_KM_Cellotetraose_COMMENT
# BRENDA_KM_carboxymethyl_cellulose_DATA
# BRENDA_KM_carboxymethyl_cellulose_UNITS
# BRENDA_KM_carboxymethyl_cellulose_REFS
# BRENDA_KM_carboxymethyl_cellulose_COMMENT
# BRENDA_KM_hydroxyethylcellulose_DATA
# BRENDA_KM_hydroxyethylcellulose_UNITS
# BRENDA_KM_hydroxyethylcellulose_REFS
# BRENDA_KM_hydroxyethylcellulose_COMMENT
# BRENDA_KM_Laminarin_DATA
# BRENDA_KM_Laminarin_UNITS
# BRENDA_KM_Laminarin_REFS
# BRENDA_KM_Laminarin_COMMENT
# BRENDA_KM_cellohexaose_DATA
# BRENDA_KM_cellohexaose_UNITS
# BRENDA_KM_cellohexaose_REFS
# BRENDA_KM_cellohexaose_COMMENT
# BRENDA_TN_Laminarin_DATA
# BRENDA_TN_Laminarin_UNITS
# BRENDA_TN_Laminarin_REFS
# BRENDA_TN_Laminarin_COMMENT
# BRENDA_TN_Cellotetraose_DATA
# BRENDA_TN_Cellotetraose_UNITS
# BRENDA_TN_Cellotetraose_REFS
# BRENDA_TN_Cellotetraose_COMMENT
# BRENDA_TN_hydroxyethylcellulose_DATA
# BRENDA_TN_hydroxyethylcellulose_UNITS
# BRENDA_TN_hydroxyethylcellulose_REFS
# BRENDA_TN_hydroxyethylcellulose_COMMENT
# BRENDA_TN_cellohexaose_DATA
# BRENDA_TN_cellohexaose_UNITS
# BRENDA_TN_cellohexaose_REFS
# BRENDA_TN_cellohexaose_COMMENT
# BRENDA_TN_Cellopentaose_DATA
# BRENDA_TN_Cellopentaose_UNITS
# BRENDA_TN_Cellopentaose_REFS
# BRENDA_TN_Cellopentaose_COMMENT
# BRENDA_TN_cellotriose_DATA
# BRENDA_TN_cellotriose_UNITS
# BRENDA_TN_cellotriose_REFS
# BRENDA_TN_cellotriose_COMMENT
# BRENDA_REFERENCES_387
# BRENDA_REFERENCES_387_PUBMED
# BRENDA_TN_raffinose_DATA
# BRENDA_TN_raffinose_UNITS
# BRENDA_TN_raffinose_REFS
# BRENDA_TN_raffinose_COMMENT
# BRENDA_TN_cellobiose_DATA
# BRENDA_TN_cellobiose_UNITS
# BRENDA_TN_cellobiose_REFS
# BRENDA_TN_cellobiose_COMMENT
# Virus_hosts
# Fragment
# Gene_encoded_by
# Alternative_products_isoforms
# Erroneous_gene_model_prediction
# Erroneous_initiation
# Erroneous_termination
# Erroneous_translation
# Frameshift
# Mass_spectrometry
# Polymorphism
# RNA_editing
# Sequence_caution
# Alternative_sequence
# Natural_variant
# Non_adjacent_residues
# Non_standard_residue
# Non_terminal_residue
# Sequence_conflict
# Sequence_uncertainty
# Version_sequence
# Absorption
# Catalytic_activity
# ChEBI
# ChEBI_Catalytic_activity
# ChEBI_Cofactor
# ChEBI_IDs
# Cofactor
# Function_[CC]
# Kinetics
# Pathway
# Redox_potential
# Temperature_dependence
# pH_dependence
# Active_site
# DNA_binding
# Nucleotide_binding
# Site
# Caution
# Miscellaneous_[CC]
# Status
# Subunit_structure_[CC]
# Interacts_with
# Developmental_stage
# Induction
# Tissue_specificity
# Allergenic_properties
# Biotechnological_use
# Disruption_phenotype
# Involvement_in_disease
# Pharmaceutical_use
# Toxic_dose
# Subcellular_location_[CC]
# Intramembrane
# Topological_domain
# Post_translational_modification
# Cross_link
# Initiator_methionine
# Lipidation
# Peptide
# Propeptide
# Transit_peptide
# Beta_strand
# Helix
# Turn
# Mapped_PubMed_ID
# Domain_[CC]
# Coiled_coil
# Compositional_bias
# Motif
# Repeat
# Zinc_finger
# Taxonomic_lineage_SUPERPHYLUM
# Taxonomic_lineage_SUPERCLASS
# Taxonomic_lineage_INFRACLASS
# Taxonomic_lineage_SUPERORDER
# Taxonomic_lineage_SUBORDER
# Taxonomic_lineage_INFRAORDER
# Taxonomic_lineage_PARVORDER
# Taxonomic_lineage_SUPERFAMILY
# Taxonomic_lineage_SUBFAMILY
# Taxonomic_lineage_TRIBE
# Taxonomic_lineage_SUBTRIBE
# Taxonomic_lineage_SPECIES_GROUP
# Taxonomic_lineage_SPECIES_SUBGROUP
# Taxonomic_lineage_SUBSPECIES
# Taxonomic_lineage_VARIETAS
# Taxonomic_lineage_FORMA
# Cross_reference_ABCD
# Cross_reference_Allergome
# Cross_reference_Antibodypedia
# Cross_reference_ArachnoServer
# Cross_reference_Araport
# Cross_reference_Bgee
# Cross_reference_BindingDB
# Cross_reference_BioCyc
# Cross_reference_BioGRID
# Cross_reference_BioGRID_ORCS
# Cross_reference_BioMuta
# Cross_reference_BMRB
# Cross_reference_CarbonylDB
# Cross_reference_CCDS
# Cross_reference_CGD
# Cross_reference_ChEMBL
# Cross_reference_ChiTaRS
# Cross_reference_CollecTF
# Cross_reference_ComplexPortal
# Cross_reference_COMPLUYEAST_2DPAGE
# Cross_reference_ConoServer
# Cross_reference_CORUM
# Cross_reference_CPTAC
# Cross_reference_CPTC
# Cross_reference_CTD
# Cross_reference_dbSNP
# Cross_reference_DDBJ
# Cross_reference_DEPOD
# Cross_reference_dictyBase
# Cross_reference_DIP
# Cross_reference_DisGeNET
# Cross_reference_DisProt
# Cross_reference_DMDM
# Cross_reference_DNASU
# Cross_reference_DOSAC_COBS_2DPAGE
# Cross_reference_DrugBank
# Cross_reference_DrugCentral
# Cross_reference_EchoBASE
# Cross_reference_ELM
# Ensembl_transcript
# EnsemblMetazoa_transcript
# EnsemblPlants_transcript
# EnsemblProtists_transcript
# Cross_reference_ENZYME
# Cross_reference_EPD
# Cross_reference_ESTHER
# Cross_reference_euHCVdb
# Cross_reference_ExpressionAtlas
# Cross_reference_FlyBase
# Cross_reference_GenAtlas
# Cross_reference_GenBank
# Cross_reference_GeneCards
# Cross_reference_GeneDB
# Cross_reference_GeneReviews
# Cross_reference_GeneTree
# Cross_reference_Genevisible
# Cross_reference_GeneWiki
# Cross_reference_GenomeRNAi
# Cross_reference_GlyConnect
# Cross_reference_GlyGen
# Cross_reference_GO
# Cross_reference_GPCRDB
# Cross_reference_Gramene
# Cross_reference_GuidetoPHARMACOLOGY
# Cross_reference_HAMAP
# Cross_reference_HGNC
# Cross_reference_HPA
# Cross_reference_HUGE
# Cross_reference_IDEAL
# Cross_reference_IMGT_GENE_DB
# Cross_reference_IntAct
# Cross_reference_iPTMnet
# Cross_reference_jPOST
# Cross_reference_LegioList
# Cross_reference_Leproma
# Cross_reference_MaizeGDB
# Cross_reference_MalaCards
# Cross_reference_MassIVE
# Cross_reference_MaxQB
# Cross_reference_MEROPS
# Cross_reference_MetOSite
# Cross_reference_MGI
# Cross_reference_Micado
# Cross_reference_MIM
# Cross_reference_MINT
# Cross_reference_MobiDB
# Cross_reference_ModBase
# Cross_reference_MoonDB
# Cross_reference_MoonProt
# Cross_reference_neXtProt
# Cross_reference_NIAGADS
# Cross_reference_OGP
# Cross_reference_OpenTargets
# Cross_reference_Orphanet
# Cross_reference_PathwayCommons
# Cross_reference_PaxDb
# Cross_reference_PCDDB
# Cross_reference_PDBe_KB
# Cross_reference_PDBj
# Cross_reference_PeptideAtlas
# Cross_reference_PeroxiBase
# Cross_reference_PharmGKB
# Cross_reference_Pharos
# Cross_reference_PHI_base
# Cross_reference_PhosphoSitePlus
# Cross_reference_PhylomeDB
# Cross_reference_PIRSF
# Cross_reference_PlantReactome
# Cross_reference_PomBase
# Cross_reference_PRIDE
# Cross_reference_PRO
# Cross_reference_ProMEX
# Cross_reference_Proteomes
# Cross_reference_ProteomicsDB
# Cross_reference_ProtoNet
# Cross_reference_PseudoCAP
# Cross_reference_RCSB_PDB
# Cross_reference_Reactome
# Cross_reference_REBASE
# Cross_reference_REPRODUCTION_2DPAGE
# Cross_reference_RGD
# Cross_reference_RNAct
# Cross_reference_Rouge
# Cross_reference_SABIO_RK
# Cross_reference_SASBDB
# Cross_reference_SFLD
# Cross_reference_SGD
# Cross_reference_SignaLink
# Cross_reference_SIGNOR
# Cross_reference_SOURCE
# Cross_reference_SWISS_2DPAGE
# Cross_reference_SWISS_MODEL_Workspace
# Cross_reference_SwissLipids
# Cross_reference_SwissPalm
# Cross_reference_TAIR
# Cross_reference_TCDB
# Cross_reference_TIGRFAMs
# Cross_reference_TopDownProteomics
# Cross_reference_TreeFam
# Cross_reference_TubercuList
# Cross_reference_UCD_2DPAGE
# Cross_reference_UCSC
# Cross_reference_UniLectin
# Cross_reference_UniPathway
# Cross_reference_VGNC
# Cross_reference_WBParaSite
# Cross_reference_World_2DPAGE
# Cross_reference_WormBase
# Cross_reference_Xenbase
# Cross_reference_ZFIN
# BRENDA_REFERENCES_270
# BRENDA_REFERENCES_270_PUBMED
# BRENDA_REFERENCES_161
# BRENDA_REFERENCES_161_PUBMED
# BRENDA_REFERENCES_169
# BRENDA_REFERENCES_169_PUBMED
# BRENDA_REFERENCES_247
# BRENDA_REFERENCES_247_PUBMED
# BRENDA_REFERENCES_259
# BRENDA_REFERENCES_259_PUBMED
# BRENDA_REFERENCES_262
# BRENDA_REFERENCES_262_PUBMED
# BRENDA_TN_4_methylumbelliferyl_N,N'_diacetylchitobiose_DATA
# BRENDA_TN_4_methylumbelliferyl_N,N'_diacetylchitobiose_UNITS
# BRENDA_TN_4_methylumbelliferyl_N,N'_diacetylchitobiose_REFS
# BRENDA_TN_4_methylumbelliferyl_N,N'_diacetylchitobiose_COMMENT
# BRENDA_REFERENCES_190
# BRENDA_REFERENCES_190_PUBMED
# BRENDA_KM_4_methylumbelliferyl_beta_D_N,N',N''_triacetylchitotriose_DATA
# BRENDA_KM
# BRENDA_KM_4_methylumbelliferyl_beta_D_N,N',N''_triacetylchitotriose_UNITS
# BRENDA_KM_4_methylumbelliferyl_beta_D_N,N',N''_triacetylchitotriose_REFS
# BRENDA_REFERENCES_18
# BRENDA_REFERENCES_334
# BRENDA_REFERENCES_334_PUBMED
# BRENDA_REFERENCES_87
# BRENDA_REFERENCES_87_PUBMED
# BRENDA_TN_beta_chitin_DATA
# BRENDA_TN_beta_chitin_UNITS
# BRENDA_TN_beta_chitin_REFS
# BRENDA_TN_beta_chitin_COMMENT
# BRENDA_REFERENCES_107
# BRENDA_REFERENCES_107_PUBMED
# BRENDA_REFERENCES_181
# BRENDA_REFERENCES_181_PUBMED
# BRENDA_REFERENCES_278
# BRENDA_REFERENCES_278_PUBMED
# BRENDA_KM_4_nitrophenyl_2_acetylamino_4_O_[2_acetylamino_2_deoxy_beta_D_glucopyranosyl]_2_deoxy_beta_D_glucopyranoside_DATA
# BRENDA_KM_4_nitrophenyl_2_acetylamino_4_O_[2_acetylamino_2_deoxy_beta_D_glucopyranosyl]_2_deoxy_beta_D_glucopyranoside_UNITS
# BRENDA_KM_4_nitrophenyl_2_acetylamino_4_O_[2_acetylamino_2_deoxy_beta_D_glucopyranosyl]_2_deoxy_beta_D_glucopyranoside_REFS
# BRENDA_KM_4_nitrophenyl_2_acetylamino_4_O_[2_acetylamino_2_deoxy_beta_D_glucopyranosyl]_2_deoxy_beta_D_glucopyranoside_COMMENT
# BRENDA_TN_4_nitrophenyl_2_acetylamino_4_O_[2_acetylamino_2_deoxy_beta_D_glucopyranosyl]_2_deoxy_beta_D_glucopyranoside_DATA
# BRENDA_TN_4_nitrophenyl_2_acetylamino_4_O_[2_acetylamino_2_deoxy_beta_D_glucopyranosyl]_2_deoxy_beta_D_glucopyranoside_UNITS
# BRENDA_TN_4_nitrophenyl_2_acetylamino_4_O_[2_acetylamino_2_deoxy_beta_D_glucopyranosyl]_2_deoxy_beta_D_glucopyranoside_REFS
# BRENDA_TN_4_nitrophenyl_2_acetylamino_4_O_[2_acetylamino_2_deoxy_beta_D_glucopyranosyl]_2_deoxy_beta_D_glucopyranoside_COMMENT
# BRENDA_REFERENCES_139
# BRENDA_REFERENCES_139_PUBMED
# BRENDA_KKM_DATA
# BRENDA_KKM_UNITS
# BRENDA_KKM_REFS
# BRENDA_KKM_COMMENT
# BRENDA_KM_4_nitrophenyl_beta_N,N'_diacetylchitobioside_DATA
# BRENDA_KM_4_nitrophenyl_beta_N,N'_diacetylchitobioside_UNITS
# BRENDA_KM_4_nitrophenyl_beta_N,N'_diacetylchitobioside_REFS
# BRENDA_KM_4_nitrophenyl_beta_N,N'_diacetylchitobioside_COMMENT
# BRENDA_TN_4_nitrophenyl_beta_N,N'_diacetylchitobioside_DATA
# BRENDA_TN_4_nitrophenyl_beta_N,N'_diacetylchitobioside_UNITS
# BRENDA_TN_4_nitrophenyl_beta_N,N'_diacetylchitobioside_REFS
# BRENDA_TN_4_nitrophenyl_beta_N,N'_diacetylchitobioside_COMMENT
# BRENDA_KM_4_methylumbelliferyl_beta_N,N',N''_triacetylchitotrioside_DATA
# BRENDA_KM_4_methylumbelliferyl_beta_N,N',N''_triacetylchitotrioside_UNITS
# BRENDA_KM_4_methylumbelliferyl_beta_N,N',N''_triacetylchitotrioside_REFS
# BRENDA_KM_4_methylumbelliferyl_beta_N,N',N''_triacetylchitotrioside_COMMENT
# BRENDA_KM_4_methylumbelliferyl_beta_D_N,N',N''_triacetylchitotrioside_DATA
# BRENDA_KM_4_methylumbelliferyl_beta_D_N,N',N''_triacetylchitotrioside_UNITS
# BRENDA_KM_4_methylumbelliferyl_beta_D_N,N',N''_triacetylchitotrioside_REFS
# BRENDA_KM_4_methylumbelliferyl_beta_D_N,N',N''_triacetylchitotrioside_COMMENT
# BRENDA_TN_4_methylumbelliferyl_beta_D_N,N',N''_triacetylchitotrioside_DATA
# BRENDA_TN_4_methylumbelliferyl_beta_D_N,N',N''_triacetylchitotrioside_UNITS
# BRENDA_TN_4_methylumbelliferyl_beta_D_N,N',N''_triacetylchitotrioside_REFS
# BRENDA_TN_4_methylumbelliferyl_beta_D_N,N',N''_triacetylchitotrioside_COMMENT
# BRENDA_KM_4_nitrophenyl_beta_1,4_N,N'_diacetyl_chitobiose_DATA
# BRENDA_KM_4_nitrophenyl_beta_1,4_N,N'_diacetyl_chitobiose_UNITS
# BRENDA_KM_4_nitrophenyl_beta_1,4_N,N'_diacetyl_chitobiose_REFS
# BRENDA_KM_4_nitrophenyl_beta_1,4_N,N'_diacetyl_chitobiose_COMMENT
# BRENDA_TN_4_nitrophenyl_beta_1,4_N,N'_diacetyl_chitobiose_DATA
# BRENDA_TN_4_nitrophenyl_beta_1,4_N,N'_diacetyl_chitobiose_UNITS
# BRENDA_TN_4_nitrophenyl_beta_1,4_N,N'_diacetyl_chitobiose_REFS
# BRENDA_TN_4_nitrophenyl_beta_1,4_N,N'_diacetyl_chitobiose_COMMENT
# BRENDA_AC_DATA
# BRENDA_AC_REFS
# BRENDA_AC_COMMENT
# BRENDA_REFERENCES_176
# BRENDA_REFERENCES_176_PUBMED
# BRENDA_KM_colloidal_chitin_DATA
# BRENDA_KM_colloidal_chitin_UNITS
# BRENDA_KM_colloidal_chitin_REFS
# BRENDA_KM_colloidal_chitin_COMMENT
# BRENDA_KM_powdered_chitin_DATA
# BRENDA_KM_powdered_chitin_UNITS
# BRENDA_KM_powdered_chitin_REFS
# BRENDA_KM_powdered_chitin_COMMENT
# BRENDA_REFERENCES_242
# BRENDA_REFERENCES_242_PUBMED
# BRENDA_SS_DATA
# BRENDA_SS_REFS
# BRENDA_KM_4_methylumbelliferyl_chitobioside_DATA
# BRENDA_KM_4_methylumbelliferyl_chitobioside_UNITS
# BRENDA_KM_4_methylumbelliferyl_chitobioside_REFS
# BRENDA_KM_4_methylumbelliferyl_chitobioside_COMMENT
# BRENDA_TN_4_methylumbelliferyl_chitobioside_DATA
# BRENDA_TN_4_methylumbelliferyl_chitobioside_UNITS
# BRENDA_TN_4_methylumbelliferyl_chitobioside_REFS
# BRENDA_TN_4_methylumbelliferyl_chitobioside_COMMENT
# BRENDA_IC50_methylallosamidin_DATA
# BRENDA_IC50
# BRENDA_IC50_methylallosamidin_UNITS
# BRENDA_IC50_methylallosamidin_REFS
# BRENDA_IC50_methylallosamidin_COMMENT
# BRENDA_KM_4_methylumbelliferyl_beta_D_N,N',N''_triacetyl_chitotriose_DATA
# BRENDA_KM_4_methylumbelliferyl_beta_D_N,N',N''_triacetyl_chitotriose_UNITS
# BRENDA_KM_4_methylumbelliferyl_beta_D_N,N',N''_triacetyl_chitotriose_REFS
# BRENDA_KM_4_methylumbelliferyl_beta_D_N,N',N''_triacetyl_chitotriose_COMMENT
# BRENDA_IC50_allosamidin_DATA
# BRENDA_IC50_allosamidin_UNITS
# BRENDA_IC50_allosamidin_REFS
# BRENDA_IC50_allosamidin_COMMENT
# BRENDA_KM_4_methylumbelliferyl_beta_N,N'_diacetylchitobioside_DATA
# BRENDA_KM_4_methylumbelliferyl_beta_N,N'_diacetylchitobioside_UNITS
# BRENDA_KM_4_methylumbelliferyl_beta_N,N'_diacetylchitobioside_REFS
# BRENDA_KM_4_methylumbelliferyl_beta_N,N'_diacetylchitobioside_COMMENT
# BRENDA_KM_alpha_chitin_DATA
# BRENDA_KM_alpha_chitin_UNITS
# BRENDA_KM_alpha_chitin_REFS
# BRENDA_KM_alpha_chitin_COMMENT
# BRENDA_KM_DATA
# BRENDA_KM_UNITS
# BRENDA_KM_REFS
# BRENDA_KM_COMMENT
# BRENDA_KI_4_nitrophenyl_N,N'_diacetylchitobiose_DATA
# BRENDA_KI
# BRENDA_KI_4_nitrophenyl_N,N'_diacetylchitobiose_UNITS
# BRENDA_KI_4_nitrophenyl_N,N'_diacetylchitobiose_REFS
# BRENDA_KI_4_nitrophenyl_N,N'_diacetylchitobiose_COMMENT
# BRENDA_KM_4_nitrophenyl_N,N'_diacetylchitobiose_DATA
# BRENDA_KM_4_nitrophenyl_N,N'_diacetylchitobiose_UNITS
# BRENDA_KM_4_nitrophenyl_N,N'_diacetylchitobiose_REFS
# BRENDA_KM_4_nitrophenyl_N,N'_diacetylchitobiose_COMMENT
# BRENDA_TN_4_nitrophenyl_N,N'_diacetylchitobiose_DATA
# BRENDA_TN_4_nitrophenyl_N,N'_diacetylchitobiose_UNITS
# BRENDA_TN_4_nitrophenyl_N,N'_diacetylchitobiose_REFS
# BRENDA_TN_4_nitrophenyl_N,N'_diacetylchitobiose_COMMENT
# BRENDA_KM_4_nitrophenyl_N,N'_diacetyl_beta_D_chitobioside_DATA
# BRENDA_KM_4_nitrophenyl_N,N'_diacetyl_beta_D_chitobioside_UNITS
# BRENDA_KM_4_nitrophenyl_N,N'_diacetyl_beta_D_chitobioside_REFS
# BRENDA_KM_4_nitrophenyl_N,N'_diacetyl_beta_D_chitobioside_COMMENT
# BRENDA_TN_colloidal_chitin_DATA
# BRENDA_TN_colloidal_chitin_UNITS
# BRENDA_TN_colloidal_chitin_REFS
# BRENDA_TN_colloidal_chitin_COMMENT
# Virus_hosts
# Gene_encoded_by
# Alternative_products_isoforms
# Erroneous_gene_model_prediction
# Erroneous_initiation
# Erroneous_termination
# Erroneous_translation
# Frameshift
# Polymorphism
# RNA_editing
# Sequence_caution
# Alternative_sequence
# Non_standard_residue
# Sequence_uncertainty
# Absorption
# ChEBI
# ChEBI_Catalytic_activity
# ChEBI_Cofactor
# ChEBI_IDs
# Cofactor
# Pathway
# Redox_potential
# Binding_site
# DNA_binding
# Metal_binding
# Nucleotide_binding
# Site
# Subunit_structure_[CC]
# Interacts_with
# Biotechnological_use
# Disruption_phenotype
# Involvement_in_disease
# Pharmaceutical_use
# Toxic_dose
# Intramembrane
# Topological_domain
# Transmembrane
# Post_translational_modification
# Cross_link
# Glycosylation
# Initiator_methionine
# Lipidation
# Modified_residue
# Peptide
# Propeptide
# Transit_peptide
# Coiled_coil
# Motif
# Repeat
# Zinc_finger
# Taxonomic_lineage_SUBKINGDOM
# Taxonomic_lineage_SUPERPHYLUM
# Taxonomic_lineage_SUPERCLASS
# Taxonomic_lineage_INFRACLASS
# Taxonomic_lineage_SUPERORDER
# Taxonomic_lineage_INFRAORDER
# Taxonomic_lineage_PARVORDER
# Taxonomic_lineage_SUPERFAMILY
# Taxonomic_lineage_SUBGENUS
# Taxonomic_lineage_SPECIES_GROUP
# Taxonomic_lineage_SPECIES_SUBGROUP
# Taxonomic_lineage_SUBSPECIES
# Taxonomic_lineage_VARIETAS
# Taxonomic_lineage_FORMA
# Cross_reference_ABCD
# Cross_reference_Antibodypedia
# Cross_reference_ArachnoServer
# Cross_reference_Araport
# Cross_reference_Bgee
# Cross_reference_BindingDB
# Cross_reference_BioCyc
# Cross_reference_BioGRID
# Cross_reference_BioGRID_ORCS
# Cross_reference_BioMuta
# Cross_reference_BMRB
# Cross_reference_CarbonylDB
# Cross_reference_CCDS
# Cross_reference_CDD
# Cross_reference_CGD
# Cross_reference_ChEMBL
# Cross_reference_ChiTaRS
# Cross_reference_CLAE
# Cross_reference_CollecTF
# Cross_reference_ComplexPortal
# Cross_reference_COMPLUYEAST_2DPAGE
# Cross_reference_ConoServer
# Cross_reference_CORUM
# Cross_reference_CPTAC
# Cross_reference_CPTC
# Cross_reference_CTD
# Cross_reference_dbSNP
# Cross_reference_DDBJ
# Cross_reference_DEPOD
# Cross_reference_dictyBase
# Cross_reference_DIP
# Cross_reference_DisGeNET
# Cross_reference_DisProt
# Cross_reference_DMDM
# Cross_reference_DNASU
# Cross_reference_DOSAC_COBS_2DPAGE
# Cross_reference_DrugBank
# Cross_reference_DrugCentral
# Cross_reference_EchoBASE
# Cross_reference_ELM
# Ensembl_transcript
# EnsemblBacteria_transcript
# EnsemblFungi_transcript
# EnsemblMetazoa_transcript
# EnsemblProtists_transcript
# Cross_reference_ENZYME
# Cross_reference_EPD
# Cross_reference_ESTHER
# Cross_reference_euHCVdb
# Cross_reference_FlyBase
# Cross_reference_GenAtlas
# Cross_reference_GenBank
# Cross_reference_GeneCards
# Cross_reference_GeneDB
# Cross_reference_GeneReviews
# Cross_reference_GeneTree
# Cross_reference_GeneWiki
# Cross_reference_GenomeRNAi
# Cross_reference_GlyConnect
# Cross_reference_GlyGen
# Cross_reference_GO
# Cross_reference_GPCRDB
# Cross_reference_GuidetoPHARMACOLOGY
# Cross_reference_HAMAP
# Cross_reference_HGNC
# Cross_reference_HPA
# Cross_reference_HUGE
# Cross_reference_IDEAL
# Cross_reference_IMGT_GENE_DB
# Cross_reference_IntAct
# Cross_reference_iPTMnet
# Cross_reference_jPOST
# Cross_reference_LegioList
# Cross_reference_Leproma
# Cross_reference_MalaCards
# Cross_reference_MassIVE
# Cross_reference_MaxQB
# Cross_reference_MEROPS
# Cross_reference_MetOSite
# Cross_reference_MGI
# Cross_reference_Micado
# Cross_reference_MIM
# Cross_reference_MINT
# Cross_reference_MobiDB
# Cross_reference_ModBase
# Cross_reference_MoonDB
# Cross_reference_MoonProt
# Cross_reference_neXtProt
# Cross_reference_NIAGADS
# Cross_reference_OGP
# Cross_reference_OpenTargets
# Cross_reference_Orphanet
# Cross_reference_PANTHER
# Cross_reference_PathwayCommons
# Cross_reference_PATRIC
# Cross_reference_PCDDB
# Cross_reference_PDBe_KB
# Cross_reference_PDBj
# Cross_reference_PeptideAtlas
# Cross_reference_PeroxiBase
# Cross_reference_PharmGKB
# Cross_reference_Pharos
# Cross_reference_PHI_base
# Cross_reference_PhosphoSitePlus
# Cross_reference_PhylomeDB
# Cross_reference_PlantReactome
# Cross_reference_PomBase
# Cross_reference_PRO
# Cross_reference_ProMEX
# Cross_reference_Proteomes
# Cross_reference_ProteomicsDB
# Cross_reference_ProtoNet
# Cross_reference_PseudoCAP
# Cross_reference_RCSB_PDB
# Cross_reference_Reactome
# Cross_reference_REBASE
# Cross_reference_REPRODUCTION_2DPAGE
# Cross_reference_RGD
# Cross_reference_RNAct
# Cross_reference_Rouge
# Cross_reference_SABIO_RK
# Cross_reference_SASBDB
# Cross_reference_SFLD
# Cross_reference_SGD
# Cross_reference_SignaLink
# Cross_reference_SIGNOR
# Cross_reference_SOURCE
# Cross_reference_SWISS_2DPAGE
# Cross_reference_SWISS_MODEL_Workspace
# Cross_reference_SwissLipids
# Cross_reference_SwissPalm
# Cross_reference_TAIR
# Cross_reference_TCDB
# Cross_reference_TIGRFAMs
# Cross_reference_TopDownProteomics
# Cross_reference_TreeFam
# Cross_reference_TubercuList
# Cross_reference_UCD_2DPAGE
# Cross_reference_UCSC
# Cross_reference_UniLectin
# Cross_reference_UniPathway
# Cross_reference_VEuPathDB
# Cross_reference_VGNC
# Cross_reference_WBParaSite
# Cross_reference_World_2DPAGE
# Cross_reference_WormBase
# Cross_reference_Xenbase
# Cross_reference_ZFIN
# BRENDA_REFERENCES_4
# BRENDA_REFERENCES_4_PUBMED
# BRENDA_REFERENCES_69
# BRENDA_REFERENCES_69_PUBMED
# Virus_hosts
# Alternative_products_isoforms
# Erroneous_gene_model_prediction
# Erroneous_termination
# Mass_spectrometry
# Polymorphism
# RNA_editing
# Non_adjacent_residues
# Non_standard_residue
# Sequence_uncertainty
# Absorption
# Pathway
# Redox_potential
# Temperature_dependence
# pH_dependence
# Active_site
# DNA_binding
# Allergenic_properties
# Biotechnological_use
# Pharmaceutical_use
# Toxic_dose
# Intramembrane
# Disulfide_bond
# Peptide
# Signal_peptide
# Transit_peptide
# Repeat
# Zinc_finger
# Taxonomic_lineage_SUPERPHYLUM
# Taxonomic_lineage_VARIETAS
# Taxonomic_lineage_FORMA
# Cross_reference_Allergome
# Cross_reference_ArachnoServer
# Cross_reference_BRENDA
# Cross_reference_CAZy
# Cross_reference_CLAE
# Cross_reference_CollecTF
# Cross_reference_COMPLUYEAST_2DPAGE
# Cross_reference_ConoServer
# Cross_reference_DDBJ
# Cross_reference_DEPOD
# Cross_reference_dictyBase
# Cross_reference_DOSAC_COBS_2DPAGE
# EnsemblProtists_transcript
# Cross_reference_ENZYME
# Cross_reference_ESTHER
# Cross_reference_euHCVdb
# Cross_reference_GenAtlas
# Cross_reference_GenBank
# Cross_reference_GeneDB
# Cross_reference_GlyConnect
# Cross_reference_GO
# Cross_reference_GPCRDB
# Cross_reference_HUGE
# Cross_reference_IMGT_GENE_DB
# Cross_reference_LegioList
# Cross_reference_Leproma
# Cross_reference_MaizeGDB
# Cross_reference_MEROPS
# Cross_reference_Micado
# Cross_reference_MobiDB
# Cross_reference_ModBase
# Cross_reference_MoonProt
# Cross_reference_NIAGADS
# Cross_reference_OGP
# Cross_reference_PCDDB
# Cross_reference_PDBe_KB
# Cross_reference_PDBj
# Cross_reference_PeroxiBase
# Cross_reference_ProMEX
# Cross_reference_Proteomes
# Cross_reference_ProtoNet
# Cross_reference_PseudoCAP
# Cross_reference_RCSB_PDB
# Cross_reference_REBASE
# Cross_reference_REPRODUCTION_2DPAGE
# Cross_reference_RGD
# Cross_reference_Rouge
# Cross_reference_SASBDB
# Cross_reference_SFLD
# Cross_reference_SGD
# Cross_reference_SMART
# Cross_reference_SOURCE
# Cross_reference_SUPFAM
# Cross_reference_SWISS_2DPAGE
# Cross_reference_SWISS_MODEL_Workspace
# Cross_reference_SwissLipids
# Cross_reference_TubercuList
# Cross_reference_UCD_2DPAGE
# Cross_reference_UniLectin
# Cross_reference_UniPathway
# Cross_reference_VGNC
# Cross_reference_WBParaSite
# Cross_reference_World_2DPAGE
# Cross_reference_WormBase
# Cross_reference_Xenbase
# Cross_reference_ZFIN
# Virus_hosts
# Fragment
# Gene_encoded_by
# Alternative_products_isoforms
# Erroneous_termination
# Erroneous_translation
# Mass_spectrometry
# RNA_editing
# Non_adjacent_residues
# Non_standard_residue
# Non_terminal_residue
# Sequence_uncertainty
# Absorption
# Pathway
# Redox_potential
# Temperature_dependence
# pH_dependence
# DNA_binding
# Allergenic_properties
# Biotechnological_use
# Pharmaceutical_use
# Toxic_dose
# Intramembrane
# Topological_domain
# Transmembrane
# Disulfide_bond
# Glycosylation
# Lipidation
# Peptide
# Propeptide
# Signal_peptide
# Transit_peptide
# Repeat
# Zinc_finger
# Taxonomic_lineage_SUPERKINGDOM
# Taxonomic_lineage_SUPERPHYLUM
# Taxonomic_lineage_VARIETAS
# Taxonomic_lineage_FORMA
# Cross_reference_ABCD
# Cross_reference_Allergome
# Cross_reference_ArachnoServer
# Cross_reference_BioCyc
# Cross_reference_BMRB
# Cross_reference_CAZy
# Cross_reference_CLAE
# Cross_reference_CollecTF
# Cross_reference_COMPLUYEAST_2DPAGE
# Cross_reference_ConoServer
# Cross_reference_DDBJ
# Cross_reference_DEPOD
# Cross_reference_DOSAC_COBS_2DPAGE
# Cross_reference_EchoBASE
# EnsemblBacteria_transcript
# Cross_reference_ENZYME
# Cross_reference_ESTHER
# Cross_reference_euHCVdb
# Cross_reference_GenAtlas
# Cross_reference_GenBank
# Cross_reference_Gene3D
# Cross_reference_GlyGen
# Cross_reference_GO
# Cross_reference_GPCRDB
# Cross_reference_HAMAP
# Cross_reference_HUGE
# Cross_reference_IMGT_GENE_DB
# Cross_reference_LegioList
# Cross_reference_Leproma
# Cross_reference_MEROPS
# Cross_reference_Micado
# Cross_reference_MobiDB
# Cross_reference_ModBase
# Cross_reference_MoonProt
# Cross_reference_NIAGADS
# Cross_reference_OGP
# Cross_reference_PATRIC
# Cross_reference_PCDDB
# Cross_reference_PDBe_KB
# Cross_reference_PDBj
# Cross_reference_PeroxiBase
# Cross_reference_PHI_base
# Cross_reference_PIRSF
# Cross_reference_PlantReactome
# Cross_reference_PRINTS
# Cross_reference_ProMEX
# Cross_reference_Proteomes
# Cross_reference_ProtoNet
# Cross_reference_PseudoCAP
# Cross_reference_RCSB_PDB
# Cross_reference_REBASE
# Cross_reference_REPRODUCTION_2DPAGE
# Cross_reference_Rouge
# Cross_reference_SASBDB
# Cross_reference_SFLD
# Cross_reference_SOURCE
# Cross_reference_SUPFAM
# Cross_reference_SWISS_MODEL_Workspace
# Cross_reference_SwissLipids
# Cross_reference_TIGRFAMs
# Cross_reference_TopDownProteomics
# Cross_reference_TubercuList
# Cross_reference_UCD_2DPAGE
# Cross_reference_UniLectin
# Cross_reference_UniPathway
# Cross_reference_WBParaSite
# Cross_reference_World_2DPAGE
# Cross_reference_ZFIN
# BRENDA_REFERENCES_69
# BRENDA_REFERENCES_69_PUBMED
# BRENDA_REFERENCES_52
# BRENDA_REFERENCES_52_PUBMED
# BRENDA_PM_DATA
# BRENDA_PM_REFS
# BRENDA_PM_COMMENT
# BRENDA_MW_DATA
# BRENDA_MW_REFS
# BRENDA_MW_COMMENT
# Virus_hosts
# Gene_encoded_by
# Alternative_products_isoforms
# Erroneous_gene_model_prediction
# Erroneous_initiation
# Erroneous_termination
# Erroneous_translation
# Frameshift
# Mass_spectrometry
# Polymorphism
# RNA_editing
# Sequence_caution
# Alternative_sequence
# Natural_variant
# Non_adjacent_residues
# Non_standard_residue
# Sequence_uncertainty
# Absorption
# Redox_potential
# Temperature_dependence
# pH_dependence
# Active_site
# DNA_binding
# Nucleotide_binding
# Caution
# Developmental_stage
# Induction
# Allergenic_properties
# Biotechnological_use
# Involvement_in_disease
# Pharmaceutical_use
# Toxic_dose
# Intramembrane
# Post_translational_modification
# Cross_link
# Disulfide_bond
# Initiator_methionine
# Lipidation
# Modified_residue
# Peptide
# Propeptide
# Signal_peptide
# Transit_peptide
# Protein_families
# Repeat
# Zinc_finger
# Taxonomic_lineage_SUPERPHYLUM
# Taxonomic_lineage_SUPERCLASS
# Taxonomic_lineage_SUBCLASS
# Taxonomic_lineage_INFRACLASS
# Taxonomic_lineage_SUPERORDER
# Taxonomic_lineage_SUBORDER
# Taxonomic_lineage_INFRAORDER
# Taxonomic_lineage_PARVORDER
# Taxonomic_lineage_SUPERFAMILY
# Taxonomic_lineage_SUBFAMILY
# Taxonomic_lineage_SUBTRIBE
# Taxonomic_lineage_SUBGENUS
# Taxonomic_lineage_SPECIES_GROUP
# Taxonomic_lineage_SPECIES_SUBGROUP
# Taxonomic_lineage_SUBSPECIES
# Taxonomic_lineage_VARIETAS
# Taxonomic_lineage_FORMA
# Cross_reference_ABCD
# Cross_reference_Allergome
# Cross_reference_Antibodypedia
# Cross_reference_ArachnoServer
# Cross_reference_Bgee
# Cross_reference_BindingDB
# Cross_reference_BioGRID_ORCS
# Cross_reference_BioMuta
# Cross_reference_CarbonylDB
# Cross_reference_CCDS
# Cross_reference_CDD
# Cross_reference_CGD
# Cross_reference_ChEMBL
# Cross_reference_ChiTaRS
# Cross_reference_CLAE
# Cross_reference_CollecTF
# Cross_reference_COMPLUYEAST_2DPAGE
# Cross_reference_ConoServer
# Cross_reference_CORUM
# Cross_reference_CPTAC
# Cross_reference_CPTC
# Cross_reference_CTD
# Cross_reference_dbSNP
# Cross_reference_DDBJ
# Cross_reference_DEPOD
# Cross_reference_dictyBase
# Cross_reference_DisGeNET
# Cross_reference_DMDM
# Cross_reference_DOSAC_COBS_2DPAGE
# Cross_reference_DrugBank
# Cross_reference_DrugCentral
# Cross_reference_EchoBASE
# Cross_reference_ELM
# Ensembl_transcript
# EnsemblMetazoa_transcript
# EnsemblProtists_transcript
# Cross_reference_ENZYME
# Cross_reference_EPD
# Cross_reference_ESTHER
# Cross_reference_euHCVdb
# Cross_reference_FlyBase
# Cross_reference_GenAtlas
# Cross_reference_GenBank
# Cross_reference_Gene3D
# Cross_reference_GeneCards
# Cross_reference_GeneDB
# Cross_reference_GeneReviews
# Cross_reference_GeneWiki
# Cross_reference_GenomeRNAi
# Cross_reference_GlyConnect
# Cross_reference_GlyGen
# Cross_reference_GO
# Cross_reference_GPCRDB
# Cross_reference_GuidetoPHARMACOLOGY
# Cross_reference_HAMAP
# Cross_reference_HGNC
# Cross_reference_HPA
# Cross_reference_HUGE
# Cross_reference_IDEAL
# Cross_reference_IMGT_GENE_DB
# Cross_reference_jPOST
# Cross_reference_LegioList
# Cross_reference_Leproma
# Cross_reference_MaizeGDB
# Cross_reference_MalaCards
# Cross_reference_MassIVE
# Cross_reference_MEROPS
# Cross_reference_MetOSite
# Cross_reference_MGI
# Cross_reference_Micado
# Cross_reference_MIM
# Cross_reference_MobiDB
# Cross_reference_ModBase
# Cross_reference_MoonDB
# Cross_reference_MoonProt
# Cross_reference_neXtProt
# Cross_reference_NIAGADS
# Cross_reference_OGP
# Cross_reference_OpenTargets
# Cross_reference_Orphanet
# Cross_reference_PANTHER
# Cross_reference_PathwayCommons
# Cross_reference_PCDDB
# Cross_reference_PDBe_KB
# Cross_reference_PDBj
# Cross_reference_PeptideAtlas
# Cross_reference_PeroxiBase
# Cross_reference_PharmGKB
# Cross_reference_Pharos
# Cross_reference_PHI_base
# Cross_reference_PhosphoSitePlus
# Cross_reference_PIRSF
# Cross_reference_PlantReactome
# Cross_reference_PomBase
# Cross_reference_PRINTS
# Cross_reference_ProMEX
# Cross_reference_PROSITE
# Cross_reference_Proteomes
# Cross_reference_ProtoNet
# Cross_reference_PseudoCAP
# Cross_reference_RCSB_PDB
# Cross_reference_Reactome
# Cross_reference_REBASE
# Cross_reference_REPRODUCTION_2DPAGE
# Cross_reference_RGD
# Cross_reference_Rouge
# Cross_reference_SABIO_RK
# Cross_reference_SASBDB
# Cross_reference_SFLD
# Cross_reference_SignaLink
# Cross_reference_SIGNOR
# Cross_reference_SMART
# Cross_reference_SOURCE
# Cross_reference_SUPFAM
# Cross_reference_SWISS_2DPAGE
# Cross_reference_SWISS_MODEL_Workspace
# Cross_reference_SwissLipids
# Cross_reference_TopDownProteomics
# Cross_reference_TreeFam
# Cross_reference_TubercuList
# Cross_reference_UCD_2DPAGE
# Cross_reference_UCSC
# Cross_reference_UniLectin
# Cross_reference_VGNC
# Cross_reference_WBParaSite
# Cross_reference_World_2DPAGE
# Cross_reference_WormBase
# Cross_reference_Xenbase
# Cross_reference_ZFIN
# Virus_hosts
# Fragment
# Gene_encoded_by
# Alternative_products_isoforms
# Erroneous_termination
# Erroneous_translation
# Polymorphism
# RNA_editing
# Non_adjacent_residues
# Non_standard_residue
# Non_terminal_residue
# Sequence_uncertainty
# Absorption
# ChEBI_Catalytic_activity
# Pathway
# Redox_potential
# Temperature_dependence
# pH_dependence
# Metal_binding
# Site
# Allergenic_properties
# Biotechnological_use
# Pharmaceutical_use
# Toxic_dose
# Intramembrane
# Topological_domain
# Transmembrane
# Disulfide_bond
# Glycosylation
# Peptide
# Propeptide
# Signal_peptide
# Transit_peptide
# Coiled_coil
# Repeat
# Zinc_finger
# Taxonomic_lineage_SUPERKINGDOM
# Taxonomic_lineage_SUPERPHYLUM
# Taxonomic_lineage_SUBTRIBE
# Taxonomic_lineage_SUBSPECIES
# Taxonomic_lineage_VARIETAS
# Taxonomic_lineage_FORMA
# Cross_reference_ABCD
# Cross_reference_Allergome
# Cross_reference_ArachnoServer
# Cross_reference_CAZy
# Cross_reference_CLAE
# Cross_reference_CollecTF
# Cross_reference_ComplexPortal
# Cross_reference_COMPLUYEAST_2DPAGE
# Cross_reference_ConoServer
# Cross_reference_DDBJ
# Cross_reference_DEPOD
# Cross_reference_DOSAC_COBS_2DPAGE
# Cross_reference_EchoBASE
# EnsemblBacteria_transcript
# Cross_reference_ENZYME
# Cross_reference_ESTHER
# Cross_reference_euHCVdb
# Cross_reference_GenAtlas
# Cross_reference_GenBank
# Cross_reference_Gene3D
# Cross_reference_GeneDB
# Cross_reference_GeneReviews
# Cross_reference_GO
# Cross_reference_GPCRDB
# Cross_reference_HAMAP
# Cross_reference_HUGE
# Cross_reference_IMGT_GENE_DB
# Cross_reference_LegioList
# Cross_reference_Leproma
# Cross_reference_MaizeGDB
# Cross_reference_MEROPS
# Cross_reference_Micado
# Cross_reference_MobiDB
# Cross_reference_ModBase
# Cross_reference_NIAGADS
# Cross_reference_PANTHER
# Cross_reference_PATRIC
# Cross_reference_PCDDB
# Cross_reference_PDBe_KB
# Cross_reference_PDBj
# Cross_reference_PeroxiBase
# Cross_reference_Pfam
# Cross_reference_PIRSF
# Cross_reference_PlantReactome
# Cross_reference_ProMEX
# Cross_reference_Proteomes
# Cross_reference_ProtoNet
# Cross_reference_PseudoCAP
# Cross_reference_RCSB_PDB
# Cross_reference_REBASE
# Cross_reference_Rouge
# Cross_reference_SASBDB
# Cross_reference_SFLD
# Cross_reference_SMART
# Cross_reference_SOURCE
# Cross_reference_SWISS_2DPAGE
# Cross_reference_SWISS_MODEL_Workspace
# Cross_reference_SwissLipids
# Cross_reference_TCDB
# Cross_reference_TIGRFAMs
# Cross_reference_TopDownProteomics
# Cross_reference_TubercuList
# Cross_reference_UCD_2DPAGE
# Cross_reference_UniLectin
# Cross_reference_UniPathway
# Cross_reference_WBParaSite
# Gene_names__synonym_
# Virus_hosts
# Gene_encoded_by
# Alternative_products_isoforms
# Erroneous_gene_model_prediction
# Erroneous_initiation
# Erroneous_termination
# Erroneous_translation
# Frameshift
# Mass_spectrometry
# Polymorphism
# RNA_editing
# Sequence_caution
# Natural_variant
# Non_adjacent_residues
# Non_standard_residue
# Sequence_uncertainty
# Absorption
# Pathway
# Redox_potential
# Active_site
# DNA_binding
# Metal_binding
# Site
# Miscellaneous_[CC]
# Interacts_with
# Biotechnological_use
# Disruption_phenotype
# Involvement_in_disease
# Pharmaceutical_use
# Toxic_dose
# Intramembrane
# Topological_domain
# Transmembrane
# Cross_link
# Disulfide_bond
# Glycosylation
# Lipidation
# Peptide
# Propeptide
# Signal_peptide
# Transit_peptide
# Domain_[CC]
# Protein_families
# Compositional_bias
# Motif
# Zinc_finger
# Taxonomic_lineage_SUBKINGDOM
# Taxonomic_lineage_SUPERPHYLUM
# Taxonomic_lineage_SUBTRIBE
# Taxonomic_lineage_SPECIES_GROUP
# Taxonomic_lineage_SPECIES_SUBGROUP
# Taxonomic_lineage_VARIETAS
# Taxonomic_lineage_FORMA
# Cross_reference_ABCD
# Cross_reference_Antibodypedia
# Cross_reference_ArachnoServer
# Cross_reference_Araport
# Cross_reference_BindingDB
# Cross_reference_BioGRID_ORCS
# Cross_reference_BioMuta
# Cross_reference_CarbonylDB
# Cross_reference_CAZy
# Cross_reference_CCDS
# Cross_reference_CDD
# Cross_reference_CGD
# Cross_reference_ChEMBL
# Cross_reference_ChiTaRS
# Cross_reference_CLAE
# Cross_reference_CollecTF
# Cross_reference_ComplexPortal
# Cross_reference_COMPLUYEAST_2DPAGE
# Cross_reference_ConoServer
# Cross_reference_CORUM
# Cross_reference_CPTAC
# Cross_reference_CPTC
# Cross_reference_dbSNP
# Cross_reference_DDBJ
# Cross_reference_DEPOD
# Cross_reference_dictyBase
# Cross_reference_DisGeNET
# Cross_reference_DisProt
# Cross_reference_DMDM
# Cross_reference_DNASU
# Cross_reference_DOSAC_COBS_2DPAGE
# Cross_reference_DrugBank
# Cross_reference_DrugCentral
# Cross_reference_EchoBASE
# Cross_reference_ELM
# Ensembl_transcript
# EnsemblFungi_transcript
# EnsemblPlants_transcript
# EnsemblProtists_transcript
# Cross_reference_ENZYME
# Cross_reference_ESTHER
# Cross_reference_euHCVdb
# Cross_reference_ExpressionAtlas
# Cross_reference_FlyBase
# Cross_reference_GenAtlas
# Cross_reference_GenBank
# Cross_reference_GeneCards
# Cross_reference_GeneReviews
# Cross_reference_Genevisible
# Cross_reference_GeneWiki
# Cross_reference_GenomeRNAi
# Cross_reference_GlyConnect
# Cross_reference_GlyGen
# Cross_reference_GO
# Cross_reference_GPCRDB
# Cross_reference_Gramene
# Cross_reference_GuidetoPHARMACOLOGY
# Cross_reference_HAMAP
# Cross_reference_HGNC
# Cross_reference_HPA
# Cross_reference_HUGE
# Cross_reference_IDEAL
# Cross_reference_IMGT_GENE_DB
# Cross_reference_jPOST
# Cross_reference_LegioList
# Cross_reference_Leproma
# Cross_reference_MaizeGDB
# Cross_reference_MalaCards
# Cross_reference_MassIVE
# Cross_reference_MaxQB
# Cross_reference_MEROPS
# Cross_reference_MetOSite
# Cross_reference_MGI
# Cross_reference_Micado
# Cross_reference_MIM
# Cross_reference_MINT
# Cross_reference_MobiDB
# Cross_reference_ModBase
# Cross_reference_MoonDB
# Cross_reference_MoonProt
# Cross_reference_neXtProt
# Cross_reference_NIAGADS
# Cross_reference_OGP
# Cross_reference_OpenTargets
# Cross_reference_Orphanet
# Cross_reference_PANTHER
# Cross_reference_PathwayCommons
# Cross_reference_PATRIC
# Cross_reference_PCDDB
# Cross_reference_PDBe_KB
# Cross_reference_PDBj
# Cross_reference_PeroxiBase
# Cross_reference_PharmGKB
# Cross_reference_Pharos
# Cross_reference_PHI_base
# Cross_reference_PhosphoSitePlus
# Cross_reference_PIRSF
# Cross_reference_PlantReactome
# Cross_reference_PomBase
# Cross_reference_PRINTS
# Cross_reference_ProMEX
# Cross_reference_Proteomes
# Cross_reference_ProteomicsDB
# Cross_reference_ProtoNet
# Cross_reference_PseudoCAP
# Cross_reference_RCSB_PDB
# Cross_reference_Reactome
# Cross_reference_REBASE
# Cross_reference_REPRODUCTION_2DPAGE
# Cross_reference_RGD
# Cross_reference_RNAct
# Cross_reference_Rouge
# Cross_reference_SASBDB
# Cross_reference_SFLD
# Cross_reference_SGD
# Cross_reference_SignaLink
# Cross_reference_SIGNOR
# Cross_reference_SMART
# Cross_reference_SOURCE
# Cross_reference_SWISS_2DPAGE
# Cross_reference_SWISS_MODEL_Workspace
# Cross_reference_SwissLipids
# Cross_reference_SwissPalm
# Cross_reference_TAIR
# Cross_reference_TCDB
# Cross_reference_TIGRFAMs
# Cross_reference_TopDownProteomics
# Cross_reference_TreeFam
# Cross_reference_TubercuList
# Cross_reference_UCD_2DPAGE
# Cross_reference_UniLectin
# Cross_reference_UniPathway
# Cross_reference_VGNC
# Cross_reference_WBParaSite
# Cross_reference_Xenbase
# Cross_reference_ZFIN
# BRENDA_REFERENCES_140
# BRENDA_REFERENCES_140_PUBMED
# BRENDA_REFERENCES_192
# BRENDA_REFERENCES_192_PUBMED
# BRENDA_REFERENCES_285
# BRENDA_REFERENCES_285_PUBMED
# BRENDA_REFERENCES_319
# BRENDA_REFERENCES_319_PUBMED
# BRENDA_EN_DATA
# BRENDA_EN_REFS
# BRENDA_EN_COMMENT
# BRENDA_KI_sulfamic_acid_DATA
# BRENDA_KI_sulfamic_acid_UNITS
# BRENDA_KI_sulfamic_acid_REFS
# BRENDA_KI_sulfamic_acid_COMMENT
# BRENDA_KI_2,4_bis[aminodihydroxy_lambda4_sulfanyl]_5_chloroaniline_DATA
# BRENDA_KI_2,4_bis[aminodihydroxy_lambda4_sulfanyl]_5_chloroaniline_UNITS
# BRENDA_KI_2,4_bis[aminodihydroxy_lambda4_sulfanyl]_5_chloroaniline_REFS
# BRENDA_KI_2,4_bis[aminodihydroxy_lambda4_sulfanyl]_5_chloroaniline_COMMENT
# BRENDA_KI_valdecoxib_DATA
# BRENDA_KI_valdecoxib_UNITS
# BRENDA_KI_valdecoxib_REFS
# BRENDA_KI_valdecoxib_COMMENT
# BRENDA_KI_4_[aminodihydroxy_lambda4_sulfanyl]_2_chloroaniline_DATA
# BRENDA_KI_4_[aminodihydroxy_lambda4_sulfanyl]_2_chloroaniline_UNITS
# BRENDA_KI_4_[aminodihydroxy_lambda4_sulfanyl]_2_chloroaniline_REFS
# BRENDA_KI_4_[aminodihydroxy_lambda4_sulfanyl]_2_chloroaniline_COMMENT
# BRENDA_KI_celecoxib_DATA
# BRENDA_KI_celecoxib_UNITS
# BRENDA_KI_celecoxib_REFS
# BRENDA_KI_celecoxib_COMMENT
# BRENDA_KI_methazolamide_DATA
# BRENDA_KI_methazolamide_UNITS
# BRENDA_KI_methazolamide_REFS
# BRENDA_KI_methazolamide_COMMENT
# BRENDA_KI_1,5_bis[aminodihydroxy_lambda4_sulfanyl]_2,3_dichlorobenzene_DATA
# BRENDA_KI_1,5_bis[aminodihydroxy_lambda4_sulfanyl]_2,3_dichlorobenzene_UNITS
# BRENDA_KI_1,5_bis[aminodihydroxy_lambda4_sulfanyl]_2,3_dichlorobenzene_REFS
# BRENDA_KI_1,5_bis[aminodihydroxy_lambda4_sulfanyl]_2,3_dichlorobenzene_COMMENT
# BRENDA_KI_3_[aminodihydroxy_lambda4_sulfanyl]aniline_DATA
# BRENDA_KI_3_[aminodihydroxy_lambda4_sulfanyl]aniline_UNITS
# BRENDA_KI_3_[aminodihydroxy_lambda4_sulfanyl]aniline_REFS
# BRENDA_KI_3_[aminodihydroxy_lambda4_sulfanyl]aniline_COMMENT
# BRENDA_KI_4_amino_N_4_sulfamoylbenzylbenzenesulfonamide_DATA
# BRENDA_KI_4_amino_N_4_sulfamoylbenzylbenzenesulfonamide_UNITS
# BRENDA_KI_4_amino_N_4_sulfamoylbenzylbenzenesulfonamide_REFS
# BRENDA_KI_4_amino_N_4_sulfamoylbenzylbenzenesulfonamide_COMMENT
# BRENDA_KI_[4_[aminodihydroxy_lambda4_sulfanyl]phenyl]hydrazine_DATA
# BRENDA_KI_[4_[aminodihydroxy_lambda4_sulfanyl]phenyl]hydrazine_UNITS
# BRENDA_KI_[4_[aminodihydroxy_lambda4_sulfanyl]phenyl]hydrazine_REFS
# BRENDA_KI_[4_[aminodihydroxy_lambda4_sulfanyl]phenyl]hydrazine_COMMENT
# BRENDA_KI_sulfanilamide_DATA
# BRENDA_KI_sulfanilamide_UNITS
# BRENDA_KI_sulfanilamide_REFS
# BRENDA_KI_sulfanilamide_COMMENT
# BRENDA_KI_1_[4_[aminodihydroxy_lambda4_sulfanyl]phenyl]ethanamine_DATA
# BRENDA_KI_1_[4_[aminodihydroxy_lambda4_sulfanyl]phenyl]ethanamine_UNITS
# BRENDA_KI_1_[4_[aminodihydroxy_lambda4_sulfanyl]phenyl]ethanamine_REFS
# BRENDA_KI_1_[4_[aminodihydroxy_lambda4_sulfanyl]phenyl]ethanamine_COMMENT
# BRENDA_KI_4_[aminodihydroxy_lambda4_sulfanyl]_2_bromoaniline_DATA
# BRENDA_KI_4_[aminodihydroxy_lambda4_sulfanyl]_2_bromoaniline_UNITS
# BRENDA_KI_4_[aminodihydroxy_lambda4_sulfanyl]_2_bromoaniline_REFS
# BRENDA_KI_4_[aminodihydroxy_lambda4_sulfanyl]_2_bromoaniline_COMMENT
# BRENDA_KI_4_[aminodihydroxy_lambda4_sulfanyl]_2_iodoaniline_DATA
# BRENDA_KI_4_[aminodihydroxy_lambda4_sulfanyl]_2_iodoaniline_UNITS
# BRENDA_KI_4_[aminodihydroxy_lambda4_sulfanyl]_2_iodoaniline_REFS
# BRENDA_KI_4_[aminodihydroxy_lambda4_sulfanyl]_2_iodoaniline_COMMENT
# BRENDA_KI_1_[4_[aminodihydroxy_lambda4_sulfanyl]phenyl]methanamine_DATA
# BRENDA_KI_1_[4_[aminodihydroxy_lambda4_sulfanyl]phenyl]methanamine_UNITS
# BRENDA_KI_1_[4_[aminodihydroxy_lambda4_sulfanyl]phenyl]methanamine_REFS
# BRENDA_KI_1_[4_[aminodihydroxy_lambda4_sulfanyl]phenyl]methanamine_COMMENT
# BRENDA_KI_dorzolamide_DATA
# BRENDA_KI_dorzolamide_UNITS
# BRENDA_KI_dorzolamide_REFS
# BRENDA_KI_dorzolamide_COMMENT
# BRENDA_KI_2,4_bis[aminodihydroxy_lamba4_sulfanyl]_5_trifluoromethylaniline_DATA
# BRENDA_KI_2,4_bis[aminodihydroxy_lamba4_sulfanyl]_5_trifluoromethylaniline_UNITS
# BRENDA_KI_2,4_bis[aminodihydroxy_lamba4_sulfanyl]_5_trifluoromethylaniline_REFS
# BRENDA_KI_2,4_bis[aminodihydroxy_lamba4_sulfanyl]_5_trifluoromethylaniline_COMMENT
# BRENDA_KI_4_[aminodihydroxy_lambda4_sulfanyl]_2_fluoroaniline_DATA
# BRENDA_KI_4_[aminodihydroxy_lambda4_sulfanyl]_2_fluoroaniline_UNITS
# BRENDA_KI_4_[aminodihydroxy_lambda4_sulfanyl]_2_fluoroaniline_REFS
# BRENDA_KI_4_[aminodihydroxy_lambda4_sulfanyl]_2_fluoroaniline_COMMENT
# BRENDA_KI_N3__DATA
# BRENDA_KI_N3__UNITS
# BRENDA_KI_N3__REFS
# BRENDA_KI_N3__COMMENT
# BRENDA_TN_DATA
# BRENDA_TN_UNITS
# BRENDA_TN_REFS
# BRENDA_TN_COMMENT
# BRENDA_IC50_Cyanate_DATA
# BRENDA_IC50
# BRENDA_IC50_Cyanate_UNITS
# BRENDA_IC50_Cyanate_REFS
# BRENDA_IC50_Cyanate_COMMENT
# BRENDA_IC50_cyanide_DATA
# BRENDA_IC50_cyanide_UNITS
# BRENDA_IC50_cyanide_REFS
# BRENDA_IC50_cyanide_COMMENT
# BRENDA_IC50_acetazolamide_DATA
# BRENDA_IC50_acetazolamide_UNITS
# BRENDA_IC50_acetazolamide_REFS
# BRENDA_IC50_acetazolamide_COMMENT
# BRENDA_IC50_azide_DATA
# BRENDA_IC50_azide_UNITS
# BRENDA_IC50_azide_REFS
# BRENDA_IC50_azide_COMMENT
# BRENDA_REFERENCES_314
# BRENDA_REFERENCES_314_PUBMED
# BRENDA_SA_DATA
# BRENDA_SA_UNITS
# BRENDA_SA_REFS
# BRENDA_SS_DATA
# BRENDA_SS_REFS
# BRENDA_KI_zonisamide_DATA
# BRENDA_KI_zonisamide_UNITS
# BRENDA_KI_zonisamide_REFS
# BRENDA_KI_zonisamide_COMMENT
# BRENDA_KI_2_hydrazinocarbonyl_3_phenyl_1H_indole_5_sulfonamide_DATA
# BRENDA_KI_2_hydrazinocarbonyl_3_phenyl_1H_indole_5_sulfonamide_UNITS
# BRENDA_KI_2_hydrazinocarbonyl_3_phenyl_1H_indole_5_sulfonamide_REFS
# BRENDA_KI_2_hydrazinocarbonyl_3_phenyl_1H_indole_5_sulfonamide_COMMENT
# BRENDA_KI_brinzolamide_DATA
# BRENDA_KI_brinzolamide_UNITS
# BRENDA_KI_brinzolamide_REFS
# BRENDA_KI_brinzolamide_COMMENT
# BRENDA_REFERENCES_166
# BRENDA_REFERENCES_166_PUBMED
# BRENDA_REFERENCES_173
# BRENDA_REFERENCES_173_PUBMED
# BRENDA_REFERENCES_174
# BRENDA_REFERENCES_174_PUBMED
# BRENDA_REFERENCES_179
# BRENDA_REFERENCES_179_PUBMED
# BRENDA_REFERENCES_183
# BRENDA_REFERENCES_183_PUBMED
# BRENDA_REFERENCES_170
# BRENDA_REFERENCES_170_PUBMED
# BRENDA_KI_5_[[4_nitrophenylsulfonyl]amino]_1,3,4_thiadiazole_2_sulfonamide_DATA
# BRENDA_KI_5_[[4_nitrophenylsulfonyl]amino]_1,3,4_thiadiazole_2_sulfonamide_UNITS
# BRENDA_KI_5_[[4_nitrophenylsulfonyl]amino]_1,3,4_thiadiazole_2_sulfonamide_REFS
# BRENDA_KI_5_[[4_nitrophenylsulfonyl]amino]_1,3,4_thiadiazole_2_sulfonamide_COMMENT
# BRENDA_KI_5_[[4_bromophenylsulfonyl]amino]_1,3,4_thiadiazole_2_sulfonamide_DATA
# BRENDA_KI_5_[[4_bromophenylsulfonyl]amino]_1,3,4_thiadiazole_2_sulfonamide_UNITS
# BRENDA_KI_5_[[4_bromophenylsulfonyl]amino]_1,3,4_thiadiazole_2_sulfonamide_REFS
# BRENDA_KI_5_[[4_bromophenylsulfonyl]amino]_1,3,4_thiadiazole_2_sulfonamide_COMMENT
# BRENDA_KI_N_5_sulfamoyl_1,3,4_thiadiazol_2_ylfuran_2_carboxamide_DATA
# BRENDA_KI_N_5_sulfamoyl_1,3,4_thiadiazol_2_ylfuran_2_carboxamide_UNITS
# BRENDA_KI_N_5_sulfamoyl_1,3,4_thiadiazol_2_ylfuran_2_carboxamide_REFS
# BRENDA_KI_N_5_sulfamoyl_1,3,4_thiadiazol_2_ylfuran_2_carboxamide_COMMENT
# BRENDA_KI_Furosemide_DATA
# BRENDA_KI_Furosemide_UNITS
# BRENDA_KI_Furosemide_REFS
# BRENDA_KI_Furosemide_COMMENT
# BRENDA_KI_4_aminosulfonyl_N_[2_[4_aminosulfonylphenyl]ethyl]benzamide_DATA
# BRENDA_KI_4_aminosulfonyl_N_[2_[4_aminosulfonylphenyl]ethyl]benzamide_UNITS
# BRENDA_KI_4_aminosulfonyl_N_[2_[4_aminosulfonylphenyl]ethyl]benzamide_REFS
# BRENDA_KI_4_aminosulfonyl_N_[2_[4_aminosulfonylphenyl]ethyl]benzamide_COMMENT
# BRENDA_KI_4_[2_[[[4_aminosulfonylphenyl]amino]carbonothioyl_amino]ethyl]benzenesulfonamide_DATA
# BRENDA_KI_4_[2_[[[4_aminosulfonylphenyl]amino]carbonothioyl_amino]ethyl]benzenesulfonamide_UNITS
# BRENDA_KI_4_[2_[[[4_aminosulfonylphenyl]amino]carbonothioyl_amino]ethyl]benzenesulfonamide_REFS
# BRENDA_KI_4_[2_[[[4_aminosulfonylphenyl]amino]carbonothioyl_amino]ethyl]benzenesulfonamide_COMMENT
# BRENDA_KI_4_[2_[anilinocarbonothioylamino]ethyl]benzenesulfonamide_DATA
# BRENDA_KI_4_[2_[anilinocarbonothioylamino]ethyl]benzenesulfonamide_UNITS
# BRENDA_KI_4_[2_[anilinocarbonothioylamino]ethyl]benzenesulfonamide_REFS
# BRENDA_KI_4_[2_[anilinocarbonothioylamino]ethyl]benzenesulfonamide_COMMENT
# BRENDA_KI_4_[[anilinocarbonothioylamino]methyl]benzenesulfonamide_DATA
# BRENDA_KI_4_[[anilinocarbonothioylamino]methyl]benzenesulfonamide_UNITS
# BRENDA_KI_4_[[anilinocarbonothioylamino]methyl]benzenesulfonamide_REFS
# BRENDA_KI_4_[[anilinocarbonothioylamino]methyl]benzenesulfonamide_COMMENT
# BRENDA_KI_4_[2_[anilinocarbonylamino]ethyl]benzenesulfonamide_DATA
# BRENDA_KI_4_[2_[anilinocarbonylamino]ethyl]benzenesulfonamide_UNITS
# BRENDA_KI_4_[2_[anilinocarbonylamino]ethyl]benzenesulfonamide_REFS
# BRENDA_KI_4_[2_[anilinocarbonylamino]ethyl]benzenesulfonamide_COMMENT
# BRENDA_KI_4_[anilinocarbonylamino]_6_chlorobenzene_1,3_disulfonamide_DATA
# BRENDA_KI_4_[anilinocarbonylamino]_6_chlorobenzene_1,3_disulfonamide_UNITS
# BRENDA_KI_4_[anilinocarbonylamino]_6_chlorobenzene_1,3_disulfonamide_REFS
# BRENDA_KI_4_[anilinocarbonylamino]_6_chlorobenzene_1,3_disulfonamide_COMMENT
# BRENDA_KI_4_[[phenylsulfonylamino]methyl]benzenesulfonamide_DATA
# BRENDA_KI_4_[[phenylsulfonylamino]methyl]benzenesulfonamide_UNITS
# BRENDA_KI_4_[[phenylsulfonylamino]methyl]benzenesulfonamide_REFS
# BRENDA_KI_4_[[phenylsulfonylamino]methyl]benzenesulfonamide_COMMENT
# BRENDA_KI_4_[acetyloxyamino]_N_[4_aminosulfonylphenyl]benzenesulfonamide_DATA
# BRENDA_KI_4_[acetyloxyamino]_N_[4_aminosulfonylphenyl]benzenesulfonamide_UNITS
# ...
# BRENDA_KI_N_1,3_benzothiazol_2_yl_2_[[5_2_hydroxyphenyl_4H_1,2_4_triazol_3_yl]sulfanyl]acetamide_REFS
# BRENDA_KI_N_1,3_benzothiazol_2_yl_2_[[5_2_hydroxyphenyl_4H_1,2_4_triazol_3_yl]sulfanyl]acetamide_COMMENT
# BRENDA_KI_N_1,3_benzothiazol_2_yl_2_[[5_pyridin_4_yl_1,3_4_thiadiazol_2_yl]sulfanyl]acetamide_DATA
# BRENDA_KI_N_1,3_benzothiazol_2_yl_2_[[5_pyridin_4_yl_1,3_4_thiadiazol_2_yl]sulfanyl]acetamide_UNITS
# BRENDA_KI_N_1,3_benzothiazol_2_yl_2_[[5_pyridin_4_yl_1,3_4_thiadiazol_2_yl]sulfanyl]acetamide_REFS
# BRENDA_KI_N_1,3_benzothiazol_2_yl_2_[[5_pyridin_4_yl_1,3_4_thiadiazol_2_yl]sulfanyl]acetamide_COMMENT
# BRENDA_KI_N_phenyl_2_[[5_pyridin_4_yl_1,3_4_thiadiazol_2_yl]sulfanyl]acetamide_DATA
# BRENDA_KI_N_phenyl_2_[[5_pyridin_4_yl_1,3_4_thiadiazol_2_yl]sulfanyl]acetamide_UNITS
# BRENDA_KI_N_phenyl_2_[[5_pyridin_4_yl_1,3_4_thiadiazol_2_yl]sulfanyl]acetamide_REFS
# BRENDA_KI_N_phenyl_2_[[5_pyridin_4_yl_1,3_4_thiadiazol_2_yl]sulfanyl]acetamide_COMMENT
# BRENDA_KI_N_phenyl_2_[[5_pyridin_4_yl_1,3,4_oxadiazol_2_yl]sulfanyl]acetamide_DATA
# BRENDA_KI_N_phenyl_2_[[5_pyridin_4_yl_1,3,4_oxadiazol_2_yl]sulfanyl]acetamide_UNITS
# BRENDA_KI_N_phenyl_2_[[5_pyridin_4_yl_1,3,4_oxadiazol_2_yl]sulfanyl]acetamide_REFS
# BRENDA_KI_N_phenyl_2_[[5_pyridin_4_yl_1,3,4_oxadiazol_2_yl]sulfanyl]acetamide_COMMENT
# BRENDA_KI_2_[[5_2_hydroxyphenyl_1,3_4_thiadiazol_2_yl]sulfanyl]_N_phenylacetamide_DATA
# BRENDA_KI_2_[[5_2_hydroxyphenyl_1,3_4_thiadiazol_2_yl]sulfanyl]_N_phenylacetamide_UNITS
# BRENDA_KI_2_[[5_2_hydroxyphenyl_1,3_4_thiadiazol_2_yl]sulfanyl]_N_phenylacetamide_REFS
# BRENDA_KI_2_[[5_2_hydroxyphenyl_1,3_4_thiadiazol_2_yl]sulfanyl]_N_phenylacetamide_COMMENT
# BRENDA_KI_N_1,3_benzothiazol_2_yl_2_[[5_pyridin_3_yl_4H_1,2_4_triazol_3_yl]sulfanyl]acetamide_DATA
# BRENDA_KI_N_1,3_benzothiazol_2_yl_2_[[5_pyridin_3_yl_4H_1,2_4_triazol_3_yl]sulfanyl]acetamide_UNITS
# BRENDA_KI_N_1,3_benzothiazol_2_yl_2_[[5_pyridin_3_yl_4H_1,2_4_triazol_3_yl]sulfanyl]acetamide_REFS
# BRENDA_KI_N_1,3_benzothiazol_2_yl_2_[[5_pyridin_3_yl_4H_1,2_4_triazol_3_yl]sulfanyl]acetamide_COMMENT
# BRENDA_KI_N_1,3_benzothiazol_2_yl_2_[[5_pyridin_3_yl_1,3_4_oxadiazol_2_yl]sulfanyl]acetamide_DATA
# BRENDA_KI_N_1,3_benzothiazol_2_yl_2_[[5_pyridin_3_yl_1,3_4_oxadiazol_2_yl]sulfanyl]acetamide_UNITS
# BRENDA_KI_N_1,3_benzothiazol_2_yl_2_[[5_pyridin_3_yl_1,3_4_oxadiazol_2_yl]sulfanyl]acetamide_REFS
# BRENDA_KI_N_1,3_benzothiazol_2_yl_2_[[5_pyridin_3_yl_1,3_4_oxadiazol_2_yl]sulfanyl]acetamide_COMMENT
# BRENDA_KI_N_1,3_benzothiazol_2_yl_2_[[5_pyridin_3_yl_1,3_4_thiadiazol_2_yl]sulfanyl]acetamide_DATA
# BRENDA_KI_N_1,3_benzothiazol_2_yl_2_[[5_pyridin_3_yl_1,3_4_thiadiazol_2_yl]sulfanyl]acetamide_UNITS
# BRENDA_KI_N_1,3_benzothiazol_2_yl_2_[[5_pyridin_3_yl_1,3_4_thiadiazol_2_yl]sulfanyl]acetamide_REFS
# BRENDA_KI_N_1,3_benzothiazol_2_yl_2_[[5_pyridin_3_yl_1,3_4_thiadiazol_2_yl]sulfanyl]acetamide_COMMENT
# BRENDA_KI_N_1,3_benzothiazol_2_yl_2_[[5_2_hydroxyphenyl_1,3_4_thiadiazol_2_yl]sulfanyl]acetamide_DATA
# BRENDA_KI_N_1,3_benzothiazol_2_yl_2_[[5_2_hydroxyphenyl_1,3_4_thiadiazol_2_yl]sulfanyl]acetamide_UNITS
# BRENDA_KI_N_1,3_benzothiazol_2_yl_2_[[5_2_hydroxyphenyl_1,3_4_thiadiazol_2_yl]sulfanyl]acetamide_REFS
# BRENDA_KI_N_1,3_benzothiazol_2_yl_2_[[5_2_hydroxyphenyl_1,3_4_thiadiazol_2_yl]sulfanyl]acetamide_COMMENT
# BRENDA_LO_DATA
# BRENDA_LO_REFS
# BRENDA_TR_DATA
# BRENDA_TR_REFS
# BRENDA_TR_COMMENT
# Virus_hosts
# Alternative_products_isoforms
# Erroneous_gene_model_prediction
# Erroneous_termination
# Erroneous_translation
# Frameshift
# Polymorphism
# RNA_editing
# Alternative_sequence
# Non_adjacent_residues
# Non_standard_residue
# Sequence_uncertainty
# Absorption
# ChEBI_Cofactor
# Cofactor
# Pathway
# Redox_potential
# Temperature_dependence
# pH_dependence
# DNA_binding
# Nucleotide_binding
# Caution
# Developmental_stage
# Tissue_specificity
# Allergenic_properties
# Involvement_in_disease
# Pharmaceutical_use
# Toxic_dose
# Intramembrane
# Topological_domain
# Transmembrane
# Cross_link
# Glycosylation
# Initiator_methionine
# Peptide
# Propeptide
# Transit_peptide
# Domain_[CC]
# Compositional_bias
# Motif
# Repeat
# Zinc_finger
# Taxonomic_lineage_SUPERKINGDOM
# Taxonomic_lineage_KINGDOM
# Taxonomic_lineage_SUBKINGDOM
# Taxonomic_lineage_SUPERPHYLUM
# Taxonomic_lineage_SUBPHYLUM
# Taxonomic_lineage_SUPERCLASS
# Taxonomic_lineage_SUBCLASS
# Taxonomic_lineage_INFRACLASS
# Taxonomic_lineage_SUPERORDER
# Taxonomic_lineage_SUBORDER
# Taxonomic_lineage_INFRAORDER
# Taxonomic_lineage_PARVORDER
# Taxonomic_lineage_SUPERFAMILY
# Taxonomic_lineage_SUBFAMILY
# Taxonomic_lineage_TRIBE
# Taxonomic_lineage_SUBTRIBE
# Taxonomic_lineage_SUBGENUS
# Taxonomic_lineage_SPECIES_SUBGROUP
# Taxonomic_lineage_VARIETAS
# Taxonomic_lineage_FORMA
# Cross_reference_Allergome
# Cross_reference_Antibodypedia
# Cross_reference_ArachnoServer
# Cross_reference_Araport
# Cross_reference_Bgee
# Cross_reference_BioGRID_ORCS
# Cross_reference_BioMuta
# Cross_reference_BRENDA
# Cross_reference_CarbonylDB
# Cross_reference_CAZy
# Cross_reference_CCDS
# Cross_reference_CDD
# Cross_reference_CGD
# Cross_reference_ChiTaRS
# Cross_reference_CLAE
# Cross_reference_CollecTF
# Cross_reference_ComplexPortal
# Cross_reference_COMPLUYEAST_2DPAGE
# Cross_reference_ConoServer
# Cross_reference_CORUM
# Cross_reference_CPTAC
# Cross_reference_CPTC
# Cross_reference_CTD
# Cross_reference_dbSNP
# Cross_reference_DDBJ
# Cross_reference_DEPOD
# Cross_reference_dictyBase
# Cross_reference_DIP
# Cross_reference_DisGeNET
# Cross_reference_DisProt
# Cross_reference_DMDM
# Cross_reference_DOSAC_COBS_2DPAGE
# Cross_reference_ELM
# Ensembl_transcript
# EnsemblFungi_transcript
# EnsemblMetazoa_transcript
# EnsemblPlants_transcript
# EnsemblProtists_transcript
# Cross_reference_ENZYME
# Cross_reference_EPD
# Cross_reference_ESTHER
# Cross_reference_euHCVdb
# Cross_reference_ExpressionAtlas
# Cross_reference_FlyBase
# Cross_reference_GenAtlas
# Cross_reference_GenBank
# Cross_reference_Gene3D
# Cross_reference_GeneCards
# Cross_reference_GeneDB
# Cross_reference_GeneReviews
# Cross_reference_GeneTree
# Cross_reference_Genevisible
# Cross_reference_GeneWiki
# Cross_reference_GenomeRNAi
# Cross_reference_GlyConnect
# Cross_reference_GlyGen
# Cross_reference_GO
# Cross_reference_GPCRDB
# Cross_reference_Gramene
# Cross_reference_GuidetoPHARMACOLOGY
# Cross_reference_HAMAP
# Cross_reference_HGNC
# Cross_reference_HPA
# Cross_reference_HUGE
# Cross_reference_IDEAL
# Cross_reference_IMGT_GENE_DB
# Cross_reference_iPTMnet
# Cross_reference_LegioList
# Cross_reference_Leproma
# Cross_reference_MaizeGDB
# Cross_reference_MalaCards
# Cross_reference_MassIVE
# Cross_reference_MaxQB
# Cross_reference_MetOSite
# Cross_reference_MGI
# Cross_reference_Micado
# Cross_reference_MIM
# Cross_reference_MINT
# Cross_reference_MobiDB
# Cross_reference_ModBase
# Cross_reference_MoonDB
# Cross_reference_MoonProt
# Cross_reference_neXtProt
# Cross_reference_NIAGADS
# Cross_reference_OGP
# Cross_reference_OpenTargets
# Cross_reference_Orphanet
# Cross_reference_PANTHER
# Cross_reference_PathwayCommons
# Cross_reference_PCDDB
# Cross_reference_PDBe_KB
# Cross_reference_PDBj
# Cross_reference_PeptideAtlas
# Cross_reference_PeroxiBase
# Cross_reference_PharmGKB
# Cross_reference_Pharos
# Cross_reference_PHI_base
# Cross_reference_PhosphoSitePlus
# Cross_reference_PIRSF
# Cross_reference_PlantReactome
# Cross_reference_PomBase
# Cross_reference_ProMEX
# Cross_reference_Proteomes
# Cross_reference_ProteomicsDB
# Cross_reference_ProtoNet
# Cross_reference_PseudoCAP
# Cross_reference_RCSB_PDB
# Cross_reference_Reactome
# Cross_reference_REBASE
# Cross_reference_REPRODUCTION_2DPAGE
# Cross_reference_RGD
# Cross_reference_RNAct
# Cross_reference_Rouge
# Cross_reference_SASBDB
# Cross_reference_SFLD
# Cross_reference_SGD
# Cross_reference_SignaLink
# Cross_reference_SIGNOR
# Cross_reference_SMART
# Cross_reference_SOURCE
# Cross_reference_SUPFAM
# Cross_reference_SWISS_MODEL_Workspace
# Cross_reference_SwissLipids
# Cross_reference_SwissPalm
# Cross_reference_TAIR
# Cross_reference_TCDB
# Cross_reference_TIGRFAMs
# Cross_reference_TopDownProteomics
# Cross_reference_TreeFam
# Cross_reference_UCD_2DPAGE
# Cross_reference_UCSC
# Cross_reference_UniLectin
# Cross_reference_UniPathway
# Cross_reference_VEuPathDB
# Cross_reference_VGNC
# Cross_reference_WBParaSite
# Cross_reference_World_2DPAGE
# Cross_reference_WormBase
# Cross_reference_Xenbase
# Cross_reference_ZFIN
# BRENDA_REFERENCES_152
# BRENDA_REFERENCES_152_PUBMED
# BRENDA_REFERENCES_164
# BRENDA_REFERENCES_164_PUBMED
# BRENDA_REFERENCES_166
# BRENDA_REFERENCES_166_PUBMED
# BRENDA_PM_DATA
# BRENDA_PM_REFS
# BRENDA_PM_COMMENT
# BRENDA_REFERENCES_109
# BRENDA_REFERENCES_109_PUBMED
# BRENDA_REFERENCES_306
# BRENDA_REFERENCES_306_PUBMED
# BRENDA_REFERENCES_132
# BRENDA_REFERENCES_132_PUBMED
# BRENDA_REFERENCES_173
# BRENDA_REFERENCES_173_PUBMED
# BRENDA_REFERENCES_151
# BRENDA_REFERENCES_151_PUBMED
# BRENDA_REFERENCES_159
# BRENDA_REFERENCES_159_PUBMED
# BRENDA_AC_DATA
# BRENDA_AC_REFS
# BRENDA_AC_COMMENT
# BRENDA_REFERENCES_129
# BRENDA_REFERENCES_129_PUBMED
# Virus_hosts
# Gene_encoded_by
# Alternative_products_isoforms
# Erroneous_gene_model_prediction
# Erroneous_initiation
# Erroneous_termination
# Erroneous_translation
# Frameshift
# Mass_spectrometry
# Polymorphism
# RNA_editing
# Sequence_caution
# Non_adjacent_residues
# Non_standard_residue
# Sequence_uncertainty
# EC_number
# Absorption
# ChEBI_Catalytic_activity
# Kinetics
# Pathway
# Redox_potential
# Temperature_dependence
# pH_dependence
# Active_site
# Binding_site
# DNA_binding
# Nucleotide_binding
# Site
# Caution
# Miscellaneous_[CC]
# Developmental_stage
# Tissue_specificity
# Allergenic_properties
# Biotechnological_use
# Disruption_phenotype
# Pharmaceutical_use
# Toxic_dose
# Intramembrane
# Topological_domain
# Transmembrane
# Cross_link
# Disulfide_bond
# Glycosylation
# Lipidation
# Peptide
# Propeptide
# Domain_[CC]
# Protein_families
# Motif
# Repeat
# Zinc_finger
# Taxonomic_lineage_SUPERPHYLUM
# Taxonomic_lineage_SPECIES_SUBGROUP
# Taxonomic_lineage_FORMA
# Cross_reference_ABCD
# Cross_reference_ArachnoServer
# Cross_reference_Araport
# Cross_reference_BindingDB
# Cross_reference_CarbonylDB
# Cross_reference_CAZy
# Cross_reference_CDD
# Cross_reference_CGD
# Cross_reference_CLAE
# Cross_reference_CollecTF
# Cross_reference_ComplexPortal
# Cross_reference_COMPLUYEAST_2DPAGE
# Cross_reference_ConoServer
# Cross_reference_CORUM
# Cross_reference_CPTAC
# Cross_reference_CPTC
# Cross_reference_DDBJ
# Cross_reference_DEPOD
# Cross_reference_dictyBase
# Cross_reference_DIP
# Cross_reference_DisProt
# Cross_reference_ELM
# EnsemblFungi_transcript
# EnsemblMetazoa_transcript
# EnsemblPlants_transcript
# EnsemblProtists_transcript
# Cross_reference_ENZYME
# Cross_reference_ESTHER
# Cross_reference_euHCVdb
# Cross_reference_FlyBase
# Cross_reference_GenAtlas
# Cross_reference_GenBank
# Cross_reference_GeneReviews
# Cross_reference_GlyConnect
# Cross_reference_GlyGen
# Cross_reference_GO
# Cross_reference_GPCRDB
# Cross_reference_Gramene
# Cross_reference_GuidetoPHARMACOLOGY
# Cross_reference_HAMAP
# Cross_reference_HUGE
# Cross_reference_IDEAL
# Cross_reference_IMGT_GENE_DB
# Cross_reference_LegioList
# Cross_reference_Leproma
# Cross_reference_MaizeGDB
# Cross_reference_MEROPS
# Cross_reference_MetOSite
# Cross_reference_MGI
# Cross_reference_Micado
# Cross_reference_MobiDB
# Cross_reference_ModBase
# Cross_reference_MoonDB
# Cross_reference_MoonProt
# Cross_reference_NIAGADS
# Cross_reference_Orphanet
# Cross_reference_PANTHER
# Cross_reference_PCDDB
# Cross_reference_PDBe_KB
# Cross_reference_PDBj
# Cross_reference_PeroxiBase
# Cross_reference_PHI_base
# Cross_reference_PlantReactome
# Cross_reference_PomBase
# Cross_reference_ProMEX
# Cross_reference_Proteomes
# Cross_reference_ProtoNet
# Cross_reference_PseudoCAP
# Cross_reference_RCSB_PDB
# Cross_reference_REBASE
# Cross_reference_REPRODUCTION_2DPAGE
# Cross_reference_Rouge
# Cross_reference_SABIO_RK
# Cross_reference_SASBDB
# Cross_reference_SFLD
# Cross_reference_SGD
# Cross_reference_SignaLink
# Cross_reference_SMART
# Cross_reference_SOURCE
# Cross_reference_SWISS_MODEL_Workspace
# Cross_reference_SwissLipids
# Cross_reference_TAIR
# Cross_reference_TCDB
# Cross_reference_TIGRFAMs
# Cross_reference_TubercuList
# Cross_reference_UniLectin
# Cross_reference_UniPathway
# Cross_reference_VGNC
# Cross_reference_WBParaSite
# Cross_reference_WormBase
# Cross_reference_Xenbase
# Virus_hosts
# Alternative_products_isoforms
# Erroneous_gene_model_prediction
# Erroneous_termination
# Erroneous_translation
# Frameshift
# Mass_spectrometry
# Polymorphism
# RNA_editing
# Alternative_sequence
# Natural_variant
# Non_adjacent_residues
# Non_standard_residue
# Sequence_uncertainty
# Absorption
# Pathway
# Redox_potential
# pH_dependence
# DNA_binding
# Developmental_stage
# Tissue_specificity
# Allergenic_properties
# Involvement_in_disease
# Pharmaceutical_use
# Toxic_dose
# Intramembrane
# Topological_domain
# Transmembrane
# Cross_link
# Glycosylation
# Lipidation
# Peptide
# Signal_peptide
# Transit_peptide
# Coiled_coil
# Compositional_bias
# Motif
# Repeat
# Zinc_finger
# Taxonomic_lineage_SUBKINGDOM
# Taxonomic_lineage_SUPERPHYLUM
# Taxonomic_lineage_SUPERCLASS
# Taxonomic_lineage_INFRACLASS
# Taxonomic_lineage_SUPERORDER
# Taxonomic_lineage_INFRAORDER
# Taxonomic_lineage_PARVORDER
# Taxonomic_lineage_SUPERFAMILY
# Taxonomic_lineage_SPECIES_GROUP
# Taxonomic_lineage_SPECIES_SUBGROUP
# Taxonomic_lineage_FORMA
# Cross_reference_ABCD
# Cross_reference_Antibodypedia
# Cross_reference_ArachnoServer
# Cross_reference_Bgee
# Cross_reference_BindingDB
# Cross_reference_BioGRID_ORCS
# Cross_reference_BioMuta
# Cross_reference_BMRB
# Cross_reference_BRENDA
# Cross_reference_CarbonylDB
# Cross_reference_CAZy
# Cross_reference_CCDS
# Cross_reference_CGD
# Cross_reference_ChEMBL
# Cross_reference_ChiTaRS
# Cross_reference_CLAE
# Cross_reference_CollecTF
# Cross_reference_ComplexPortal
# Cross_reference_COMPLUYEAST_2DPAGE
# Cross_reference_ConoServer
# Cross_reference_CORUM
# Cross_reference_CPTAC
# Cross_reference_CPTC
# Cross_reference_CTD
# Cross_reference_dbSNP
# Cross_reference_DDBJ
# Cross_reference_DEPOD
# Cross_reference_dictyBase
# Cross_reference_DisGeNET
# Cross_reference_DisProt
# Cross_reference_DMDM
# Cross_reference_DOSAC_COBS_2DPAGE
# Cross_reference_DrugBank
# Cross_reference_DrugCentral
# Cross_reference_EchoBASE
# Cross_reference_ELM
# Ensembl_transcript
# EnsemblFungi_transcript
# EnsemblMetazoa_transcript
# EnsemblProtists_transcript
# Cross_reference_ENZYME
# Cross_reference_EPD
# Cross_reference_ESTHER
# Cross_reference_euHCVdb
# Cross_reference_FlyBase
# Cross_reference_GenAtlas
# Cross_reference_GenBank
# Cross_reference_GeneCards
# Cross_reference_GeneDB
# Cross_reference_GeneReviews
# Cross_reference_GeneTree
# Cross_reference_GeneWiki
# Cross_reference_GenomeRNAi
# Cross_reference_GlyConnect
# Cross_reference_GlyGen
# Cross_reference_GO
# Cross_reference_GPCRDB
# Cross_reference_GuidetoPHARMACOLOGY
# Cross_reference_HGNC
# Cross_reference_HPA
# Cross_reference_HUGE
# Cross_reference_IDEAL
# Cross_reference_IMGT_GENE_DB
# Cross_reference_jPOST
# Cross_reference_LegioList
# Cross_reference_Leproma
# Cross_reference_MaizeGDB
# Cross_reference_MalaCards
# Cross_reference_MassIVE
# Cross_reference_MaxQB
# Cross_reference_MEROPS
# Cross_reference_MetOSite
# Cross_reference_MGI
# Cross_reference_Micado
# Cross_reference_MIM
# Cross_reference_MobiDB
# Cross_reference_ModBase
# Cross_reference_MoonDB
# Cross_reference_MoonProt
# Cross_reference_neXtProt
# Cross_reference_NIAGADS
# Cross_reference_OGP
# Cross_reference_OpenTargets
# Cross_reference_Orphanet
# Cross_reference_PANTHER
# Cross_reference_PathwayCommons
# Cross_reference_PCDDB
# Cross_reference_PDBe_KB
# Cross_reference_PDBj
# Cross_reference_PeptideAtlas
# Cross_reference_PeroxiBase
# Cross_reference_PharmGKB
# Cross_reference_Pharos
# Cross_reference_PHI_base
# Cross_reference_PhosphoSitePlus
# Cross_reference_PIRSF
# Cross_reference_PlantReactome
# Cross_reference_PomBase
# Cross_reference_PRINTS
# Cross_reference_ProMEX
# Cross_reference_Proteomes
# Cross_reference_ProtoNet
# Cross_reference_PseudoCAP
# Cross_reference_RCSB_PDB
# Cross_reference_Reactome
# Cross_reference_REBASE
# Cross_reference_REPRODUCTION_2DPAGE
# Cross_reference_RGD
# Cross_reference_RNAct
# Cross_reference_Rouge
# Cross_reference_SASBDB
# Cross_reference_SGD
# Cross_reference_SignaLink
# Cross_reference_SIGNOR
# Cross_reference_SMART
# Cross_reference_SOURCE
# Cross_reference_SWISS_MODEL_Workspace
# Cross_reference_SwissLipids
# Cross_reference_SwissPalm
# Cross_reference_TCDB
# Cross_reference_TopDownProteomics
# Cross_reference_TreeFam
# Cross_reference_TubercuList
# Cross_reference_UCD_2DPAGE
# Cross_reference_UCSC
# Cross_reference_UniLectin
# Cross_reference_UniPathway
# Cross_reference_VEuPathDB
# Cross_reference_VGNC
# Cross_reference_WBParaSite
# Cross_reference_World_2DPAGE
# Cross_reference_WormBase
# Cross_reference_Xenbase
# Cross_reference_ZFIN

# %%
ordered
# Out:
# [('Taxonomic_lineage_INFRAORDER', 5),
#  ('Taxonomic_lineage_SUPERFAMILY', 5),
#  ('Cross_reference_TIGRFAMs', 5),
#  ('Cross_reference_CDD', 5),
#  ('Cross_reference_PANTHER', 5),
#  ('BRENDA_SS_DATA', 4),
#  ('BRENDA_SS_REFS', 4),
#  ('BRENDA_IC50', 4),
#  ('BRENDA_EXP_DATA', 4),
#  ('BRENDA_EXP_REFS', 4),
#  ('BRENDA_EXP_COMMENT', 4),
#  ('Erroneous_initiation', 4),
#  ('Sequence_caution', 4),
#  ('pH_dependence', 4),
#  ('Site', 4),
#  ('Tissue_specificity', 4),
#  ('Post_translational_modification', 4),
#  ('Coiled_coil', 4),
#  ('Taxonomic_lineage_INFRACLASS', 4),
#  ('Taxonomic_lineage_SUPERORDER', 4),
#  ('Cross_reference_Araport', 4),
#  ('Cross_reference_BioCyc', 4),
#  ('Cross_reference_DrugBank', 4),
#  ('EnsemblPlants_transcript', 4),
#  ('Cross_reference_Gramene', 4),
#  ('Cross_reference_PhylomeDB', 4),
#  ('Cross_reference_PIRSF', 4),
#  ('Cross_reference_ProteomicsDB', 4),
#  ('Cross_reference_TAIR', 4),
#  ('Transmembrane', 4),
#  ('Lipidation', 4),
#  ('Cross_reference_ABCD', 4),
#  ('Cross_reference_Reactome', 4),
#  ('BRENDA_PM_DATA', 4),
#  ('BRENDA_PM_REFS', 4),
#  ('BRENDA_PM_COMMENT', 4),
#  ('Erroneous_gene_model_prediction', 4),
#  ('Cross_reference_SMART', 4),
#  ('ChEBI_Catalytic_activity', 4),
#  ('Frameshift', 3),
#  ('ChEBI', 3),
#  ('ChEBI_IDs', 3),
#  ('Cofactor', 3),
#  ('Pathway', 3),
#  ('Miscellaneous_[CC]', 3),
#  ('Taxonomic_lineage_SUBFAMILY', 3),
#  ('Taxonomic_lineage_TRIBE', 3),
#  ('Taxonomic_lineage_SPECIES_GROUP', 3),
#  ('Taxonomic_lineage_SUBSPECIES', 3),
#  ('Cross_reference_BioGRID', 3),
#  ('Cross_reference_DNASU', 3),
#  ('Cross_reference_ExpressionAtlas', 3),
#  ('Cross_reference_Genevisible', 3),
#  ('Cross_reference_IntAct', 3),
#  ('Cross_reference_iPTMnet', 3),
#  ('Cross_reference_PRO', 3),
#  ('Cross_reference_UniPathway', 3),
#  ('BRENDA_REFERENCES_259', 3),
#  ('BRENDA_REFERENCES_259_PUBMED', 3),
#  ('BRENDA_AC_DATA', 3),
#  ('BRENDA_AC_REFS', 3),
#  ('BRENDA_AC_COMMENT', 3),
#  ('Alternative_sequence', 3),
#  ('Glycosylation', 3),
#  ('Propeptide', 3),
#  ('Taxonomic_lineage_SUPERCLASS', 3),
#  ('Taxonomic_lineage_PARVORDER', 3),
#  ('Cross_reference_BindingDB', 3),
#  ('Cross_reference_BioGRID_ORCS', 3),
#  ('Cross_reference_BioMuta', 3),
#  ('Cross_reference_CTD', 3),
#  ('Cross_reference_dbSNP', 3),
#  ('Cross_reference_DisGeNET', 3),
#  ('Cross_reference_DMDM', 3),
#  ('EnsemblBacteria_transcript', 3),
#  ('EnsemblFungi_transcript', 3),
#  ('Cross_reference_GeneCards', 3),
#  ('Cross_reference_GenomeRNAi', 3),
#  ('Cross_reference_HGNC', 3),
#  ('Cross_reference_MassIVE', 3),
#  ('Cross_reference_MIM', 3),
#  ('Cross_reference_neXtProt', 3),
#  ('Cross_reference_PathwayCommons', 3),
#  ('Cross_reference_PATRIC', 3),
#  ('Cross_reference_PeptideAtlas', 3),
#  ('Cross_reference_PharmGKB', 3),
#  ('Cross_reference_Pharos', 3),
#  ('Cross_reference_PhosphoSitePlus', 3),
#  ('Cross_reference_SASBDB', 3),
#  ('Disulfide_bond', 3),
#  ('Signal_peptide', 3),
#  ('Protein_families', 3),
#  ('Cross_reference_Gene3D', 3),
#  ('Cross_reference_SUPFAM', 3),
#  ('BRENDA_TN_DATA', 3),
#  ('BRENDA_TN_UNITS', 3),
#  ('BRENDA_TN_REFS', 3),
#  ('BRENDA_TN_COMMENT', 3),
#  ('Natural_variant', 3),
#  ('Cross_reference_GlyGen', 3),
#  ('Cross_reference_PRINTS', 3),
#  ('Cross_reference_SwissLipids', 3),
#  ('BRENDA_REFERENCES_72', 2),
#  ('BRENDA_REFERENCES_140', 2),
#  ('BRENDA_REFERENCES_140_PUBMED', 2),
#  ('BRENDA_REFERENCES_306', 2),
#  ('BRENDA_REFERENCES_306_PUBMED', 2),
#  ('BRENDA_REFERENCES_174', 2),
#  ('BRENDA_REFERENCES_174_PUBMED', 2),
#  ('Fragment', 2),
#  ('Non_terminal_residue', 2),
#  ('Sequence_conflict', 2),
#  ('ChEBI_Cofactor', 2),
#  ('Kinetics', 2),
#  ('Temperature_dependence', 2),
#  ('Active_site', 2),
#  ('Caution', 2),
#  ('Biotechnological_use', 2),
#  ('Compositional_bias', 2),
#  ('Taxonomic_lineage_SUBORDER', 2),
#  ('Cross_reference_BMRB', 2),
#  ('Cross_reference_EchoBASE', 2),
#  ('Cross_reference_PaxDb', 2),
#  ('Cross_reference_PRIDE', 2),
#  ('BRENDA_REFERENCES_18', 2),
#  ('BRENDA_REFERENCES_139', 2),
#  ('BRENDA_REFERENCES_139_PUBMED', 2),
#  ('BRENDA_KM_DATA', 2),
#  ('BRENDA_KM_UNITS', 2),
#  ('BRENDA_KM_REFS', 2),
#  ('BRENDA_KM_COMMENT', 2),
#  ('Binding_site', 2),
#  ('Interacts_with', 2),
#  ('Disruption_phenotype', 2),
#  ('Taxonomic_lineage_SUBKINGDOM', 2),
#  ('Taxonomic_lineage_SUBGENUS', 2),
#  ('Cross_reference_Antibodypedia', 2),
#  ('Cross_reference_Bgee', 2),
#  ('Cross_reference_CCDS', 2),
#  ('Ensembl_transcript', 2),
#  ('Cross_reference_GuidetoPHARMACOLOGY', 2),
#  ('Cross_reference_HPA', 2),
#  ('Cross_reference_OpenTargets', 2),
#  ('Cross_reference_RNAct', 2),
#  ('Cross_reference_SABIO_RK', 2),
#  ('Cross_reference_SGD', 2),
#  ('Cross_reference_TreeFam', 2),
#  ('Cross_reference_UCSC', 2),
#  ('Initiator_methionine', 2),
#  ('Cross_reference_TopDownProteomics', 2),
#  ('BRENDA_REFERENCES_166', 2),
#  ('BRENDA_REFERENCES_166_PUBMED', 2),
#  ('BRENDA_REFERENCES_173', 2),
#  ('BRENDA_REFERENCES_173_PUBMED', 2),
#  ('BRENDA_REFERENCES_217', 2),
#  ('BRENDA_REFERENCES_217_PUBMED', 2),
#  ('BRENDA_TR_DATA', 2),
#  ('BRENDA_TR_REFS', 2),
#  ('BRENDA_TR_COMMENT', 2),
#  ('Developmental_stage', 2),
#  ('Topological_domain', 2),
#  ('Cross_reference_CarbonylDB', 2),
#  ('Cross_reference_ChiTaRS', 2),
#  ('Cross_reference_DisProt', 2),
#  ('Cross_reference_GeneReviews', 2),
#  ('Cross_reference_GeneWiki', 2),
#  ('Cross_reference_GlyConnect', 2),
#  ('Cross_reference_Orphanet', 2),
#  ('Cross_reference_PCDDB', 2),
#  ('Cross_reference_ProMEX', 2),
#  ('Cross_reference_REPRODUCTION_2DPAGE', 2),
#  ('Cross_reference_SwissPalm', 2),
#  ('BRENDA_REFERENCES_226', 2),
#  ('BRENDA_REFERENCES_226_PUBMED', 2),
#  ('BRENDA_REFERENCES_20', 2),
#  ('BRENDA_REFERENCES_20_PUBMED', 2),
#  ('Transit_peptide', 2),
#  ('Motif', 2),
#  ('Taxonomic_lineage_SUBTRIBE', 2),
#  ('Cross_reference_PlantReactome', 2),
#  ('BRENDA_REFERENCES_129', 2),
#  ('BRENDA_REFERENCES_129_PUBMED', 2),
#  ('BRENDA_REFERENCES_5', 2),
#  ('BRENDA_REFERENCES_5_PUBMED', 2),
#  ('BRENDA_REFERENCES_15', 2),
#  ('BRENDA_REFERENCES_15_PUBMED', 2),
#  ('BRENDA_REFERENCES_248', 2),
#  ('BRENDA_REFERENCES_248_PUBMED', 2),
#  ('BRENDA_REFERENCES_10', 2),
#  ('BRENDA_REFERENCES_10_PUBMED', 2),
#  ('BRENDA_REFERENCES_1', 2),
#  ('BRENDA_REFERENCES_1_PUBMED', 2),
#  ('Cross_reference_DIP', 2),
#  ('BRENDA_REFERENCES_159', 2),
#  ('BRENDA_REFERENCES_159_PUBMED', 2),
#  ('BRENDA_REFERENCES_132', 2),
#  ('BRENDA_REFERENCES_132_PUBMED', 2),
#  ('BRENDA_REFERENCES_102', 1),
#  ('BRENDA_REFERENCES_102_PUBMED', 1),
#  ('BRENDA_KM_p_nitrophenyl_beta_D_cellopentaoside_DATA', 1),
#  ('BRENDA_KM_p_nitrophenyl_beta_D_cellopentaoside_UNITS', 1),
#  ('BRENDA_KM_p_nitrophenyl_beta_D_cellopentaoside_REFS', 1),
#  ('BRENDA_KM_p_nitrophenyl_beta_D_cellotetraoside_DATA', 1),
#  ('BRENDA_KM_p_nitrophenyl_beta_D_cellotetraoside_UNITS', 1),
#  ('BRENDA_KM_p_nitrophenyl_beta_D_cellotetraoside_REFS', 1),
#  ('BRENDA_REFERENCES_33', 1),
#  ('BRENDA_SU_DATA', 1),
#  ('BRENDA_SU_REFS', 1),
#  ('BRENDA_SU_COMMENT', 1),
#  ('BRENDA_KM_2,4_dinitrophenyl_beta_D_cellobioside_DATA', 1),
#  ('BRENDA_KM_2,4_dinitrophenyl_beta_D_cellobioside_UNITS', 1),
#  ('BRENDA_KM_2,4_dinitrophenyl_beta_D_cellobioside_REFS', 1),
#  ('BRENDA_KM_2,4_dinitrophenyl_beta_D_cellobioside_COMMENT', 1),
#  ('BRENDA_TN_2,4_dinitrophenyl_beta_D_cellobioside_DATA', 1),
#  ('BRENDA_TN_2,4_dinitrophenyl_beta_D_cellobioside_UNITS', 1),
#  ('BRENDA_TN_2,4_dinitrophenyl_beta_D_cellobioside_REFS', 1),
#  ('BRENDA_TN_2,4_dinitrophenyl_beta_D_cellobioside_COMMENT', 1),
#  ('BRENDA_REFERENCES_53', 1),
#  ('BRENDA_REFERENCES_94', 1),
#  ('BRENDA_REFERENCES_94_PUBMED', 1),
#  ('BRENDA_REFERENCES_389', 1),
#  ('BRENDA_IC50_DATA', 1),
#  ('BRENDA_IC50_UNITS', 1),
#  ('BRENDA_IC50_REFS', 1),
#  ('BRENDA_IC50_COMMENT', 1),
#  ('BRENDA_IC50_sodium_hypochlorite_DATA', 1),
#  ('BRENDA_IC50_sodium_hypochlorite_UNITS', 1),
#  ('BRENDA_IC50_sodium_hypochlorite_REFS', 1),
#  ('BRENDA_REFERENCES_227', 1),
#  ('BRENDA_REFERENCES_227_PUBMED', 1),
#  ('BRENDA_KM_4_nitrophenyl_D_cellobioside_DATA', 1),
#  ('BRENDA_KM_4_nitrophenyl_D_cellobioside_UNITS', 1),
#  ('BRENDA_KM_4_nitrophenyl_D_cellobioside_REFS', 1),
#  ('BRENDA_KM_4_nitrophenyl_D_cellobioside_COMMENT', 1),
#  ('BRENDA_TN_4_nitrophenyl_D_cellobioside_DATA', 1),
#  ('BRENDA_TN_4_nitrophenyl_D_cellobioside_UNITS', 1),
#  ('BRENDA_TN_4_nitrophenyl_D_cellobioside_REFS', 1),
#  ('BRENDA_TN_4_nitrophenyl_D_cellobioside_COMMENT', 1),
#  ('BRENDA_TN_carboxymethyl_cellulose_DATA', 1),
#  ('BRENDA_TN_carboxymethyl_cellulose_UNITS', 1),
#  ('BRENDA_TN_carboxymethyl_cellulose_REFS', 1),
#  ('BRENDA_TN_carboxymethyl_cellulose_COMMENT', 1),
#  ('BRENDA_REFERENCES_106', 1),
#  ('BRENDA_REFERENCES_106_PUBMED', 1),
#  ('BRENDA_REFERENCES_255', 1),
#  ('BRENDA_REFERENCES_255_PUBMED', 1),
#  ('BRENDA_REFERENCES_268', 1),
#  ('BRENDA_REFERENCES_268_PUBMED', 1),
#  ('BRENDA_REFERENCES_277', 1),
#  ('BRENDA_REFERENCES_277_PUBMED', 1),
#  ('BRENDA_REFERENCES_329', 1),
#  ('BRENDA_REFERENCES_329_PUBMED', 1),
#  ('BRENDA_REFERENCES_359', 1),
#  ('BRENDA_REFERENCES_396', 1),
#  ('BRENDA_REFERENCES_396_PUBMED', 1),
#  ('BRENDA_REFERENCES_424', 1),
#  ('BRENDA_REFERENCES_424_PUBMED', 1),
#  ('BRENDA_KM_p_nitrophenyl_cellobiose_DATA', 1),
#  ('BRENDA_KM_p_nitrophenyl_cellobiose_UNITS', 1),
#  ('BRENDA_KM_p_nitrophenyl_cellobiose_REFS', 1),
#  ('BRENDA_KM_p_nitrophenyl_cellobiose_COMMENT', 1),
#  ('BRENDA_TN_p_nitrophenyl_cellobiose_DATA', 1),
#  ('BRENDA_TN_p_nitrophenyl_cellobiose_UNITS', 1),
#  ('BRENDA_TN_p_nitrophenyl_cellobiose_REFS', 1),
#  ('BRENDA_TN_p_nitrophenyl_cellobiose_COMMENT', 1),
#  ('BRENDA_REFERENCES_315', 1),
#  ('BRENDA_REFERENCES_315_PUBMED', 1),
#  ('BRENDA_REFERENCES_340', 1),
#  ('BRENDA_REFERENCES_340_PUBMED', 1),
#  ('BRENDA_TN_Barley_beta_glucan_DATA', 1),
#  ('BRENDA_TN_Barley_beta_glucan_UNITS', 1),
#  ('BRENDA_TN_Barley_beta_glucan_REFS', 1),
#  ('BRENDA_TN_Barley_beta_glucan_COMMENT', 1),
#  ('BRENDA_TN_Avicel_DATA', 1),
#  ('BRENDA_TN_Avicel_UNITS', 1),
#  ('BRENDA_TN_Avicel_REFS', 1),
#  ('BRENDA_TN_Avicel_COMMENT', 1),
#  ('BRENDA_KM_4_methylumbelliferyl_cellobioside_DATA', 1),
#  ('BRENDA_KM_4_methylumbelliferyl_cellobioside_UNITS', 1),
#  ('BRENDA_KM_4_methylumbelliferyl_cellobioside_REFS', 1),
#  ('BRENDA_KM_4_methylumbelliferyl_cellobioside_COMMENT', 1),
#  ('BRENDA_TN_4_methylumbelliferyl_cellobioside_DATA', 1),
#  ('BRENDA_TN_4_methylumbelliferyl_cellobioside_UNITS', 1),
#  ('BRENDA_TN_4_methylumbelliferyl_cellobioside_REFS', 1),
#  ('BRENDA_TN_4_methylumbelliferyl_cellobioside_COMMENT', 1),
#  ('BRENDA_REFERENCES_294', 1),
#  ('BRENDA_REFERENCES_294_PUBMED', 1),
#  ('BRENDA_TN_carboxymethylcellulose_DATA', 1),
#  ('BRENDA_TN_carboxymethylcellulose_UNITS', 1),
#  ('BRENDA_TN_carboxymethylcellulose_REFS', 1),
#  ('BRENDA_TN_carboxymethylcellulose_COMMENT', 1),
#  ('BRENDA_KM_Cellopentaose_DATA', 1),
#  ('BRENDA_KM_Cellopentaose_UNITS', 1),
#  ('BRENDA_KM_Cellopentaose_REFS', 1),
#  ('BRENDA_KM_Cellopentaose_COMMENT', 1),
#  ('BRENDA_KM_Barley_beta_glucan_DATA', 1),
#  ('BRENDA_KM_Barley_beta_glucan_UNITS', 1),
#  ('BRENDA_KM_Barley_beta_glucan_REFS', 1),
#  ('BRENDA_KM_Barley_beta_glucan_COMMENT', 1),
#  ('BRENDA_KM_cellotriose_DATA', 1),
#  ('BRENDA_KM_cellotriose_UNITS', 1),
#  ('BRENDA_KM_cellotriose_REFS', 1),
#  ('BRENDA_KM_cellotriose_COMMENT', 1),
#  ('BRENDA_KM_Cellotetraose_DATA', 1),
#  ('BRENDA_KM_Cellotetraose_UNITS', 1),
#  ('BRENDA_KM_Cellotetraose_REFS', 1),
#  ('BRENDA_KM_Cellotetraose_COMMENT', 1),
#  ('BRENDA_KM_carboxymethyl_cellulose_DATA', 1),
#  ('BRENDA_KM_carboxymethyl_cellulose_UNITS', 1),
#  ('BRENDA_KM_carboxymethyl_cellulose_REFS', 1),
#  ('BRENDA_KM_carboxymethyl_cellulose_COMMENT', 1),
#  ('BRENDA_KM_hydroxyethylcellulose_DATA', 1),
#  ('BRENDA_KM_hydroxyethylcellulose_UNITS', 1),
#  ('BRENDA_KM_hydroxyethylcellulose_REFS', 1),
#  ('BRENDA_KM_hydroxyethylcellulose_COMMENT', 1),
#  ('BRENDA_KM_Laminarin_DATA', 1),
#  ('BRENDA_KM_Laminarin_UNITS', 1),
#  ('BRENDA_KM_Laminarin_REFS', 1),
#  ('BRENDA_KM_Laminarin_COMMENT', 1),
#  ('BRENDA_KM_cellohexaose_DATA', 1),
#  ('BRENDA_KM_cellohexaose_UNITS', 1),
#  ('BRENDA_KM_cellohexaose_REFS', 1),
#  ('BRENDA_KM_cellohexaose_COMMENT', 1),
#  ('BRENDA_TN_Laminarin_DATA', 1),
#  ('BRENDA_TN_Laminarin_UNITS', 1),
#  ('BRENDA_TN_Laminarin_REFS', 1),
#  ('BRENDA_TN_Laminarin_COMMENT', 1),
#  ('BRENDA_TN_Cellotetraose_DATA', 1),
#  ('BRENDA_TN_Cellotetraose_UNITS', 1),
#  ('BRENDA_TN_Cellotetraose_REFS', 1),
#  ('BRENDA_TN_Cellotetraose_COMMENT', 1),
#  ('BRENDA_TN_hydroxyethylcellulose_DATA', 1),
#  ('BRENDA_TN_hydroxyethylcellulose_UNITS', 1),
#  ('BRENDA_TN_hydroxyethylcellulose_REFS', 1),
#  ('BRENDA_TN_hydroxyethylcellulose_COMMENT', 1),
#  ('BRENDA_TN_cellohexaose_DATA', 1),
#  ('BRENDA_TN_cellohexaose_UNITS', 1),
#  ('BRENDA_TN_cellohexaose_REFS', 1),
#  ('BRENDA_TN_cellohexaose_COMMENT', 1),
#  ('BRENDA_TN_Cellopentaose_DATA', 1),
#  ('BRENDA_TN_Cellopentaose_UNITS', 1),
#  ('BRENDA_TN_Cellopentaose_REFS', 1),
#  ('BRENDA_TN_Cellopentaose_COMMENT', 1),
#  ('BRENDA_TN_cellotriose_DATA', 1),
#  ('BRENDA_TN_cellotriose_UNITS', 1),
#  ('BRENDA_TN_cellotriose_REFS', 1),
#  ('BRENDA_TN_cellotriose_COMMENT', 1),
#  ('BRENDA_REFERENCES_387', 1),
#  ('BRENDA_REFERENCES_387_PUBMED', 1),
#  ('BRENDA_TN_raffinose_DATA', 1),
#  ('BRENDA_TN_raffinose_UNITS', 1),
#  ('BRENDA_TN_raffinose_REFS', 1),
#  ('BRENDA_TN_raffinose_COMMENT', 1),
#  ('BRENDA_TN_cellobiose_DATA', 1),
#  ('BRENDA_TN_cellobiose_UNITS', 1),
#  ('BRENDA_TN_cellobiose_REFS', 1),
#  ('BRENDA_TN_cellobiose_COMMENT', 1),
#  ('Version_sequence', 1),
#  ('Catalytic_activity', 1),
#  ('Function_[CC]', 1),
#  ('Status', 1),
#  ('Subcellular_location_[CC]', 1),
#  ('Beta_strand', 1),
#  ('Helix', 1),
#  ('Turn', 1),
#  ('Mapped_PubMed_ID', 1),
#  ('Domain_[CC]', 1),
#  ('Taxonomic_lineage_SPECIES_SUBGROUP', 1),
#  ('Cross_reference_TCDB', 1),
#  ('BRENDA_REFERENCES_270', 1),
#  ('BRENDA_REFERENCES_270_PUBMED', 1),
#  ('BRENDA_REFERENCES_161', 1),
#  ('BRENDA_REFERENCES_161_PUBMED', 1),
#  ('BRENDA_REFERENCES_169', 1),
#  ('BRENDA_REFERENCES_169_PUBMED', 1),
#  ('BRENDA_REFERENCES_247', 1),
#  ('BRENDA_REFERENCES_247_PUBMED', 1),
#  ('BRENDA_REFERENCES_262', 1),
#  ('BRENDA_REFERENCES_262_PUBMED', 1),
#  ("BRENDA_TN_4_methylumbelliferyl_N,N'_diacetylchitobiose_DATA", 1),
#  ("BRENDA_TN_4_methylumbelliferyl_N,N'_diacetylchitobiose_UNITS", 1),
#  ("BRENDA_TN_4_methylumbelliferyl_N,N'_diacetylchitobiose_REFS", 1),
#  ("BRENDA_TN_4_methylumbelliferyl_N,N'_diacetylchitobiose_COMMENT", 1),
#  ('BRENDA_REFERENCES_190', 1),
#  ('BRENDA_REFERENCES_190_PUBMED', 1),
#  ("BRENDA_KM_4_methylumbelliferyl_beta_D_N,N',N''_triacetylchitotriose_DATA",
#   1),
#  ('BRENDA_KM', 1),
#  ("BRENDA_KM_4_methylumbelliferyl_beta_D_N,N',N''_triacetylchitotriose_UNITS",
#   1),
#  ("BRENDA_KM_4_methylumbelliferyl_beta_D_N,N',N''_triacetylchitotriose_REFS",
#   1),
#  ('BRENDA_REFERENCES_334', 1),
#  ('BRENDA_REFERENCES_334_PUBMED', 1),
#  ('BRENDA_REFERENCES_87', 1),
#  ('BRENDA_REFERENCES_87_PUBMED', 1),
#  ('BRENDA_TN_beta_chitin_DATA', 1),
#  ('BRENDA_TN_beta_chitin_UNITS', 1),
#  ('BRENDA_TN_beta_chitin_REFS', 1),
#  ('BRENDA_TN_beta_chitin_COMMENT', 1),
#  ('BRENDA_REFERENCES_107', 1),
#  ('BRENDA_REFERENCES_107_PUBMED', 1),
#  ('BRENDA_REFERENCES_181', 1),
#  ('BRENDA_REFERENCES_181_PUBMED', 1),
#  ('BRENDA_REFERENCES_278', 1),
#  ('BRENDA_REFERENCES_278_PUBMED', 1),
#  ('BRENDA_KM_4_nitrophenyl_2_acetylamino_4_O_[2_acetylamino_2_deoxy_beta_D_glucopyranosyl]_2_deoxy_beta_D_glucopyranoside_DATA',
#   1),
#  ('BRENDA_KM_4_nitrophenyl_2_acetylamino_4_O_[2_acetylamino_2_deoxy_beta_D_glucopyranosyl]_2_deoxy_beta_D_glucopyranoside_UNITS',
#   1),
#  ('BRENDA_KM_4_nitrophenyl_2_acetylamino_4_O_[2_acetylamino_2_deoxy_beta_D_glucopyranosyl]_2_deoxy_beta_D_glucopyranoside_REFS',
#   1),
#  ('BRENDA_KM_4_nitrophenyl_2_acetylamino_4_O_[2_acetylamino_2_deoxy_beta_D_glucopyranosyl]_2_deoxy_beta_D_glucopyranoside_COMMENT',
#   1),
#  ('BRENDA_TN_4_nitrophenyl_2_acetylamino_4_O_[2_acetylamino_2_deoxy_beta_D_glucopyranosyl]_2_deoxy_beta_D_glucopyranoside_DATA',
#   1),
#  ('BRENDA_TN_4_nitrophenyl_2_acetylamino_4_O_[2_acetylamino_2_deoxy_beta_D_glucopyranosyl]_2_deoxy_beta_D_glucopyranoside_UNITS',
#   1),
#  ('BRENDA_TN_4_nitrophenyl_2_acetylamino_4_O_[2_acetylamino_2_deoxy_beta_D_glucopyranosyl]_2_deoxy_beta_D_glucopyranoside_REFS',
#   1),
#  ('BRENDA_TN_4_nitrophenyl_2_acetylamino_4_O_[2_acetylamino_2_deoxy_beta_D_glucopyranosyl]_2_deoxy_beta_D_glucopyranoside_COMMENT',
#   1),
#  ('BRENDA_KKM_DATA', 1),
#  ('BRENDA_KKM_UNITS', 1),
#  ('BRENDA_KKM_REFS', 1),
#  ('BRENDA_KKM_COMMENT', 1),
#  ("BRENDA_KM_4_nitrophenyl_beta_N,N'_diacetylchitobioside_DATA", 1),
#  ("BRENDA_KM_4_nitrophenyl_beta_N,N'_diacetylchitobioside_UNITS", 1),
#  ("BRENDA_KM_4_nitrophenyl_beta_N,N'_diacetylchitobioside_REFS", 1),
#  ("BRENDA_KM_4_nitrophenyl_beta_N,N'_diacetylchitobioside_COMMENT", 1),
#  ("BRENDA_TN_4_nitrophenyl_beta_N,N'_diacetylchitobioside_DATA", 1),
#  ("BRENDA_TN_4_nitrophenyl_beta_N,N'_diacetylchitobioside_UNITS", 1),
#  ("BRENDA_TN_4_nitrophenyl_beta_N,N'_diacetylchitobioside_REFS", 1),
#  ("BRENDA_TN_4_nitrophenyl_beta_N,N'_diacetylchitobioside_COMMENT", 1),
#  ("BRENDA_KM_4_methylumbelliferyl_beta_N,N',N''_triacetylchitotrioside_DATA",
#   1),
#  ("BRENDA_KM_4_methylumbelliferyl_beta_N,N',N''_triacetylchitotrioside_UNITS",
#   1),
#  ("BRENDA_KM_4_methylumbelliferyl_beta_N,N',N''_triacetylchitotrioside_REFS",
#   1),
#  ("BRENDA_KM_4_methylumbelliferyl_beta_N,N',N''_triacetylchitotrioside_COMMENT",
#   1),
#  ("BRENDA_KM_4_methylumbelliferyl_beta_D_N,N',N''_triacetylchitotrioside_DATA",
#   1),
#  ("BRENDA_KM_4_methylumbelliferyl_beta_D_N,N',N''_triacetylchitotrioside_UNITS",
#   1),
#  ("BRENDA_KM_4_methylumbelliferyl_beta_D_N,N',N''_triacetylchitotrioside_REFS",
#   1),
#  ("BRENDA_KM_4_methylumbelliferyl_beta_D_N,N',N''_triacetylchitotrioside_COMMENT",
#   1),
#  ("BRENDA_TN_4_methylumbelliferyl_beta_D_N,N',N''_triacetylchitotrioside_DATA",
#   1),
#  ("BRENDA_TN_4_methylumbelliferyl_beta_D_N,N',N''_triacetylchitotrioside_UNITS",
#   1),
#  ("BRENDA_TN_4_methylumbelliferyl_beta_D_N,N',N''_triacetylchitotrioside_REFS",
#   1),
#  ("BRENDA_TN_4_methylumbelliferyl_beta_D_N,N',N''_triacetylchitotrioside_COMMENT",
#   1),
#  ("BRENDA_KM_4_nitrophenyl_beta_1,4_N,N'_diacetyl_chitobiose_DATA", 1),
#  ("BRENDA_KM_4_nitrophenyl_beta_1,4_N,N'_diacetyl_chitobiose_UNITS", 1),
#  ("BRENDA_KM_4_nitrophenyl_beta_1,4_N,N'_diacetyl_chitobiose_REFS", 1),
#  ("BRENDA_KM_4_nitrophenyl_beta_1,4_N,N'_diacetyl_chitobiose_COMMENT", 1),
#  ("BRENDA_TN_4_nitrophenyl_beta_1,4_N,N'_diacetyl_chitobiose_DATA", 1),
#  ("BRENDA_TN_4_nitrophenyl_beta_1,4_N,N'_diacetyl_chitobiose_UNITS", 1),
#  ("BRENDA_TN_4_nitrophenyl_beta_1,4_N,N'_diacetyl_chitobiose_REFS", 1),
#  ("BRENDA_TN_4_nitrophenyl_beta_1,4_N,N'_diacetyl_chitobiose_COMMENT", 1),
#  ('BRENDA_REFERENCES_176', 1),
#  ('BRENDA_REFERENCES_176_PUBMED', 1),
#  ('BRENDA_KM_colloidal_chitin_DATA', 1),
#  ('BRENDA_KM_colloidal_chitin_UNITS', 1),
#  ('BRENDA_KM_colloidal_chitin_REFS', 1),
#  ('BRENDA_KM_colloidal_chitin_COMMENT', 1),
#  ('BRENDA_KM_powdered_chitin_DATA', 1),
#  ('BRENDA_KM_powdered_chitin_UNITS', 1),
#  ('BRENDA_KM_powdered_chitin_REFS', 1),
#  ('BRENDA_KM_powdered_chitin_COMMENT', 1),
#  ('BRENDA_REFERENCES_242', 1),
#  ('BRENDA_REFERENCES_242_PUBMED', 1),
#  ('BRENDA_KM_4_methylumbelliferyl_chitobioside_DATA', 1),
#  ('BRENDA_KM_4_methylumbelliferyl_chitobioside_UNITS', 1),
#  ('BRENDA_KM_4_methylumbelliferyl_chitobioside_REFS', 1),
#  ('BRENDA_KM_4_methylumbelliferyl_chitobioside_COMMENT', 1),
#  ('BRENDA_TN_4_methylumbelliferyl_chitobioside_DATA', 1),
#  ('BRENDA_TN_4_methylumbelliferyl_chitobioside_UNITS', 1),
#  ('BRENDA_TN_4_methylumbelliferyl_chitobioside_REFS', 1),
#  ('BRENDA_TN_4_methylumbelliferyl_chitobioside_COMMENT', 1),
#  ('BRENDA_IC50_methylallosamidin_DATA', 1),
#  ('BRENDA_IC50_methylallosamidin_UNITS', 1),
#  ('BRENDA_IC50_methylallosamidin_REFS', 1),
#  ('BRENDA_IC50_methylallosamidin_COMMENT', 1),
#  ("BRENDA_KM_4_methylumbelliferyl_beta_D_N,N',N''_triacetyl_chitotriose_DATA",
#   1),
#  ("BRENDA_KM_4_methylumbelliferyl_beta_D_N,N',N''_triacetyl_chitotriose_UNITS",
#   1),
#  ("BRENDA_KM_4_methylumbelliferyl_beta_D_N,N',N''_triacetyl_chitotriose_REFS",
#   1),
#  ("BRENDA_KM_4_methylumbelliferyl_beta_D_N,N',N''_triacetyl_chitotriose_COMMENT",
#   1),
#  ('BRENDA_IC50_allosamidin_DATA', 1),
#  ('BRENDA_IC50_allosamidin_UNITS', 1),
#  ('BRENDA_IC50_allosamidin_REFS', 1),
#  ('BRENDA_IC50_allosamidin_COMMENT', 1),
#  ("BRENDA_KM_4_methylumbelliferyl_beta_N,N'_diacetylchitobioside_DATA", 1),
#  ("BRENDA_KM_4_methylumbelliferyl_beta_N,N'_diacetylchitobioside_UNITS", 1),
#  ("BRENDA_KM_4_methylumbelliferyl_beta_N,N'_diacetylchitobioside_REFS", 1),
#  ("BRENDA_KM_4_methylumbelliferyl_beta_N,N'_diacetylchitobioside_COMMENT", 1),
#  ('BRENDA_KM_alpha_chitin_DATA', 1),
#  ('BRENDA_KM_alpha_chitin_UNITS', 1),
#  ('BRENDA_KM_alpha_chitin_REFS', 1),
#  ('BRENDA_KM_alpha_chitin_COMMENT', 1),
#  ("BRENDA_KI_4_nitrophenyl_N,N'_diacetylchitobiose_DATA", 1),
#  ('BRENDA_KI', 1),
#  ("BRENDA_KI_4_nitrophenyl_N,N'_diacetylchitobiose_UNITS", 1),
#  ("BRENDA_KI_4_nitrophenyl_N,N'_diacetylchitobiose_REFS", 1),
#  ("BRENDA_KI_4_nitrophenyl_N,N'_diacetylchitobiose_COMMENT", 1),
#  ("BRENDA_KM_4_nitrophenyl_N,N'_diacetylchitobiose_DATA", 1),
#  ("BRENDA_KM_4_nitrophenyl_N,N'_diacetylchitobiose_UNITS", 1),
#  ("BRENDA_KM_4_nitrophenyl_N,N'_diacetylchitobiose_REFS", 1),
#  ("BRENDA_KM_4_nitrophenyl_N,N'_diacetylchitobiose_COMMENT", 1),
#  ("BRENDA_TN_4_nitrophenyl_N,N'_diacetylchitobiose_DATA", 1),
#  ("BRENDA_TN_4_nitrophenyl_N,N'_diacetylchitobiose_UNITS", 1),
#  ("BRENDA_TN_4_nitrophenyl_N,N'_diacetylchitobiose_REFS", 1),
#  ("BRENDA_TN_4_nitrophenyl_N,N'_diacetylchitobiose_COMMENT", 1),
#  ("BRENDA_KM_4_nitrophenyl_N,N'_diacetyl_beta_D_chitobioside_DATA", 1),
#  ("BRENDA_KM_4_nitrophenyl_N,N'_diacetyl_beta_D_chitobioside_UNITS", 1),
#  ("BRENDA_KM_4_nitrophenyl_N,N'_diacetyl_beta_D_chitobioside_REFS", 1),
#  ("BRENDA_KM_4_nitrophenyl_N,N'_diacetyl_beta_D_chitobioside_COMMENT", 1),
#  ('BRENDA_TN_colloidal_chitin_DATA', 1),
#  ('BRENDA_TN_colloidal_chitin_UNITS', 1),
#  ('BRENDA_TN_colloidal_chitin_REFS', 1),
#  ('BRENDA_TN_colloidal_chitin_COMMENT', 1),
#  ('Metal_binding', 1),
#  ('Subunit_structure_[CC]', 1),
#  ('Repeat', 1),
#  ('Taxonomic_lineage_VARIETAS', 1),
#  ('Cross_reference_ChEMBL', 1),
#  ('Cross_reference_CLAE', 1),
#  ('Cross_reference_DrugCentral', 1),
#  ('Cross_reference_GeneTree', 1),
#  ('Cross_reference_MaxQB', 1),
#  ('Cross_reference_VEuPathDB', 1),
#  ('BRENDA_REFERENCES_52', 1),
#  ('BRENDA_REFERENCES_52_PUBMED', 1),
#  ('BRENDA_MW_DATA', 1),
#  ('BRENDA_MW_REFS', 1),
#  ('BRENDA_MW_COMMENT', 1),
#  ('Redox_potential', 1),
#  ('Cross_reference_ELM', 1),
#  ('BRENDA_REFERENCES_192', 1),
#  ('BRENDA_REFERENCES_192_PUBMED', 1),
#  ('BRENDA_REFERENCES_285', 1),
#  ('BRENDA_REFERENCES_285_PUBMED', 1),
#  ('BRENDA_REFERENCES_319', 1),
#  ('BRENDA_REFERENCES_319_PUBMED', 1),
#  ('BRENDA_EN_DATA', 1),
#  ('BRENDA_EN_REFS', 1),
#  ('BRENDA_EN_COMMENT', 1),
#  ('BRENDA_KI_sulfamic_acid_DATA', 1),
#  ('BRENDA_KI_sulfamic_acid_UNITS', 1),
#  ('BRENDA_KI_sulfamic_acid_REFS', 1),
#  ('BRENDA_KI_sulfamic_acid_COMMENT', 1),
#  ('BRENDA_KI_2,4_bis[aminodihydroxy_lambda4_sulfanyl]_5_chloroaniline_DATA',
#   1),
#  ('BRENDA_KI_2,4_bis[aminodihydroxy_lambda4_sulfanyl]_5_chloroaniline_UNITS',
#   1),
#  ('BRENDA_KI_2,4_bis[aminodihydroxy_lambda4_sulfanyl]_5_chloroaniline_REFS',
#   1),
#  ('BRENDA_KI_2,4_bis[aminodihydroxy_lambda4_sulfanyl]_5_chloroaniline_COMMENT',
#   1),
#  ('BRENDA_KI_valdecoxib_DATA', 1),
#  ('BRENDA_KI_valdecoxib_UNITS', 1),
#  ('BRENDA_KI_valdecoxib_REFS', 1),
#  ('BRENDA_KI_valdecoxib_COMMENT', 1),
#  ('BRENDA_KI_4_[aminodihydroxy_lambda4_sulfanyl]_2_chloroaniline_DATA', 1),
#  ('BRENDA_KI_4_[aminodihydroxy_lambda4_sulfanyl]_2_chloroaniline_UNITS', 1),
#  ('BRENDA_KI_4_[aminodihydroxy_lambda4_sulfanyl]_2_chloroaniline_REFS', 1),
#  ('BRENDA_KI_4_[aminodihydroxy_lambda4_sulfanyl]_2_chloroaniline_COMMENT', 1),
#  ('BRENDA_KI_celecoxib_DATA', 1),
#  ('BRENDA_KI_celecoxib_UNITS', 1),
#  ('BRENDA_KI_celecoxib_REFS', 1),
#  ('BRENDA_KI_celecoxib_COMMENT', 1),
#  ('BRENDA_KI_methazolamide_DATA', 1),
#  ('BRENDA_KI_methazolamide_UNITS', 1),
#  ('BRENDA_KI_methazolamide_REFS', 1),
#  ('BRENDA_KI_methazolamide_COMMENT', 1),
#  ('BRENDA_KI_1,5_bis[aminodihydroxy_lambda4_sulfanyl]_2,3_dichlorobenzene_DATA',
#   1),
#  ('BRENDA_KI_1,5_bis[aminodihydroxy_lambda4_sulfanyl]_2,3_dichlorobenzene_UNITS',
#   1),
#  ('BRENDA_KI_1,5_bis[aminodihydroxy_lambda4_sulfanyl]_2,3_dichlorobenzene_REFS',
#   1),
#  ('BRENDA_KI_1,5_bis[aminodihydroxy_lambda4_sulfanyl]_2,3_dichlorobenzene_COMMENT',
#   1),
#  ('BRENDA_KI_3_[aminodihydroxy_lambda4_sulfanyl]aniline_DATA', 1),
#  ('BRENDA_KI_3_[aminodihydroxy_lambda4_sulfanyl]aniline_UNITS', 1),
#  ('BRENDA_KI_3_[aminodihydroxy_lambda4_sulfanyl]aniline_REFS', 1),
#  ('BRENDA_KI_3_[aminodihydroxy_lambda4_sulfanyl]aniline_COMMENT', 1),
#  ('BRENDA_KI_4_amino_N_4_sulfamoylbenzylbenzenesulfonamide_DATA', 1),
#  ('BRENDA_KI_4_amino_N_4_sulfamoylbenzylbenzenesulfonamide_UNITS', 1),
#  ('BRENDA_KI_4_amino_N_4_sulfamoylbenzylbenzenesulfonamide_REFS', 1),
#  ('BRENDA_KI_4_amino_N_4_sulfamoylbenzylbenzenesulfonamide_COMMENT', 1),
#  ('BRENDA_KI_[4_[aminodihydroxy_lambda4_sulfanyl]phenyl]hydrazine_DATA', 1),
#  ('BRENDA_KI_[4_[aminodihydroxy_lambda4_sulfanyl]phenyl]hydrazine_UNITS', 1),
#  ('BRENDA_KI_[4_[aminodihydroxy_lambda4_sulfanyl]phenyl]hydrazine_REFS', 1),
#  ('BRENDA_KI_[4_[aminodihydroxy_lambda4_sulfanyl]phenyl]hydrazine_COMMENT', 1),
#  ('BRENDA_KI_sulfanilamide_DATA', 1),
#  ('BRENDA_KI_sulfanilamide_UNITS', 1),
#  ('BRENDA_KI_sulfanilamide_REFS', 1),
#  ('BRENDA_KI_sulfanilamide_COMMENT', 1),
#  ('BRENDA_KI_1_[4_[aminodihydroxy_lambda4_sulfanyl]phenyl]ethanamine_DATA', 1),
#  ('BRENDA_KI_1_[4_[aminodihydroxy_lambda4_sulfanyl]phenyl]ethanamine_UNITS',
#   1),
#  ('BRENDA_KI_1_[4_[aminodihydroxy_lambda4_sulfanyl]phenyl]ethanamine_REFS', 1),
#  ('BRENDA_KI_1_[4_[aminodihydroxy_lambda4_sulfanyl]phenyl]ethanamine_COMMENT',
#   1),
#  ('BRENDA_KI_4_[aminodihydroxy_lambda4_sulfanyl]_2_bromoaniline_DATA', 1),
#  ('BRENDA_KI_4_[aminodihydroxy_lambda4_sulfanyl]_2_bromoaniline_UNITS', 1),
#  ('BRENDA_KI_4_[aminodihydroxy_lambda4_sulfanyl]_2_bromoaniline_REFS', 1),
#  ('BRENDA_KI_4_[aminodihydroxy_lambda4_sulfanyl]_2_bromoaniline_COMMENT', 1),
#  ('BRENDA_KI_4_[aminodihydroxy_lambda4_sulfanyl]_2_iodoaniline_DATA', 1),
#  ('BRENDA_KI_4_[aminodihydroxy_lambda4_sulfanyl]_2_iodoaniline_UNITS', 1),
#  ('BRENDA_KI_4_[aminodihydroxy_lambda4_sulfanyl]_2_iodoaniline_REFS', 1),
#  ('BRENDA_KI_4_[aminodihydroxy_lambda4_sulfanyl]_2_iodoaniline_COMMENT', 1),
#  ('BRENDA_KI_1_[4_[aminodihydroxy_lambda4_sulfanyl]phenyl]methanamine_DATA',
#   1),
#  ('BRENDA_KI_1_[4_[aminodihydroxy_lambda4_sulfanyl]phenyl]methanamine_UNITS',
#   1),
#  ('BRENDA_KI_1_[4_[aminodihydroxy_lambda4_sulfanyl]phenyl]methanamine_REFS',
#   1),
#  ('BRENDA_KI_1_[4_[aminodihydroxy_lambda4_sulfanyl]phenyl]methanamine_COMMENT',
#   1),
#  ('BRENDA_KI_dorzolamide_DATA', 1),
#  ('BRENDA_KI_dorzolamide_UNITS', 1),
#  ('BRENDA_KI_dorzolamide_REFS', 1),
#  ('BRENDA_KI_dorzolamide_COMMENT', 1),
#  ('BRENDA_KI_2,4_bis[aminodihydroxy_lamba4_sulfanyl]_5_trifluoromethylaniline_DATA',
#   1),
#  ('BRENDA_KI_2,4_bis[aminodihydroxy_lamba4_sulfanyl]_5_trifluoromethylaniline_UNITS',
#   1),
#  ('BRENDA_KI_2,4_bis[aminodihydroxy_lamba4_sulfanyl]_5_trifluoromethylaniline_REFS',
#   1),
#  ('BRENDA_KI_2,4_bis[aminodihydroxy_lamba4_sulfanyl]_5_trifluoromethylaniline_COMMENT',
#   1),
#  ('BRENDA_KI_4_[aminodihydroxy_lambda4_sulfanyl]_2_fluoroaniline_DATA', 1),
#  ('BRENDA_KI_4_[aminodihydroxy_lambda4_sulfanyl]_2_fluoroaniline_UNITS', 1),
#  ('BRENDA_KI_4_[aminodihydroxy_lambda4_sulfanyl]_2_fluoroaniline_REFS', 1),
#  ('BRENDA_KI_4_[aminodihydroxy_lambda4_sulfanyl]_2_fluoroaniline_COMMENT', 1),
#  ('BRENDA_KI_N3__DATA', 1),
#  ('BRENDA_KI_N3__UNITS', 1),
#  ('BRENDA_KI_N3__REFS', 1),
#  ('BRENDA_KI_N3__COMMENT', 1),
#  ('BRENDA_IC50_Cyanate_DATA', 1),
#  ('BRENDA_IC50_Cyanate_UNITS', 1),
#  ('BRENDA_IC50_Cyanate_REFS', 1),
#  ('BRENDA_IC50_Cyanate_COMMENT', 1),
#  ('BRENDA_IC50_cyanide_DATA', 1),
#  ('BRENDA_IC50_cyanide_UNITS', 1),
#  ('BRENDA_IC50_cyanide_REFS', 1),
#  ('BRENDA_IC50_cyanide_COMMENT', 1),
#  ('BRENDA_IC50_acetazolamide_DATA', 1),
#  ('BRENDA_IC50_acetazolamide_UNITS', 1),
#  ('BRENDA_IC50_acetazolamide_REFS', 1),
#  ('BRENDA_IC50_acetazolamide_COMMENT', 1),
#  ('BRENDA_IC50_azide_DATA', 1),
#  ('BRENDA_IC50_azide_UNITS', 1),
#  ('BRENDA_IC50_azide_REFS', 1),
#  ('BRENDA_IC50_azide_COMMENT', 1),
#  ('BRENDA_REFERENCES_314', 1),
#  ('BRENDA_REFERENCES_314_PUBMED', 1),
#  ('BRENDA_SA_DATA', 1),
#  ('BRENDA_SA_UNITS', 1),
#  ('BRENDA_SA_REFS', 1),
#  ('BRENDA_KI_zonisamide_DATA', 1),
#  ('BRENDA_KI_zonisamide_UNITS', 1),
#  ('BRENDA_KI_zonisamide_REFS', 1),
#  ('BRENDA_KI_zonisamide_COMMENT', 1),
#  ('BRENDA_KI_2_hydrazinocarbonyl_3_phenyl_1H_indole_5_sulfonamide_DATA', 1),
#  ('BRENDA_KI_2_hydrazinocarbonyl_3_phenyl_1H_indole_5_sulfonamide_UNITS', 1),
#  ('BRENDA_KI_2_hydrazinocarbonyl_3_phenyl_1H_indole_5_sulfonamide_REFS', 1),
#  ('BRENDA_KI_2_hydrazinocarbonyl_3_phenyl_1H_indole_5_sulfonamide_COMMENT', 1),
#  ('BRENDA_KI_brinzolamide_DATA', 1),
#  ('BRENDA_KI_brinzolamide_UNITS', 1),
#  ('BRENDA_KI_brinzolamide_REFS', 1),
#  ('BRENDA_KI_brinzolamide_COMMENT', 1),
#  ('BRENDA_REFERENCES_179', 1),
#  ('BRENDA_REFERENCES_179_PUBMED', 1),
#  ('BRENDA_REFERENCES_183', 1),
#  ('BRENDA_REFERENCES_183_PUBMED', 1),
#  ('BRENDA_REFERENCES_170', 1),
#  ('BRENDA_REFERENCES_170_PUBMED', 1),
#  ('BRENDA_KI_5_[[4_nitrophenylsulfonyl]amino]_1,3,4_thiadiazole_2_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_5_[[4_nitrophenylsulfonyl]amino]_1,3,4_thiadiazole_2_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_5_[[4_nitrophenylsulfonyl]amino]_1,3,4_thiadiazole_2_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_5_[[4_nitrophenylsulfonyl]amino]_1,3,4_thiadiazole_2_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_5_[[4_bromophenylsulfonyl]amino]_1,3,4_thiadiazole_2_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_5_[[4_bromophenylsulfonyl]amino]_1,3,4_thiadiazole_2_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_5_[[4_bromophenylsulfonyl]amino]_1,3,4_thiadiazole_2_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_5_[[4_bromophenylsulfonyl]amino]_1,3,4_thiadiazole_2_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_N_5_sulfamoyl_1,3,4_thiadiazol_2_ylfuran_2_carboxamide_DATA', 1),
#  ('BRENDA_KI_N_5_sulfamoyl_1,3,4_thiadiazol_2_ylfuran_2_carboxamide_UNITS', 1),
#  ('BRENDA_KI_N_5_sulfamoyl_1,3,4_thiadiazol_2_ylfuran_2_carboxamide_REFS', 1),
#  ('BRENDA_KI_N_5_sulfamoyl_1,3,4_thiadiazol_2_ylfuran_2_carboxamide_COMMENT',
#   1),
#  ('BRENDA_KI_Furosemide_DATA', 1),
#  ('BRENDA_KI_Furosemide_UNITS', 1),
#  ('BRENDA_KI_Furosemide_REFS', 1),
#  ('BRENDA_KI_Furosemide_COMMENT', 1),
#  ('BRENDA_KI_4_aminosulfonyl_N_[2_[4_aminosulfonylphenyl]ethyl]benzamide_DATA',
#   1),
#  ('BRENDA_KI_4_aminosulfonyl_N_[2_[4_aminosulfonylphenyl]ethyl]benzamide_UNITS',
#   1),
#  ('BRENDA_KI_4_aminosulfonyl_N_[2_[4_aminosulfonylphenyl]ethyl]benzamide_REFS',
#   1),
#  ('BRENDA_KI_4_aminosulfonyl_N_[2_[4_aminosulfonylphenyl]ethyl]benzamide_COMMENT',
#   1),
#  ('BRENDA_KI_4_[2_[[[4_aminosulfonylphenyl]amino]carbonothioyl_amino]ethyl]benzenesulfonamide_DATA',
#   1),
#  ('BRENDA_KI_4_[2_[[[4_aminosulfonylphenyl]amino]carbonothioyl_amino]ethyl]benzenesulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_4_[2_[[[4_aminosulfonylphenyl]amino]carbonothioyl_amino]ethyl]benzenesulfonamide_REFS',
#   1),
#  ('BRENDA_KI_4_[2_[[[4_aminosulfonylphenyl]amino]carbonothioyl_amino]ethyl]benzenesulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_4_[2_[anilinocarbonothioylamino]ethyl]benzenesulfonamide_DATA',
#   1),
#  ('BRENDA_KI_4_[2_[anilinocarbonothioylamino]ethyl]benzenesulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_4_[2_[anilinocarbonothioylamino]ethyl]benzenesulfonamide_REFS',
#   1),
#  ('BRENDA_KI_4_[2_[anilinocarbonothioylamino]ethyl]benzenesulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_4_[[anilinocarbonothioylamino]methyl]benzenesulfonamide_DATA', 1),
#  ('BRENDA_KI_4_[[anilinocarbonothioylamino]methyl]benzenesulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_4_[[anilinocarbonothioylamino]methyl]benzenesulfonamide_REFS', 1),
#  ('BRENDA_KI_4_[[anilinocarbonothioylamino]methyl]benzenesulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_4_[2_[anilinocarbonylamino]ethyl]benzenesulfonamide_DATA', 1),
#  ('BRENDA_KI_4_[2_[anilinocarbonylamino]ethyl]benzenesulfonamide_UNITS', 1),
#  ('BRENDA_KI_4_[2_[anilinocarbonylamino]ethyl]benzenesulfonamide_REFS', 1),
#  ('BRENDA_KI_4_[2_[anilinocarbonylamino]ethyl]benzenesulfonamide_COMMENT', 1),
#  ('BRENDA_KI_4_[anilinocarbonylamino]_6_chlorobenzene_1,3_disulfonamide_DATA',
#   1),
#  ('BRENDA_KI_4_[anilinocarbonylamino]_6_chlorobenzene_1,3_disulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_4_[anilinocarbonylamino]_6_chlorobenzene_1,3_disulfonamide_REFS',
#   1),
#  ('BRENDA_KI_4_[anilinocarbonylamino]_6_chlorobenzene_1,3_disulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_4_[[phenylsulfonylamino]methyl]benzenesulfonamide_DATA', 1),
#  ('BRENDA_KI_4_[[phenylsulfonylamino]methyl]benzenesulfonamide_UNITS', 1),
#  ('BRENDA_KI_4_[[phenylsulfonylamino]methyl]benzenesulfonamide_REFS', 1),
#  ('BRENDA_KI_4_[[phenylsulfonylamino]methyl]benzenesulfonamide_COMMENT', 1),
#  ('BRENDA_KI_4_[acetyloxyamino]_N_[4_aminosulfonylphenyl]benzenesulfonamide_DATA',
#   1),
#  ('BRENDA_KI_4_[acetyloxyamino]_N_[4_aminosulfonylphenyl]benzenesulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_4_[acetyloxyamino]_N_[4_aminosulfonylphenyl]benzenesulfonamide_REFS',
#   1),
#  ('BRENDA_KI_4_[acetyloxyamino]_N_[4_aminosulfonylphenyl]benzenesulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_4_[phenylsulfonylamino]benzenesulfonamide_DATA', 1),
#  ('BRENDA_KI_4_[phenylsulfonylamino]benzenesulfonamide_UNITS', 1),
#  ('BRENDA_KI_4_[phenylsulfonylamino]benzenesulfonamide_REFS', 1),
#  ('BRENDA_KI_4_[phenylsulfonylamino]benzenesulfonamide_COMMENT', 1),
#  ('BRENDA_KI_4_[methylsulfonylamino]benzenesulfonamide_DATA', 1),
#  ('BRENDA_KI_4_[methylsulfonylamino]benzenesulfonamide_UNITS', 1),
#  ('BRENDA_KI_4_[methylsulfonylamino]benzenesulfonamide_REFS', 1),
#  ('BRENDA_KI_4_[methylsulfonylamino]benzenesulfonamide_COMMENT', 1),
#  ('BRENDA_KI_N_[4_aminosulfonylphenyl]benzamide_DATA', 1),
#  ('BRENDA_KI_N_[4_aminosulfonylphenyl]benzamide_UNITS', 1),
#  ('BRENDA_KI_N_[4_aminosulfonylphenyl]benzamide_REFS', 1),
#  ('BRENDA_KI_N_[4_aminosulfonylphenyl]benzamide_COMMENT', 1),
#  ('BRENDA_KI_N_[4_aminosulfonylphenyl]_2,2,2_trifluoroacetamide_DATA', 1),
#  ('BRENDA_KI_N_[4_aminosulfonylphenyl]_2,2,2_trifluoroacetamide_UNITS', 1),
#  ('BRENDA_KI_N_[4_aminosulfonylphenyl]_2,2,2_trifluoroacetamide_REFS', 1),
#  ('BRENDA_KI_N_[4_aminosulfonylphenyl]_2,2,2_trifluoroacetamide_COMMENT', 1),
#  ('BRENDA_KI_3_[anilinocarbonylamino]benzenesulfonamide_DATA', 1),
#  ('BRENDA_KI_3_[anilinocarbonylamino]benzenesulfonamide_UNITS', 1),
#  ('BRENDA_KI_3_[anilinocarbonylamino]benzenesulfonamide_REFS', 1),
#  ('BRENDA_KI_3_[anilinocarbonylamino]benzenesulfonamide_COMMENT', 1),
#  ('BRENDA_KI_N_[4_aminosulfonylphenyl]pentanamide_DATA', 1),
#  ('BRENDA_KI_N_[4_aminosulfonylphenyl]pentanamide_UNITS', 1),
#  ('BRENDA_KI_N_[4_aminosulfonylphenyl]pentanamide_REFS', 1),
#  ('BRENDA_KI_N_[4_aminosulfonylphenyl]pentanamide_COMMENT', 1),
#  ('BRENDA_KI_N_[4_aminosulfonylphenyl]butanamide_DATA', 1),
#  ('BRENDA_KI_N_[4_aminosulfonylphenyl]butanamide_UNITS', 1),
#  ('BRENDA_KI_N_[4_aminosulfonylphenyl]butanamide_REFS', 1),
#  ('BRENDA_KI_N_[4_aminosulfonylphenyl]butanamide_COMMENT', 1),
#  ('BRENDA_KI_N_[4_aminosulfonylphenyl]_2_methylpropanamide_DATA', 1),
#  ('BRENDA_KI_N_[4_aminosulfonylphenyl]_2_methylpropanamide_UNITS', 1),
#  ('BRENDA_KI_N_[4_aminosulfonylphenyl]_2_methylpropanamide_REFS', 1),
#  ('BRENDA_KI_N_[4_aminosulfonylphenyl]_2_methylpropanamide_COMMENT', 1),
#  ('BRENDA_KI_N_[4_aminosulfonylphenyl]_2,2_dimethylpropanamide_DATA', 1),
#  ('BRENDA_KI_N_[4_aminosulfonylphenyl]_2,2_dimethylpropanamide_UNITS', 1),
#  ('BRENDA_KI_N_[4_aminosulfonylphenyl]_2,2_dimethylpropanamide_REFS', 1),
#  ('BRENDA_KI_N_[4_aminosulfonylphenyl]_2,2_dimethylpropanamide_COMMENT', 1),
#  ('BRENDA_KI_2_N,N_dimethylamino_1,3,4_thiadiazole_5_methanesulfonamide_DATA',
#   1),
#  ('BRENDA_KI_2_N,N_dimethylamino_1,3,4_thiadiazole_5_methanesulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_2_N,N_dimethylamino_1,3,4_thiadiazole_5_methanesulfonamide_REFS',
#   1),
#  ('BRENDA_KI_2_N,N_dimethylamino_1,3,4_thiadiazole_5_methanesulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_4_aminoethylbenzenesulfonamide_DATA', 1),
#  ('BRENDA_KI_4_aminoethylbenzenesulfonamide_UNITS', 1),
#  ('BRENDA_KI_4_aminoethylbenzenesulfonamide_REFS', 1),
#  ('BRENDA_KI_4_aminoethylbenzenesulfonamide_COMMENT', 1),
#  ('BRENDA_KI_homosulfanilamide_DATA', 1),
#  ('BRENDA_KI_homosulfanilamide_UNITS', 1),
#  ('BRENDA_KI_homosulfanilamide_REFS', 1),
#  ('BRENDA_KI_homosulfanilamide_COMMENT', 1),
#  ('BRENDA_KI_N_[4_aminosulfonylphenyl]propanamide_DATA', 1),
#  ('BRENDA_KI_N_[4_aminosulfonylphenyl]propanamide_UNITS', 1),
#  ('BRENDA_KI_N_[4_aminosulfonylphenyl]propanamide_REFS', 1),
#  ('BRENDA_KI_N_[4_aminosulfonylphenyl]propanamide_COMMENT', 1),
#  ('BRENDA_KI_hydrochlorothiazide_DATA', 1),
#  ('BRENDA_KI_hydrochlorothiazide_UNITS', 1),
#  ('BRENDA_KI_hydrochlorothiazide_REFS', 1),
#  ('BRENDA_KI_hydrochlorothiazide_COMMENT', 1),
#  ('BRENDA_KI_N_[4_aminosulfonylphenyl]acetamide_DATA', 1),
#  ('BRENDA_KI_N_[4_aminosulfonylphenyl]acetamide_UNITS', 1),
#  ('BRENDA_KI_N_[4_aminosulfonylphenyl]acetamide_REFS', 1),
#  ('BRENDA_KI_N_[4_aminosulfonylphenyl]acetamide_COMMENT', 1),
#  ('BRENDA_KI_sulthiame_DATA', 1),
#  ('BRENDA_KI_sulthiame_UNITS', 1),
#  ('BRENDA_KI_sulthiame_REFS', 1),
#  ('BRENDA_KI_sulthiame_COMMENT', 1),
#  ('BRENDA_KI_DATA', 1),
#  ('BRENDA_KI_UNITS', 1),
#  ('BRENDA_KI_REFS', 1),
#  ('BRENDA_KI_COMMENT', 1),
#  ('BRENDA_KI_4_3_formylphenylbenzene_1_sulfonamide_DATA', 1),
#  ('BRENDA_KI_4_3_formylphenylbenzene_1_sulfonamide_UNITS', 1),
#  ('BRENDA_KI_4_3_formylphenylbenzene_1_sulfonamide_REFS', 1),
#  ('BRENDA_KI_4_3_formylphenylbenzene_1_sulfonamide_COMMENT', 1),
#  ('BRENDA_KI_acetoazolamide_DATA', 1),
#  ('BRENDA_KI_acetoazolamide_UNITS', 1),
#  ('BRENDA_KI_acetoazolamide_REFS', 1),
#  ('BRENDA_KI_acetoazolamide_COMMENT', 1),
#  ('BRENDA_KI_4_2_methylphenylbenzene_1_sulfonamide_DATA', 1),
#  ('BRENDA_KI_4_2_methylphenylbenzene_1_sulfonamide_UNITS', 1),
#  ('BRENDA_KI_4_2_methylphenylbenzene_1_sulfonamide_REFS', 1),
#  ('BRENDA_KI_4_2_methylphenylbenzene_1_sulfonamide_COMMENT', 1),
#  ('BRENDA_KI_4_phenylbenzene_1_sulfonamide_DATA', 1),
#  ('BRENDA_KI_4_phenylbenzene_1_sulfonamide_UNITS', 1),
#  ('BRENDA_KI_4_phenylbenzene_1_sulfonamide_REFS', 1),
#  ('BRENDA_KI_4_phenylbenzene_1_sulfonamide_COMMENT', 1),
#  ('BRENDA_KI_4_3_quinolinylbenzene_1_sulfonamide_DATA', 1),
#  ('BRENDA_KI_4_3_quinolinylbenzene_1_sulfonamide_UNITS', 1),
#  ('BRENDA_KI_4_3_quinolinylbenzene_1_sulfonamide_REFS', 1),
#  ('BRENDA_KI_4_3_quinolinylbenzene_1_sulfonamide_COMMENT', 1),
#  ('BRENDA_KI_N_hydroxysulfamide_DATA', 1),
#  ('BRENDA_KI_N_hydroxysulfamide_UNITS', 1),
#  ('BRENDA_KI_N_hydroxysulfamide_REFS', 1),
#  ('BRENDA_KI_N_hydroxysulfamide_COMMENT', 1),
#  ('BRENDA_KI_tert_butyl_2_6_methylsulfonylbenzo[d]thiazol_2_ylamino_2_oxoethylcarbamate_DATA',
#   1),
#  ('BRENDA_KI_tert_butyl_2_6_methylsulfonylbenzo[d]thiazol_2_ylamino_2_oxoethylcarbamate_UNITS',
#   1),
#  ('BRENDA_KI_tert_butyl_2_6_methylsulfonylbenzo[d]thiazol_2_ylamino_2_oxoethylcarbamate_REFS',
#   1),
#  ('BRENDA_KI_tert_butyl_2_6_methylsulfonylbenzo[d]thiazol_2_ylamino_2_oxoethylcarbamate_COMMENT',
#   1),
#  ('BRENDA_KI_3_morpholin_4_yl_4H_[1,2,3]thiadiazolo[3_4_a]benzimidazole_7_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_3_morpholin_4_yl_4H_[1,2,3]thiadiazolo[3_4_a]benzimidazole_7_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_3_morpholin_4_yl_4H_[1,2,3]thiadiazolo[3_4_a]benzimidazole_7_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_3_morpholin_4_yl_4H_[1,2,3]thiadiazolo[3_4_a]benzimidazole_7_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_S_4_2,4_dibenzylpiperazine_1_carbonylbenzenesulfonamide_DATA', 1),
#  ('BRENDA_KI_S_4_2,4_dibenzylpiperazine_1_carbonylbenzenesulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_S_4_2,4_dibenzylpiperazine_1_carbonylbenzenesulfonamide_REFS', 1),
#  ('BRENDA_KI_S_4_2,4_dibenzylpiperazine_1_carbonylbenzenesulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_S_4_2_benzyl_4_methanesulfonylpiperazine_1_carbonylbenzene_1_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_S_4_2_benzyl_4_methanesulfonylpiperazine_1_carbonylbenzene_1_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_S_4_2_benzyl_4_methanesulfonylpiperazine_1_carbonylbenzene_1_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_S_4_2_benzyl_4_methanesulfonylpiperazine_1_carbonylbenzene_1_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_3_chloro_4H_[1,2,3]thiadiazolo[3,4_a]benzimidazole_7_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_3_chloro_4H_[1,2,3]thiadiazolo[3,4_a]benzimidazole_7_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_3_chloro_4H_[1,2,3]thiadiazolo[3,4_a]benzimidazole_7_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_3_chloro_4H_[1,2,3]thiadiazolo[3,4_a]benzimidazole_7_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_3_methylsulfanyl_4H_[1,2,3]thiadiazolo[3_4_a]benzimidazole_7_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_3_methylsulfanyl_4H_[1,2,3]thiadiazolo[3_4_a]benzimidazole_7_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_3_methylsulfanyl_4H_[1,2,3]thiadiazolo[3_4_a]benzimidazole_7_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_3_methylsulfanyl_4H_[1,2,3]thiadiazolo[3_4_a]benzimidazole_7_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_S_4_3_benzyl_4_methanesulfonylpiperazine_1_carbonylbenzene_1_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_S_4_3_benzyl_4_methanesulfonylpiperazine_1_carbonylbenzene_1_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_S_4_3_benzyl_4_methanesulfonylpiperazine_1_carbonylbenzene_1_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_S_4_3_benzyl_4_methanesulfonylpiperazine_1_carbonylbenzene_1_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_S_4_[4_benzenesulfonyl_2_benzylpiperazine_1_carbonyl]benzene_1_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_S_4_[4_benzenesulfonyl_2_benzylpiperazine_1_carbonyl]benzene_1_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_S_4_[4_benzenesulfonyl_2_benzylpiperazine_1_carbonyl]benzene_1_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_S_4_[4_benzenesulfonyl_2_benzylpiperazine_1_carbonyl]benzene_1_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_S_4_4_acetyl_3_benzylpiperazine_1_carbonylbenzene_1_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_S_4_4_acetyl_3_benzylpiperazine_1_carbonylbenzene_1_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_S_4_4_acetyl_3_benzylpiperazine_1_carbonylbenzene_1_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_S_4_4_acetyl_3_benzylpiperazine_1_carbonylbenzene_1_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_4_[2S_2_benzylpiperazine_1_carbonyl]benzene_1_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_4_[2S_2_benzylpiperazine_1_carbonyl]benzene_1_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_4_[2S_2_benzylpiperazine_1_carbonyl]benzene_1_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_4_[2S_2_benzylpiperazine_1_carbonyl]benzene_1_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_S_4_[2_benzyl_4_4_sulfamoylbenzoylpiperazine_1_carbonyl]benzene_1_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_S_4_[2_benzyl_4_4_sulfamoylbenzoylpiperazine_1_carbonyl]benzene_1_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_S_4_[2_benzyl_4_4_sulfamoylbenzoylpiperazine_1_carbonyl]benzene_1_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_S_4_[2_benzyl_4_4_sulfamoylbenzoylpiperazine_1_carbonyl]benzene_1_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_R_4_[2_benzyl_4_2_phenylacetylpiperazine_1_carbonyl]benzene_1_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_R_4_[2_benzyl_4_2_phenylacetylpiperazine_1_carbonyl]benzene_1_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_R_4_[2_benzyl_4_2_phenylacetylpiperazine_1_carbonyl]benzene_1_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_R_4_[2_benzyl_4_2_phenylacetylpiperazine_1_carbonyl]benzene_1_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_S_1_[4_benzenesulfonyl_2_benzylpiperazin_1_yl]ethan_1_one_DATA',
#   1),
#  ('BRENDA_KI_S_1_[4_benzenesulfonyl_2_benzylpiperazin_1_yl]ethan_1_one_UNITS',
#   1),
#  ('BRENDA_KI_S_1_[4_benzenesulfonyl_2_benzylpiperazin_1_yl]ethan_1_one_REFS',
#   1),
#  ('BRENDA_KI_S_1_[4_benzenesulfonyl_2_benzylpiperazin_1_yl]ethan_1_one_COMMENT',
#   1),
#  ('BRENDA_KI_S_4_[3_benzyl_4_2_phenylacetylpiperazine_1_carbonyl]benzene_1_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_S_4_[3_benzyl_4_2_phenylacetylpiperazine_1_carbonyl]benzene_1_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_S_4_[3_benzyl_4_2_phenylacetylpiperazine_1_carbonyl]benzene_1_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_S_4_[3_benzyl_4_2_phenylacetylpiperazine_1_carbonyl]benzene_1_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_R_4_3_benzyl_4_methanesulfonylpiperazine_1_carbonylbenzene_1_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_R_4_3_benzyl_4_methanesulfonylpiperazine_1_carbonylbenzene_1_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_R_4_3_benzyl_4_methanesulfonylpiperazine_1_carbonylbenzene_1_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_R_4_3_benzyl_4_methanesulfonylpiperazine_1_carbonylbenzene_1_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_S_4_[2_benzyl_4_2_phenylacetylpiperazine_1_carbonyl]benzene_1_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_S_4_[2_benzyl_4_2_phenylacetylpiperazine_1_carbonyl]benzene_1_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_S_4_[2_benzyl_4_2_phenylacetylpiperazine_1_carbonyl]benzene_1_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_S_4_[2_benzyl_4_2_phenylacetylpiperazine_1_carbonyl]benzene_1_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_R_1_[4_benzenesulfonyl_2_benzylpiperazin_1_yl]ethan_1_one_DATA',
#   1),
#  ('BRENDA_KI_R_1_[4_benzenesulfonyl_2_benzylpiperazin_1_yl]ethan_1_one_UNITS',
#   1),
#  ('BRENDA_KI_R_1_[4_benzenesulfonyl_2_benzylpiperazin_1_yl]ethan_1_one_REFS',
#   1),
#  ('BRENDA_KI_R_1_[4_benzenesulfonyl_2_benzylpiperazin_1_yl]ethan_1_one_COMMENT',
#   1),
#  ('BRENDA_KI_R__4_4_benzoyl_2_benzylpiperazine_1_carbonylbenzene_1_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_R__4_4_benzoyl_2_benzylpiperazine_1_carbonylbenzene_1_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_R__4_4_benzoyl_2_benzylpiperazine_1_carbonylbenzene_1_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_R__4_4_benzoyl_2_benzylpiperazine_1_carbonylbenzene_1_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_S_4_3_benzylpiperazine_1_carbonylbenzene_1_sulfonamide_DATA', 1),
#  ('BRENDA_KI_S_4_3_benzylpiperazine_1_carbonylbenzene_1_sulfonamide_UNITS', 1),
#  ('BRENDA_KI_S_4_3_benzylpiperazine_1_carbonylbenzene_1_sulfonamide_REFS', 1),
#  ('BRENDA_KI_S_4_3_benzylpiperazine_1_carbonylbenzene_1_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_S__4_4_benzoyl_2_benzylpiperazine_1_carbonylbenzene_1_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_S__4_4_benzoyl_2_benzylpiperazine_1_carbonylbenzene_1_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_S__4_4_benzoyl_2_benzylpiperazine_1_carbonylbenzene_1_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_S__4_4_benzoyl_2_benzylpiperazine_1_carbonylbenzene_1_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_R_4_4_acetyl_3_benzylpiperazine_1_carbonylbenzene_1_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_R_4_4_acetyl_3_benzylpiperazine_1_carbonylbenzene_1_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_R_4_4_acetyl_3_benzylpiperazine_1_carbonylbenzene_1_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_R_4_4_acetyl_3_benzylpiperazine_1_carbonylbenzene_1_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_R_4_2_benzyl_4_methanesulfonylpiperazine_1_carbonylbenzene_1_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_R_4_2_benzyl_4_methanesulfonylpiperazine_1_carbonylbenzene_1_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_R_4_2_benzyl_4_methanesulfonylpiperazine_1_carbonylbenzene_1_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_R_4_2_benzyl_4_methanesulfonylpiperazine_1_carbonylbenzene_1_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_S_4_4_benzoyl_3_benzylpiperazine_1_carbonylbenzene_1_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_S_4_4_benzoyl_3_benzylpiperazine_1_carbonylbenzene_1_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_S_4_4_benzoyl_3_benzylpiperazine_1_carbonylbenzene_1_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_S_4_4_benzoyl_3_benzylpiperazine_1_carbonylbenzene_1_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_S_4_3,4_dibenzylpiperazine_1_carbonylbenzene_1_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_S_4_3,4_dibenzylpiperazine_1_carbonylbenzene_1_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_S_4_3,4_dibenzylpiperazine_1_carbonylbenzene_1_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_S_4_3,4_dibenzylpiperazine_1_carbonylbenzene_1_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_R_4_[4_benzenesulfonyl_3_benzylpiperazine_1_carbonyl]benzene_1_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_R_4_[4_benzenesulfonyl_3_benzylpiperazine_1_carbonyl]benzene_1_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_R_4_[4_benzenesulfonyl_3_benzylpiperazine_1_carbonyl]benzene_1_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_R_4_[4_benzenesulfonyl_3_benzylpiperazine_1_carbonyl]benzene_1_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_R_4_3,4_dibenzylpiperazine_1_carbonylbenzene_1_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_R_4_3,4_dibenzylpiperazine_1_carbonylbenzene_1_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_R_4_3,4_dibenzylpiperazine_1_carbonylbenzene_1_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_R_4_3,4_dibenzylpiperazine_1_carbonylbenzene_1_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_4H_[1,2,3]thiadiazolo[3,4_a]benzimidazole_7_sulfonamide_DATA', 1),
#  ('BRENDA_KI_4H_[1,2,3]thiadiazolo[3,4_a]benzimidazole_7_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_4H_[1,2,3]thiadiazolo[3,4_a]benzimidazole_7_sulfonamide_REFS', 1),
#  ('BRENDA_KI_4H_[1,2,3]thiadiazolo[3,4_a]benzimidazole_7_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_N_1_2_hydroxyphenylamino_3_methyl_1_oxobutan_2_ylcarbamothioylbenzamide_DATA',
#   1),
#  ('BRENDA_KI_N_1_2_hydroxyphenylamino_3_methyl_1_oxobutan_2_ylcarbamothioylbenzamide_UNITS',
#   1),
#  ('BRENDA_KI_N_1_2_hydroxyphenylamino_3_methyl_1_oxobutan_2_ylcarbamothioylbenzamide_REFS',
#   1),
#  ('BRENDA_KI_N_1_2_hydroxyphenylamino_3_methyl_1_oxobutan_2_ylcarbamothioylbenzamide_COMMENT',
#   1),
#  ('BRENDA_KI_N_1_2_hydroxyphenylamino_4_methyl_1_oxopentan_2_ylcarbamothioyl_benzamide_DATA',
#   1),
#  ('BRENDA_KI_N_1_2_hydroxyphenylamino_4_methyl_1_oxopentan_2_ylcarbamothioyl_benzamide_UNITS',
#   1),
#  ('BRENDA_KI_N_1_2_hydroxyphenylamino_4_methyl_1_oxopentan_2_ylcarbamothioyl_benzamide_REFS',
#   1),
#  ('BRENDA_KI_N_1_2_hydroxyphenylamino_4_methyl_1_oxopentan_2_ylcarbamothioyl_benzamide_COMMENT',
#   1),
#  ('BRENDA_KI_R__4_2_benzyl_4_methylpiperazine_1_carbonylbenzene_1_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_R__4_2_benzyl_4_methylpiperazine_1_carbonylbenzene_1_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_R__4_2_benzyl_4_methylpiperazine_1_carbonylbenzene_1_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_R__4_2_benzyl_4_methylpiperazine_1_carbonylbenzene_1_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_R_4_[4_benzenesulfonyl_2_benzylpiperazine_1_carbonyl]benzene_1_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_R_4_[4_benzenesulfonyl_2_benzylpiperazine_1_carbonyl]benzene_1_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_R_4_[4_benzenesulfonyl_2_benzylpiperazine_1_carbonyl]benzene_1_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_R_4_[4_benzenesulfonyl_2_benzylpiperazine_1_carbonyl]benzene_1_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_S__4_2_benzyl_4_methylpiperazine_1_carbonylbenzene_1_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_S__4_2_benzyl_4_methylpiperazine_1_carbonylbenzene_1_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_S__4_2_benzyl_4_methylpiperazine_1_carbonylbenzene_1_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_S__4_2_benzyl_4_methylpiperazine_1_carbonylbenzene_1_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_4_[2R_2_benzylpiperazine_1_carbonyl]benzene_1_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_4_[2R_2_benzylpiperazine_1_carbonyl]benzene_1_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_4_[2R_2_benzylpiperazine_1_carbonyl]benzene_1_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_4_[2R_2_benzylpiperazine_1_carbonyl]benzene_1_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_R_4_[3_benzyl_4_2_phenylacetylpiperazine_1_carbonyl]benzene_1_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_R_4_[3_benzyl_4_2_phenylacetylpiperazine_1_carbonyl]benzene_1_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_R_4_[3_benzyl_4_2_phenylacetylpiperazine_1_carbonyl]benzene_1_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_R_4_[3_benzyl_4_2_phenylacetylpiperazine_1_carbonyl]benzene_1_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_S_4_[4_benzenesulfonyl_3_benzylpiperazine_1_carbonyl]benzene_1_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_S_4_[4_benzenesulfonyl_3_benzylpiperazine_1_carbonyl]benzene_1_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_S_4_[4_benzenesulfonyl_3_benzylpiperazine_1_carbonyl]benzene_1_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_S_4_[4_benzenesulfonyl_3_benzylpiperazine_1_carbonyl]benzene_1_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_R_4_4_benzoyl_3_benzylpiperazine_1_carbonylbenzene_1_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_R_4_4_benzoyl_3_benzylpiperazine_1_carbonylbenzene_1_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_R_4_4_benzoyl_3_benzylpiperazine_1_carbonylbenzene_1_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_R_4_4_benzoyl_3_benzylpiperazine_1_carbonylbenzene_1_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_S_4_3_benzyl_4_methylpiperazine_1_carbonylbenzene_1_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_S_4_3_benzyl_4_methylpiperazine_1_carbonylbenzene_1_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_S_4_3_benzyl_4_methylpiperazine_1_carbonylbenzene_1_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_S_4_3_benzyl_4_methylpiperazine_1_carbonylbenzene_1_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_R_4_3_benzylpiperazine_1_carbonylbenzene_1_sulfonamide_DATA', 1),
#  ('BRENDA_KI_R_4_3_benzylpiperazine_1_carbonylbenzene_1_sulfonamide_UNITS', 1),
#  ('BRENDA_KI_R_4_3_benzylpiperazine_1_carbonylbenzene_1_sulfonamide_REFS', 1),
#  ('BRENDA_KI_R_4_3_benzylpiperazine_1_carbonylbenzene_1_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_R_4_3_benzyl_4_methylpiperazine_1_carbonylbenzene_1_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_R_4_3_benzyl_4_methylpiperazine_1_carbonylbenzene_1_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_R_4_3_benzyl_4_methylpiperazine_1_carbonylbenzene_1_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_R_4_3_benzyl_4_methylpiperazine_1_carbonylbenzene_1_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_R_17R_4_[2_benzyl_4_4_sulfamoylbenzoylpiperazine_1_carbonyl]benzene_1_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_R_17R_4_[2_benzyl_4_4_sulfamoylbenzoylpiperazine_1_carbonyl]benzene_1_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_R_17R_4_[2_benzyl_4_4_sulfamoylbenzoylpiperazine_1_carbonyl]benzene_1_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_R_17R_4_[2_benzyl_4_4_sulfamoylbenzoylpiperazine_1_carbonyl]benzene_1_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_R_4_2,4_dibenzylpiperazine_1_carbonylbenzenesulfonamide_DATA', 1),
#  ('BRENDA_KI_R_4_2,4_dibenzylpiperazine_1_carbonylbenzenesulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_R_4_2,4_dibenzylpiperazine_1_carbonylbenzenesulfonamide_REFS', 1),
#  ('BRENDA_KI_R_4_2,4_dibenzylpiperazine_1_carbonylbenzenesulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_curcumin_DATA', 1),
#  ('BRENDA_KI_curcumin_UNITS', 1),
#  ('BRENDA_KI_curcumin_REFS', 1),
#  ('BRENDA_KI_curcumin_COMMENT', 1),
#  ('BRENDA_KI_2E_2_[4_hydroxyphenylmethylidene]_N_5_sulfanylidene_4,5_dihydro_1_3,4_thiadiazol_2_ylhydrazine_1_carboxamide_DATA',
#   1),
#  ('BRENDA_KI_2E_2_[4_hydroxyphenylmethylidene]_N_5_sulfanylidene_4,5_dihydro_1_3,4_thiadiazol_2_ylhydrazine_1_carboxamide_UNITS',
#   1),
#  ('BRENDA_KI_2E_2_[4_hydroxyphenylmethylidene]_N_5_sulfanylidene_4,5_dihydro_1_3,4_thiadiazol_2_ylhydrazine_1_carboxamide_REFS',
#   1),
#  ('BRENDA_KI_2E_2_[4_hydroxyphenylmethylidene]_N_5_sulfanylidene_4,5_dihydro_1_3,4_thiadiazol_2_ylhydrazine_1_carboxamide_COMMENT',
#   1),
#  ('BRENDA_KI_salicylic_acid_DATA', 1),
#  ('BRENDA_KI_salicylic_acid_UNITS', 1),
#  ('BRENDA_KI_salicylic_acid_REFS', 1),
#  ('BRENDA_KI_salicylic_acid_COMMENT', 1),
#  ('BRENDA_KI_dobutamine_DATA', 1),
#  ('BRENDA_KI_dobutamine_UNITS', 1),
#  ('BRENDA_KI_dobutamine_REFS', 1),
#  ('BRENDA_KI_dobutamine_COMMENT', 1),
#  ('BRENDA_KI_2E_2_[4_hydroxy_3_methylphenylmethylidene]_N_5_sulfanylidene_4_5_dihydro_1,3,4_thiadiazol_2_ylhydrazine_1_carboxamide_DATA',
#   1),
#  ('BRENDA_KI_2E_2_[4_hydroxy_3_methylphenylmethylidene]_N_5_sulfanylidene_4_5_dihydro_1,3,4_thiadiazol_2_ylhydrazine_1_carboxamide_UNITS',
#   1),
#  ('BRENDA_KI_2E_2_[4_hydroxy_3_methylphenylmethylidene]_N_5_sulfanylidene_4_5_dihydro_1,3,4_thiadiazol_2_ylhydrazine_1_carboxamide_REFS',
#   1),
#  ('BRENDA_KI_2E_2_[4_hydroxy_3_methylphenylmethylidene]_N_5_sulfanylidene_4_5_dihydro_1,3,4_thiadiazol_2_ylhydrazine_1_carboxamide_COMMENT',
#   1),
#  ('BRENDA_KI_resorcinol_DATA', 1),
#  ('BRENDA_KI_resorcinol_UNITS', 1),
#  ('BRENDA_KI_resorcinol_REFS', 1),
#  ('BRENDA_KI_resorcinol_COMMENT', 1),
#  ('BRENDA_KI_catechol_DATA', 1),
#  ('BRENDA_KI_catechol_UNITS', 1),
#  ('BRENDA_KI_catechol_REFS', 1),
#  ('BRENDA_KI_catechol_COMMENT', 1),
#  ('BRENDA_KI_2_coumaric_acid_DATA', 1),
#  ('BRENDA_KI_2_coumaric_acid_UNITS', 1),
#  ('BRENDA_KI_2_coumaric_acid_REFS', 1),
#  ('BRENDA_KI_2_coumaric_acid_COMMENT', 1),
#  ('BRENDA_KI_phenol_DATA', 1),
#  ('BRENDA_KI_phenol_UNITS', 1),
#  ('BRENDA_KI_phenol_REFS', 1),
#  ('BRENDA_KI_phenol_COMMENT', 1),
#  ('BRENDA_REFERENCES_344', 1),
#  ('BRENDA_REFERENCES_344_PUBMED', 1),
#  ('BRENDA_KI_3,4_dihydroisoquinoline_21H_sulfonamide_DATA', 1),
#  ('BRENDA_KI_3,4_dihydroisoquinoline_21H_sulfonamide_UNITS', 1),
#  ('BRENDA_KI_3,4_dihydroisoquinoline_21H_sulfonamide_REFS', 1),
#  ('BRENDA_KI_3,4_dihydroisoquinoline_21H_sulfonamide_COMMENT', 1),
#  ('BRENDA_KI_6,7_dimethoxy_1_ethyl_3,4_dihydroisoquinoline_21H_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_6,7_dimethoxy_1_ethyl_3,4_dihydroisoquinoline_21H_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_6,7_dimethoxy_1_ethyl_3,4_dihydroisoquinoline_21H_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_6,7_dimethoxy_1_ethyl_3,4_dihydroisoquinoline_21H_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_6,7_dimethoxy_1_methyl_3,4_dihydroisoquinoline_21H_sulfonamide_DATA',
#   1),
#  ('BRENDA_KI_6,7_dimethoxy_1_methyl_3,4_dihydroisoquinoline_21H_sulfonamide_UNITS',
#   1),
#  ('BRENDA_KI_6,7_dimethoxy_1_methyl_3,4_dihydroisoquinoline_21H_sulfonamide_REFS',
#   1),
#  ('BRENDA_KI_6,7_dimethoxy_1_methyl_3,4_dihydroisoquinoline_21H_sulfonamide_COMMENT',
#   1),
#  ('BRENDA_KI_1_cyclopropyl_6,7_dimethoxy_3,4_dihydroisoquinoline_21H_sulfonamide_DATA',
#   1),
#  ...]

# %%
ec_num = ec_nums[2]

df = pd.read_csv(f"../workflows/{ec_num}/csv/{ec_num}_uniprot.csv")

filtered_seqs = readFastaFile(f"../workflows/{ec_num}/files/{ec_num}_filt.fasta")

filtered_names = [seq.name for seq in filtered_seqs]

filtered_df = df.loc[(df["Entry"].isin(filtered_names))]

filtered_df[['Entry', 'Taxonomic_lineage_INFRAORDER'] ]

#print(filtered_df['Cross_reference_TIGRFAMs'])
# Out:
#          Entry Taxonomic_lineage_INFRAORDER
# 2   A0A0D9RRD7                  Simiiformes
# 3   A0A0D9RYP7                  Simiiformes
# 4       Q09767                          NaN
# 5       Q15382                  Simiiformes
# 6       C9ZVV9                          NaN
# ..         ...                          ...
# 89      Q68U42                          NaN
# 90      P60763                  Simiiformes
# 91      Q9UL25                  Simiiformes
# 92      Q6T311                  Simiiformes
# 93      Q6T310                  Simiiformes
#
# [88 rows x 2 columns]
