# %%
from FilteringScripts import *

# %% [markdown]
# # Beta lactamases 3_5_2_6

# %%
filtered = generate_filtered_entries('3_5_2_6', 0.15, 'BRENDA_KM', 5)
# Out:
# BRENDA_KM
# 3_5_2_6 BRENDA_KM: 55.04% of entries annotated
# Choose a SMART row to grab entries from: 0
# Choose a InterPro row to grab entries from: 0
# Happy with selection(Y/N): Y
# Number of sequences after IP filtering = 80
# Number of sequences after SMART filtering = 44
# Cross_reference_Gene3D
# 3_5_2_6 Cross_reference_Gene3D: 98.45% of entries annotated
#
#
# Compare entries to gene3D filtering? (Y/N): Y
# Cross_reference_Gene3D
# 3.40.710.10;              82
# 3.60.15.10;               45
# dtype: int64
# Enter a Gene3D tag: 3.40.710.10;
# Would you like to choose another group? (Y/N): N
# The number of entries in the Gene3D group are 82
#
# Cross_reference_OrthoDB
# 3_5_2_6 Cross_reference_OrthoDB: 4.65% of entries annotated
#
#
# Compare entries to OrthoDB filtering? (Y/N): N
# 3_5_2_6: BRENDA_KM: 51.25% of entries annotated in IP
# 3_5_2_6: BRENDA_KM: 61.36% of entries annotated in SMART
# 3_5_2_6: BRENDA_KM: 51.22% of entries annotated in Gene3D

# %%
calc_total_overlap(filtered)

compare_overlap(filtered, 'IP', 'SMART')

compare_overlap(filtered, 'IP', 'Gene3D')

compare_overlap(filtered, 'SMART', 'Gene3D')
# Out:
# IP: entries = 80
# SMART: entries = 44
# Gene3D: entries = 82
# Total overlap between all groups 0
#
# IP: entries = 80
# SMART: entries = 44
# Total overlap between IP & SMART is 0
#
# IP: entries = 80
# Gene3D: entries = 82
# Total overlap between IP & Gene3D is 80
#
# SMART: entries = 44
# Gene3D: entries = 82
# Total overlap between SMART & Gene3D is 0
# set()

# %% [markdown]
# # EC 4_1_1_39: Rubisco
#
# https://pubmed.ncbi.nlm.nih.gov/18063718/ - Function, structure, and evolution of the RubisCO-like proteins and their RubisCO homologs
#
# Forms I, II & III are functionally distinct from Form IV

# %%
rub_filtered = generate_filtered_entries('4_1_1_39', 0.5, 'BRENDA_KM', 2)
# Out:
# BRENDA_KM
# 4_1_1_39 BRENDA_KM: 71.05% of entries annotated
# Choose a SMART row to grab entries from: 0
# Choose a InterPro row to grab entries from: 0
# Happy with selection(Y/N): Y
# Number of sequences after IP filtering = 102
# Number of sequences after SMART filtering = 6
# Cross_reference_Gene3D
# 4_1_1_39 Cross_reference_Gene3D: 99.12% of entries annotated
#
#
# Compare entries to gene3D filtering? (Y/N): Y
# Cross_reference_Gene3D
# 3.20.20.110;3.30.70.150;    106
# 3.30.190.10;                  6
# 3.20.20.110;                  1
# dtype: int64
# Enter a Gene3D tag: 3.20.20.110;3.30.70.150;
# Would you like to choose another group? (Y/N): N
# The number of entries in the Gene3D group are 106
#
# Cross_reference_OrthoDB
# 4_1_1_39 Cross_reference_OrthoDB: 9.65% of entries annotated
#
#
# Compare entries to OrthoDB filtering? (Y/N): Y
# Cross_reference_OrthoDB
# 474428at2759;              4
# 9533at2157;                4
# 1258997at2759;             2
# ...

# %%
calc_total_overlap(rub_filtered)

compare_overlap(rub_filtered, 'IP', 'SMART')

compare_overlap(rub_filtered, 'IP', 'Gene3D')

compare_overlap(rub_filtered, 'IP', 'Ortho_DB')

compare_overlap(rub_filtered, 'SMART', 'Gene3D')
# Out:
# IP: entries = 102
# SMART: entries = 6
# Gene3D: entries = 106
# Ortho_DB: entries = 4
# Total overlap between all groups 0
#
# IP: entries = 102
# SMART: entries = 6
# Total overlap between IP & SMART is 0
#
# IP: entries = 102
# Gene3D: entries = 106
# Total overlap between IP & Gene3D is 102
#
# IP: entries = 102
# Ortho_DB: entries = 4
# Total overlap between IP & Ortho_DB is 4
#
# SMART: entries = 6
# Gene3D: entries = 106
# Total overlap between SMART & Gene3D is 0
# set()

# %% [markdown]
# # Chitinase 3_2_1_14
#
# Molecular evolution and functional characterization of chitinase gene family in Populus trichocarpa -
# https://www.sciencedirect.com/science/article/pii/S0378111922001482?via%3Dihub

# %%
test = generate_filtered_entries('3_2_1_14', 0.2, 'BRENDA_KM', 5)
# Out:
# BRENDA_KM
# 3_2_1_14 BRENDA_KM: 13.68% of entries annotated
# Choose a SMART row to grab entries from: 1
# Choose a InterPro row to grab entries from: 1
# Happy with selection(Y/N): Y
# Number of sequences after IP filtering = 36
# Number of sequences after SMART filtering = 47
# Cross_reference_Gene3D
# 3_2_1_14 Cross_reference_Gene3D: 80.0% of entries annotated
#
#
# Compare entries to gene3D filtering? (Y/N): Y
# Cross_reference_Gene3D
# 3.10.50.10;                             26
# 3.30.60.10;                             21
# 2.60.40.10;3.10.50.10;                  18
# 2.60.40.10;                              5
# 1.50.10.10;2.170.160.10;4.10.870.10;     2
# 2.120.10.80;2.60.40.10;                  1
# 2.60.40.10;2.60.40.290;3.10.50.10;       1
# 2.60.40.290;3.10.50.10;                  1
# 3.10.350.10;                             1
# dtype: int64
# Enter a Gene3D tag: 3.10.50.10;
# Would you like to choose another group? (Y/N): N
# ...

# %%
calc_total_overlap(test)

compare_overlap(test, 'IP', 'SMART')

compare_overlap(test, 'IP', 'Gene3D')

compare_overlap(test, 'SMART', 'Gene3D')
# Out:
# IP: entries = 36
# SMART: entries = 47
# Gene3D: entries = 26
# Ortho_DB: entries = 2
# Total overlap between all groups 1
#
# IP: entries = 36
# SMART: entries = 47
# Total overlap between IP & SMART is 36
#
# IP: entries = 36
# Gene3D: entries = 26
# Total overlap between IP & Gene3D is 22
#
# SMART: entries = 47
# Gene3D: entries = 26
# Total overlap between SMART & Gene3D is 26
# {'A0A286JZ72',
#  'A0MWE0',
#  'A0MWE1',
#  'A6YJX1',
#  'A9LI60',
#  'B3GGC7',
#  'B5L0W0',
#  'D3GG13',
#  'D3YGV3',
#  'F8WSQ0',
#  'F8WSQ1',
#  'H9CWQ0',
#  'K7ZLW6',
#  'P11797',
#  'P29030',
#  'P48827',
#  'Q06HA3',
#  'Q2V6H4',
#  'Q3YLC5',
#  'Q43576',
#  'Q4W6L6',
#  'Q54276',
#  'Q5MYT4',
#  'Q5YLC0',
#  'Q8ITU3',
#  'Q9BZP6'}

# %%
test['SMART']
# Out:
# ['Q06AK1',
#  'A0A286JZ72',
#  'Q54276',
#  'Q2V6H4',
#  'H9CWQ0',
#  'K7ZLW6',
#  'A5A699',
#  'F8WSQ2',
#  'F8WSQ1',
#  'F8WSQ0',
#  'E5FGC5',
#  'Q8U1H4',
#  'P29030',
#  'D8V3F2',
#  'D3YGV3',
#  'Q43576',
#  'A9LI60',
#  'B5L0W0',
#  'Q1EM71',
#  'Q8ITU3',
#  'Q4W6L6',
#  'D3GG13',
#  'Q2I0I7',
#  'B7UB89',
#  'B3GGC7',
#  'A6YJX1',
#  'Q9CE95',
#  'B1VBB0',
#  'Q93LF1',
#  'Q06HA3',
#  'P48827',
#  'A0MWE1',
#  'A0MWE0',
#  'P11797',
#  'P07254',
#  'Q3YLC5',
#  'A0EQW8',
#  'Q75ZW9',
#  'Q5MYT4',
#  'Q4AE60',
#  'Q869E2',
#  'Q9BZP6',
#  'Q5YLC0',
#  'Q4AE57',
#  'Q4AE58',
#  'Q4AE59',
#  'Q4AE61']
