# %%
from FilteringScripts import *

# %% [markdown]
# # Beta lactamases 3_5_2_6

# %%
filtered = generate_filtered_entries('3_5_2_6', 0.15, 'BRENDA_KM', 1)
# Out:
# BRENDA_KM
# 3_5_2_6 BRENDA_KM: 55.04% of entries annotated
# Choose a SMART row to grab entries from: 0
# Choose a InterPro row to grab entries from: 1
# Happy with selection(Y/N):
# Choose a SMART row to grab entries from: 0
# Choose a InterPro row to grab entries from: -
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_9167/41558452.py in <module>
# ----> 1 filtered = generate_filtered_entries('3_5_2_6', 0.15, 'BRENDA_KM', 1)
#
# ~/expat_bench/notebooks/FilteringScripts.py in generate_filtered_entries(ec_num, threshold, enzyme_prop, entry_limit)
#     351         choose_smart_tag = int(input('Choose a SMART row to grab entries from: '))
#     352
# --> 353         choose_ip_tag = int(input('Choose a InterPro row to grab entries from: '))
#     354
#     355         #display SMART entries of chosen tags and groups that are similar
#
# ...

# %%
calc_total_overlap(filtered)

compare_overlap(filtered, 'IP', 'SMART')

compare_overlap(filtered, 'IP', 'Gene3D')

compare_overlap(filtered, 'SMART', 'Gene3D')



compare_overlap(filtered, 'IP', 'Pfam')

filtered['Gene3D']
# Out:
# IP: entries = 43
# SMART: entries = 44
# Pfam: entries = 34
# Gene3D: entries = 45
# Total overlap between all groups 33
#
# IP: entries = 43
# SMART: entries = 44
# Total overlap between IP & SMART is 43
#
# IP: entries = 43
# Gene3D: entries = 45
# Total overlap between IP & Gene3D is 43
#
# SMART: entries = 44
# Gene3D: entries = 45
# Total overlap between SMART & Gene3D is 44
#
# IP: entries = 43
# Pfam: entries = 34
# Total overlap between IP & Pfam is 33
# ['Q9KVZ2',
#  'E6Y3G9',
#  'A0A024FRL9',
#  'S5ZIP8',
#  'T2A6Y2',
#  'M1VE66',
#  'J7I0S9',
#  'H6WET3',
#  'A0A0F6N6D4',
#  'H6WZS9',
#  'I3VKD5',
#  'F2YZ26',
#  'C7C422',
#  'B6EPH0',
#  'E9RIT0',
#  'P25910',
#  'Q8KRJ3',
#  'Q9RMI1',
#  'Q5U807',
#  'Q7WYA8',
#  'Q970L2',
#  'P04190',
#  'P52699',
#  'B1NLE9',
#  'Q6D395',
#  'A8R403',
#  'Q2HY42',
#  'O31272',
#  'P52700',
#  'Q9XAY4',
#  'P26918',
#  'Q8GCU7',
#  'Q7DH52',
#  'Q53CM3',
#  'Q79MP6',
#  'Q840P9',
#  'Q9F629',
#  'Q6JE29',
#  'Q8GIW8',
#  'Q8G979',
# ...

# %% [markdown]
# # EC 4_1_1_39: Rubisco
#
# https://pubmed.ncbi.nlm.nih.gov/18063718/ - Function, structure, and evolution of the RubisCO-like proteins and their RubisCO homologs
#
# Forms I, II & III are functionally distinct from Form IV

# %%
rub_filtered = generate_filtered_entries('4_1_1_39', 0.5, 'BRENDA_KM', 2)
# Out:
# BRENDA_KM
# 4_1_1_39 BRENDA_KM: 71.05% of entries annotated
# Choose a SMART row to grab entries from: 0
# Choose a InterPro row to grab entries from: 0
# Happy with selection(Y/N): Y
# Number of sequences after IP filtering = 102
# Number of sequences after SMART filtering = 6
# Cross_reference_Gene3D
# 4_1_1_39 Cross_reference_Gene3D: 99.12% of entries annotated
#
#
# Compare entries to gene3D filtering? (Y/N): Y
# Cross_reference_Gene3D
# 3.20.20.110;3.30.70.150;    106
# 3.30.190.10;                  6
# 3.20.20.110;                  1
# dtype: int64
# Enter a Gene3D tag: 3.20.20.110;3.30.70.150;
# Would you like to choose another group? (Y/N): N
# The number of entries in the Gene3D group are 106
#
# Cross_reference_OrthoDB
# 4_1_1_39 Cross_reference_OrthoDB: 9.65% of entries annotated
#
#
# Compare entries to OrthoDB filtering? (Y/N): Y
# Cross_reference_OrthoDB
# 474428at2759;              4
# 9533at2157;                4
# 1258997at2759;             2
# ...

# %%
calc_total_overlap(rub_filtered)

compare_overlap(rub_filtered, 'IP', 'SMART')

compare_overlap(rub_filtered, 'IP', 'Gene3D')

compare_overlap(rub_filtered, 'IP', 'Ortho_DB')

compare_overlap(rub_filtered, 'SMART', 'Gene3D')
# Out:
# IP: entries = 102
# SMART: entries = 6
# Gene3D: entries = 106
# Ortho_DB: entries = 4
# Total overlap between all groups 0
#
# IP: entries = 102
# SMART: entries = 6
# Total overlap between IP & SMART is 0
#
# IP: entries = 102
# Gene3D: entries = 106
# Total overlap between IP & Gene3D is 102
#
# IP: entries = 102
# Ortho_DB: entries = 4
# Total overlap between IP & Ortho_DB is 4
#
# SMART: entries = 6
# Gene3D: entries = 106
# Total overlap between SMART & Gene3D is 0
# set()

# %% [markdown]
# # Chitinase 3_2_1_14
#
# Molecular evolution and functional characterization of chitinase gene family in Populus trichocarpa -
# https://www.sciencedirect.com/science/article/pii/S0378111922001482?via%3Dihub

# %%
test = generate_filtered_entries('3_2_1_14', 0.6,'BRENDA_KM', 5)
# Out:
# BRENDA_KM
# 3_2_1_14 BRENDA_KM: 13.68% of entries annotated
# Choose a SMART row to grab entries from: 0
# Choose a InterPro row to grab entries from: 0
# Happy with selection(Y/N): Y
# Number of sequences after IP filtering = 20
# Number of sequences after SMART filtering = 21
# Cross_reference_Pfam
# 3_2_1_14 Cross_reference_Pfam: 97.89% of entries annotated
#
#
# Compare entries to Pfam filtering? (Y/N): Y
# <class 'pandas.core.series.Series'>
# Cross_reference_Pfam
# PF00704;                    26
# PF00187;PF00182;            20
# PF08329;PF00704;            11
# PF01607;PF00704;             7
# PF02839;PF00704;             6
# PF02839;PF00041;PF00704;     5
# PF00182;                     5
# PF02011;                     2
# PF16403;PF00704;             1
# PF03427;PF00704;             1
# PF02839;PF00182;             1
# PF00041;PF00704;             1
# PF02839;                     1
# PF00041;PF01344;             1
# PF01464;                     1
# ...

# %%
calc_total_overlap(test)

compare_overlap(test, 'IP', 'SMART')

print(compare_overlap(test, 'IP', 'Gene3D'))

compare_overlap(test, 'SMART', 'Gene3D')


print(test['SMART'])
# Out:
# IP: entries = 20
# SMART: entries = 21
# Pfam: entries = 20
# Gene3D: entries = 21
# Total overlap between all groups 19
#
# IP: entries = 20
# SMART: entries = 21
# Total overlap between IP & SMART is 20
#
# IP: entries = 20
# Gene3D: entries = 21
# Total overlap between IP & Gene3D is 20
#
# {'P24626', 'Q9AXR9', 'B5L6N2', 'Q9XEN6', 'Q9FRV1', 'P11955', 'P29022', 'Q852P9', 'Q42839', 'C1K2M3', 'B1B6T0', 'Q8W428', 'Q8W427', 'A1IJ67', 'Q6T484', 'Q7XAU6', 'Q546P8', 'B3VFX0', 'Q41539', 'C0JR29'}
# SMART: entries = 21
# Gene3D: entries = 21
# Total overlap between SMART & Gene3D is 21
#
# ['Q7XAU6', 'Q852P9', 'P29022', 'P24626', 'C0JR29', 'C1K2M3', 'B3VFX0', 'Q546P8', 'Q8W427', 'Q9FRV1', 'B5L6N2', 'B1B6T0', 'Q9SQF7', 'Q41539', 'Q8W428', 'Q6T484', 'Q9XEN6', 'Q9AXR9', 'Q42839', 'P11955', 'A1IJ67']

# %% [markdown]
# # EC 3_6_5_2
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3265948/
# Phylogeny of Ras superfamily proteins - Study concluded that there are 5 families, Ras, Rab, Rho, Arf/Sar & Ran with Ras as the root of the tree

# %%
filtered = generate_filtered_entries('3_6_5_2', 0.5, 'BRENDA_KM', 2)
# Out:
# BRENDA_KM
# 3_6_5_2 does not have BRENDA_KM column
# Choose a SMART row to grab entries from: 0
# Choose a InterPro row to grab entries from: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3691/3633386553.py in <module>
# ----> 1 filtered = generate_filtered_entries('3_6_5_2', 0.5, 'BRENDA_KM', 2)
#
# ~/expat_bench/notebooks/FilteringScripts.py in generate_filtered_entries(ec_num, threshold, enzyme_prop, entry_limit)
#     360         display_grouped_families(ec_num, ip_matrix, choose_ip_tag, 'Cross_reference_InterPro')
#     361
# --> 362         end_comp = input('Happy with selection(Y/N): ')
#     363
#     364         if end_comp.upper() == "Y":
#
# ~/miniconda3/envs/expat_bench/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1163             self._parent_ident["shell"],
#    1164             self.get_parent("shell"),
# ...

# %%
calc_total_overlap(filtered)

x = compare_overlap(filtered, 'IP', 'SMART')

print(x)
# Out:
# IP: entries = 66
# SMART: entries = 73
# Pfam: entries = 74
# Gene3D: entries = 85
# Total overlap between all groups 65
#
# IP: entries = 66
# SMART: entries = 73
# Total overlap between IP & SMART is 65
#
# {'A1XKT8', 'P62746', 'Q9QUI0', 'Q4H116', 'A0A098DKM1', 'A1XKT4', 'A1XKS1', 'P61019', 'Q8WUD1', 'P62820', 'Q9D3G9', 'Q8TAI7', 'A1XKQ6', 'A1XKR6', 'A1XKT9', 'P62745', 'A0A0D9RRD7', 'Q15669', 'P63000', 'A1XKS4', 'A1XKS0', 'A1XKT6', 'A1XKR7', 'A1XKR5', 'A1XKR0', 'P61586', 'Q5U814', 'Q9H0U4', 'A0A0D9RYP7', 'A1XKT5', 'A1XKT2', 'P01112', 'A1XKQ8', 'Q5ANA9', 'Q9NRW1', 'P61006', 'Q6DUE5', 'P08134', 'Q9SSX0', 'P01116', 'A1XKT1', 'P60953', 'B0B5Z8', 'Q96AX2', 'A1XKQ7', 'Q6T310', 'A6YDU4', 'A1XKS2', 'Q99JI6', 'A1XKR2', 'A1XKS7', 'A1XKQ9', 'A1XKR3', 'A1XKS8', 'A1XKR9', 'A1XKR1', 'A1XKT3', 'P15153', 'A1XKS9', 'O97342', 'P08645', 'P60763', 'Q58XP3', 'Q4H115', 'A1XKS5'}

# %% [markdown]
# # 2_7_11_22 cyclin-dependent kinase
#
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2279817/

# %%
cyclins = generate_filtered_entries('2_7_11_22', 0.8, 'BRENDA_KM', 2)
# Out:
# BRENDA_KM
# 2_7_11_22 does not have BRENDA_KM column
# Choose a SMART row to grab entries from: 0
# Choose a InterPro row to grab entries from: 0
# Happy with selection(Y/N): Y
# Number of sequences after IP filtering = 77
# Number of sequences after SMART filtering = 91
# Cross_reference_Pfam
# 2_7_11_22 Cross_reference_Pfam: 98.92% of entries annotated
#
#
# Compare entries to Pfam filtering? (Y/N): Y
# <class 'pandas.core.series.Series'>
# Cross_reference_Pfam
# PF00069;                90
# PF07714;                 2
# dtype: int64
# Enter a Gene3D tag: PF00069;
# Would you like to choose another group? (Y/N): N
# The number of entries in the Gene3D group are 90
#
# Cross_reference_Gene3D
# 2_7_11_22 Cross_reference_Gene3D: 0.0% of entries annotated
#
#
# Compare entries to gene3D filtering? (Y/N): N
# Cross_reference_OrthoDB
# 2_7_11_22 Cross_reference_OrthoDB: 46.24% of entries annotated
#
#
# Compare entries to OrthoDB filtering? (Y/N): Y
# <class 'pandas.core.series.Series'>
# ...

# %%
calc_total_overlap(cyclins)

compare_overlap(cyclins, 'IP', 'SMART')


print(cyclins['SMART'])
# Out:
# IP: entries = 77
# SMART: entries = 91
# Pfam: entries = 90
# Ortho_DB: entries = 24
# Total overlap between all groups 23
#
# IP: entries = 77
# SMART: entries = 91
# Total overlap between IP & SMART is 77
#
# ...

# %% [markdown]
# # 1_15_1_1 Superoxide Dismutase
#
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5745492/

# %%
test = generate_filtered_entries('1_15_1_1', 0.8, 'BRENDA_KM', 2)
# Out:
# BRENDA_KM
# 1_15_1_1 does not have BRENDA_KM column
# /home/seb-porras/expat_bench/notebooks/FilteringScripts.py:133: UserWarning: Attempting to set identical left == right == -0.5 results in singular transformations; automatically expanding.
#   plt.imshow(distmat, plt.cm.inferno, interpolation='nearest')
# /home/seb-porras/expat_bench/notebooks/FilteringScripts.py:133: UserWarning: Attempting to set identical bottom == top == -0.5 results in singular transformations; automatically expanding.
#   plt.imshow(distmat, plt.cm.inferno, interpolation='nearest')
# Choose a SMART row to grab entries from: 0
# Choose a InterPro row to grab entries from: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_36417/2851820365.py in <module>
# ----> 1 test = generate_filtered_entries('1_15_1_1', 0.8, 'BRENDA_KM', 2)
#
# ...

# %%
calc_total_overlap(test)

thing = compare_overlap(test, 'IP', 'Pfam')


print(thing)
# Out:
# IP: entries = 63
# Pfam: entries = 65
# Gene3D: entries = 65
# Total overlap between all groups 63
#
# IP: entries = 63
# Pfam: entries = 65
# Total overlap between IP & Pfam is 63
#
# {'A6MHS2', 'Q9Y8H8', 'E9LK91', 'P22302', 'Q7X4G4', 'Q9RUV2', 'Q9M7R2', 'P04179', 'A0A0S2E8T0', 'P07895', 'Q5UVY7', 'Q2KN28', 'Q9P9I6', 'Q0PKG3', 'D9Q0R7', 'Q5K650', 'D3J1L2', 'Q8YSZ1', 'J7HET3', 'O93724', 'P84612', 'Q76CY6', 'Q2TV65', 'A0A088MAG2', 'C3W7V1', 'Q2KN29', 'M9QJD2', 'B0L421', 'A0A1L5JYH9', 'A9U908', 'T1T1K2', 'D0UXW8', 'P80857', 'Q08713', 'Q65Y02', 'P0AGD3', 'O82519', 'P00448', 'Q96UT6', 'Q2UZU7', 'A3NS93', 'M9P0B0', 'D0EAP3', 'F8V325', 'P09223', 'O30970', 'P61502', 'Q6QGY4', 'A0A088MM36', 'E9RHW0', 'C3W7V0', 'C3W7U9', 'I3VPK0', 'H8YHP4', 'B6ENP9', 'A3RLW7', 'C7DRQ4', 'D3IU19', 'Q71S33', 'Q6QHT3', 'Q2KN30', 'P11796', 'Q381J5'}

# %% [markdown]
# # 3_2_1_8

# %%
test = generate_filtered_entries('3_2_1_8', 0.5, 'BRENDA_KM', 3)
# Out:
# BRENDA_KM
# 3_2_1_8 BRENDA_KM: 2.26% of entries annotated
# Choose a SMART row to grab entries from: 1
# Choose a InterPro row to grab entries from: 0
# Happy with selection(Y/N): N
# Choose a SMART row to grab entries from: 0
# Choose a InterPro row to grab entries from: 0
# Happy with selection(Y/N): N
# Choose a SMART row to grab entries from: 2
# Choose a InterPro row to grab entries from: 0
# Happy with selection(Y/N): Y
# Number of sequences after IP filtering = 43
# Number of sequences after SMART filtering = 6
# Cross_reference_Pfam
# 3_2_1_8 Cross_reference_Pfam: 99.25% of entries annotated
#
#
# Compare entries to Pfam filtering? (Y/N): Y
# <class 'pandas.core.series.Series'>
# Cross_reference_Pfam
# PF00457;                            48
# PF00331;                            34
# PF00331;PF00652;                     6
# PF00734;PF00331;                     5
# PF00734;PF00457;                     4
# PF06452;PF02018;PF00331;PF00395;     3
# ...

# %%
calc_total_overlap(test)

compare_overlap(test, 'Gene3D', 'IP')

#print(test['SMART'])
# Out:
# IP: entries = 43
# SMART: entries = 6
# Pfam: entries = 48
# Gene3D: entries = 51
# Total overlap between all groups 0
#
# Gene3D: entries = 51
# IP: entries = 43
# Total overlap between Gene3D & IP is 38
# {'A0A0F7N1T1',
#  'B5SYI8',
#  'B9ZZN9',
#  'D1G4K3',
#  'D1GFE6',
#  'D1KJJ7',
#  'E0X4B3',
#  'F5CI28',
#  'F8W669',
#  'O13447',
#  'O43097',
#  'O74716',
#  'P09850',
#  'P18429',
#  'P33557',
#  'P35809',
#  'P36217',
#  'P36218',
#  'P55329',
#  'Q00263',
#  'Q06562',
#  'Q2LMP0',
#  'Q2PGY1',
#  'Q2PU02',
#  'Q3S401',
#  'Q45VU2',
#  'Q4P0L3',
#  'Q5EFR9',
#  'Q6QA21',
#  'Q6UN40',
#  'Q6VAY1',
#  'Q7ZA57',
#  'Q84F19',
#  'Q8J1V6',
#  'Q9HFH0',
#  'Q9UVF9',
#  'W8VR85',
#  'X0M5X0'}

# %%
filtered = generate_filtered_entries('2_4_99_18', 0.15, 'BRENDA_KM', 5)
# Out:
# BRENDA_KM
# 2_4_99_18 does not have BRENDA_KM column
# Choose a SMART row to grab entries from: 0
# Choose a InterPro row to grab entries from: 0
# Happy with selection(Y/N): Y
# Number of sequences after IP filtering = 64
# Cross_reference_Pfam
# 2_4_99_18 Cross_reference_Pfam: 92.13% of entries annotated
#
#
# Compare entries to Pfam filtering? (Y/N): Y
# <class 'pandas.core.series.Series'>
# Cross_reference_Pfam
# PF02516;                    32
# PF18079;PF02516;            32
# PF18246;PF18235;PF02516;     4
# PF13231;                     3
# PF02516;PF18527;             2
# PF04756;                     2
# PF02109;                     1
# PF03345;                     1
# PF04597;                     1
# PF05251;                     1
# PF05817;                     1
# PF10215;                     1
# PF18235;PF02516;             1
# dtype: int64
# Enter a Gene3D tag: PF02516;
# Would you like to choose another group? (Y/N): N
# The number of entries in the Gene3D group are 32
#
# ...

# %%
calc_total_overlap(filtered)

compare_overlap(filtered, 'Pfam', 'IP')
# Out:
# IP: entries = 64
# Pfam: entries = 32
# Ortho_DB: entries = 25
# Total overlap between all groups 3
#
# Pfam: entries = 32
# IP: entries = 64
# Total overlap between Pfam & IP is 32
# {'A1RRM7',
#  'A1RXW3',
#  'A2BM28',
#  'A3DL26',
#  'A4FWA0',
#  'A4WLR5',
#  'A4YHQ7',
#  'A5UL43',
#  'A6UQ69',
#  'A6UWW3',
#  'A6VH10',
#  'A8MBU0',
#  'A9A114',
#  'A9A9N9',
#  'B1L5S3',
#  'B1YAG2',
#  'B8D352',
#  'E1B265',
#  'O27660',
#  'O29918',
#  'O30195',
#  'O58981',
#  'P39007',
#  'Q2NHD2',
#  'Q4J9B4',
#  'Q58920',
#  'Q6LXC8',
#  'Q8U3P6',
#  'Q8ZTY7',
#  'Q93ZY3',
#  'Q973G2',
#  'Q97Z77'}
