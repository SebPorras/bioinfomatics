# %% [markdown]
# # Load in sorted fasta files and try to find columns that behave the same

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
from matplotlib import cm
import sys
from collections import defaultdict
from collections import Counter
from collections import OrderedDict
import numpy as np

# %%
df = pd.read_csv("../workflows/3_5_2_6/csv/3_5_2_6_uniprot.csv")

df = df.loc[:,~df.columns.str.startswith('BRENDA_REFERENCES') & ~df.columns.str.contains('REFS')]
# Out:
#       Entry                                     BRENDA_CL_DATA  \
# 0    Q9KVZ2  (gene blaIMP-2, recombinant expression in Esch...
# 1    A0EL75                                                NaN
# 2    Q93F76                                                NaN
# 3    Q7BEB3                                                NaN
# 4    Q51578  (Mox-1 is a unique plasmid-mediated class C be...
# ..      ...                                                ...
# 124  Q6JP75                                                NaN
# 125  Q6PL88  (cloned into a multicopy plasmid and expressed...
# 126  Q6VCW0           (expression in Escherichia coli)_count=1
# 127  Q7WZ37                                           _count=1
# 128  P0AD64           (expression in Escherichia coli)_count=1
#
#                                         BRENDA_CR_DATA BRENDA_EN_DATA  \
# 0    (purified enzyme IMP-2 MBL, hanging drop vapou...            NaN
# ...
