# %%
from filtering_scripts_v2 import *

# %% [markdown]
# # Example workflow - filtering based for Beta Lactamases

# %%
generate_filtered_entries('3_5_2_6', 0.15, 0, 'BRENDA_PHO_DATA', 1)
# Out:
# BRENDA_PHO_DATA
# 3_5_2_6 BRENDA_PHO_DATA: 17.05% of entries annotated
